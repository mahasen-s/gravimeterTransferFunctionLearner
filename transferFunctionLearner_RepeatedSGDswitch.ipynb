# %% [markdown]
# ## Deep learning prototype model
# Tensorflow implementation of a fully connected deep net for arbitrarily shaped input and output layers, with the following features:
# - Easy control of net topology and hyperparameters
# - Abstracted functions for retrieving/constructing training data
# - Exponential decay of learning rate
# - Dropout regularisation
# - Batch normalisation
# - Automatic logging of bulk statistics of each layer through tensorboard (and convenient functions to attach logging to custom functions)
#
#
# ## Visualising progress
# To inspect the training progress, run
#
# >  `>tensorboard --logdir=<log_dir>`
#
#
# from the terminal, where `log_dir` as as defined above
#
# ## Requirements
# - TensorFlow 1.8
# - numpy
# - subprocess

# %%
import tensorflow as tf
import numpy as np
from subprocess import call
import time, math
import h5py
# Out:
# /home/mahasen/anaconda3/envs/intel_3.6_TF_1.8/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Setting dtype for tensorflow and numpy environments
DTYPE = tf.float64
DTYPE_np = np.float64
log_dir = '/mnt/dataDrive3/mahasen/tmp/funclearn' # Directory where we dump tensorboard log files

# Useful function for resetting logdir and tensorflow graph
def reset_tf():
    call(["rm","-rf",log_dir+'/'])
    tf.reset_default_graph()
    
    
# Define some functions for initialising layers with appropriate statistics    
def get_weights(shape,dtype):
    # Returns trainable weight variable, initialised from truncated (+\- 2std. dev. only) standard normal distribution
    return tf.Variable(tf.truncated_normal(shape, dtype=dtype),name='weights')

def get_biases(shape,dtype):
    # Returns trainable bias variable, initialised arbitrarily as a small constant
    return tf.Variable(tf.constant(0.01, shape=shape, dtype=dtype),name='biases')

def get_bn_offset(shape,dtype):
    # Returns trainable bias/offset variable for batch normalisation
    return tf.Variable(tf.truncated_normal(shape=shape, dtype=dtype),name='beta_offset')

def get_bn_scale(shape,dtype):
    # Returns trainable scale variable for batch normalisation
    return tf.Variable(tf.constant(1.0, shape=shape, dtype=dtype),name='gamma_scale')


def variable_summaries(var):
    # Attaches mean, stddev, max, min, and a histogram of an input var to a tensor
    # Useful for TensorBoard visualisation
    with tf.name_scope('summaries'):
        mean = tf.reduce_mean(var,name='mean')
        stddev = tf.sqrt(tf.reduce_mean(tf.square(var-mean)),name='stddev')
        
        tf.summary.scalar('mean',mean)
        tf.summary.scalar('stddev',stddev)
        tf.summary.scalar('max',tf.reduce_max(var))
        tf.summary.scalar('min',tf.reduce_min(var))
        tf.summary.histogram('histogram', var)
        
def batchnorm(logits, is_test, offset, scale, iteration):
    # Get summary statistics of this batch
    mean, variance    = tf.nn.moments(logits, [0],name='moments')
    
    # We'll use an exponential moving average over the training iterations during test time
    # This is a tool to do that
    exp_moving_avg    = tf.train.ExponentialMovingAverage(0.9999, iteration)
    update_moving_avg = exp_moving_avg.apply([mean, variance])
    
    # If this is the test, we use the m,v values we obtained from the exponential moving average 
    # over mean, variance that we obtained from training. otherwise use the batch mean, variance
    mean_cond        = tf.cond(is_test, lambda: exp_moving_avg.average(mean), lambda: mean, name='mean_cond')
    variance_cond    = tf.cond(is_test, lambda: exp_moving_avg.average(variance), lambda: variance, name='variance_cond')
    
    # This applies the following normalisation: x-> scale*(x-mean(x))/(variance_epsilon+std(x)) + offset
    logits_bn = tf.nn.batch_normalization(logits, mean_cond, variance_cond, offset, scale, variance_epsilon=1e-5,name='logits_batchnormed')
    
    return logits_bn, update_moving_avg

def get_layer_complete(input_tensor,input_dim, output_dim, layer_name, is_test, prob_keep, global_step, act_func=tf.nn.relu):
    with tf.name_scope(layer_name):
        with tf.name_scope('weights'):
            weights = get_weights([input_dim, output_dim],DTYPE)
            variable_summaries(weights)
        with tf.name_scope('biases'):
            biases = get_biases([output_dim],DTYPE)
            variable_summaries(biases)
        with tf.name_scope('batchnorm'):
            offset = get_bn_offset([output_dim], DTYPE)
            scale  = get_bn_scale([output_dim], DTYPE)
        
        logits = tf.add(tf.matmul(input_tensor, weights),biases,name='logits')
        tf.summary.histogram('logits', logits)
        logits_bn, update_moving_avg = batchnorm(logits, is_test, offset, scale, global_step)
        tf.summary.histogram('logits_batchNormed', logits_bn)
        activated = act_func(logits_bn, name='activation')
        dropped_out = tf.nn.dropout(activated,prob_keep,name='dropout')
        tf.summary.histogram('activations', activated)
        return dropped_out, update_moving_avg 
    
def func_deep_learner_complete(x,m,n,h,is_test,global_step,prob_keep,act_func=tf.nn.relu,num_layers=5):
    # x is the input variable, probably a TensorFlow placeholder object
    # m is the input dimension
    # n is the output dimension
    # h is the number of hidden neurons
    # act_func is the activation function to be applied
    # is_test is a flag is use to control batch normalisation behaviour during inferene on test data
    # iteration is the iteration counter used inside the training loop; required for batch normalisation
    
    bn_moving_avg_updates = []

    with tf.variable_scope('func_learner'):
        # 0th hidden layer
        hidden_layer, update_moving_avg = get_layer_complete(x,m,h,'hidden_layer_0',is_test,prob_keep,global_step)
        bn_moving_avg_updates.append(update_moving_avg)

        # Other hidden layers
        for i in range(num_layers-1):
            hidden_layer, update_moving_avg = get_layer_complete(hidden_layer,h,h,'hidden_layer_'+str(i+1),is_test,prob_keep,global_step)
            bn_moving_avg_updates.append(update_moving_avg)

        # Output layer
        weights1= tf.get_variable(name='output_layer_weights',
                              shape=[h,n],
                              initializer=tf.random_normal_initializer(),
                              dtype=DTYPE)

    return tf.matmul(hidden_layer,weights1), bn_moving_avg_updates

def train_RBM_complete(input_size=1,output_size=1,hidden_size=1,num_layers=5,model_func=None,unknown_func=None,
                  test_x=None, test_y = None, generate_training_samples_fun=None,
                  batch_size=25, max_steps = 1000, epochs =5,
                  initial_learning_rate = 0.02, decay_rate = 1/math.e, decay_steps=1000,
                  prob_keep = 0.8):
    
    with tf.Session() as sess:
            
        with tf.name_scope('input'):
            # Placeholder variables which will be fed data at train time
            x  = tf.placeholder(DTYPE,[None,input_size],name='x_input')
            y  = tf.placeholder(DTYPE,[None,output_size],name='y_input')
        
        with tf.name_scope('control_inputs'):
            global_step = tf.Variable(0, trainable=False,name='global_step')
            epoch_ind = tf.Variable(0,trainable=False,name='epoch_ind')
            increment_epoch_ind = tf.assign_add(epoch_ind,1,name='increment_epoch_ind')
            is_test = tf.contrib.eager.Variable(False, trainable=False,name='is_test')

        # Predictions of the NN
        y_pred, bn_moving_avg_updates = func_deep_learner_complete(x,input_size,output_size,hidden_size,is_test,global_step,1,num_layers=num_layers)

        # Should add dropout!

        with tf.name_scope('mean_squared_error'):
            mse = tf.losses.mean_squared_error(y,y_pred)
        tf.summary.scalar('mean_squared_error',mse)

        with tf.name_scope('train'):
            global_step_in_epoch = global_step - epoch_ind*max_steps
            learning_rate = tf.train.exponential_decay(initial_learning_rate, global_step_in_epoch, decay_steps, decay_rate, staircase=True)
            tf.summary.scalar('learning_rate', learning_rate)
            train_step = tf.train.AdamOptimizer(learning_rate).minimize(mse, global_step = global_step)

        # Create merged summary object and file writers
        merged_summaries = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(log_dir + '/train', sess.graph)
        test_writer = tf.summary.FileWriter(log_dir + '/test', sess.graph)
        
        # Initialise variables
        sess.run(tf.global_variables_initializer())
        
        # Train the model
        start_time = time.time()
        old_time = start_time
        for j in range(epochs):
            for i in range(max_steps):
                if i % 100 ==0:
                    # Check how our model performs against the test data
                    [summary, mse_val] = sess.run([merged_summaries,mse], feed_dict={x: test_x, y: test_y, is_test: True})
                    test_writer.add_summary(summary,i + j*max_steps)
                    curr_time = time.time()
                    print('Epoch %d, Step %04d, MSE: %4.3e,  LearnRate: %4.3e, Time taken : %4.3fs' % (sess.run(epoch_ind),i, mse_val, sess.run(learning_rate),curr_time-old_time))
                    old_time = curr_time
                else:
                    # Generate new sample data and train our model
                    train_x, train_y = generate_training_samples_fun(epoch_ind, global_step)
                    summary, _ = sess.run([merged_summaries, train_step], feed_dict={x: train_x, y: train_y, is_test: False})
                    sess.run(bn_moving_avg_updates, feed_dict={x: train_x, y: train_y, is_test: False})
                    train_writer.add_summary(summary,i+ j*max_steps)
            sess.run(increment_epoch_ind)
        train_writer.close()
        test_writer.close()     
        print('\nTotal time:\t %4.3fs' % (time.time()-start_time))

# %% [markdown]
# ## Theory

# %% [markdown]
# Consider a Mach-Zehnder interferometer with interrogation time $T$ and pulse duration $\tau$. The total interferometer phase is given by:
# $$\Delta\Phi = \phi_{eff}^1 - 2\phi_{eff}^2 + \phi_{eff}^3 + \left(\mathrm{arg}(\Theta_0^1)-\mathrm{arg}(\Theta^3_0)\right)$$
# where $\phi_{eff}^i$ describes the "light phase at the atomic positions during the three Raman pulses". $\Theta_0^i$ descibes secondary phase shifts due to "different light shifts between the first and last pulse".
#
# Define the sensitivity function $g(t)$ as the effect on the total interferometer phase due to a phase jump $\delta\phi$ at time $t$. For the three-pulse Mach-Zehnder, with second pulse centered at $t=0$, $g(t)$ is given by:
# $$g(t) = \begin{cases}
# \sin(\Omega_rt), & 0<t\leq\tau \\
# 1, & \tau<t\leq T+\tau\\
# -\sin(\Omega_r(T-t)), & T+\tau<t\leq T+2\tau \\
# 0, & t>T+2\tau
# \end{cases}$$
#
# For finite Raman pulse duration (i.e. $\tau>0$), the total interferometer phase is given by:
# $$\Delta\Phi = \int_{-(T_2\tau)}^{(T+2\tau)}g(t)\frac{d\phi(t)}{dt}dt$$
#
# To perform post-correction, we separtely calculate the phase offset caused by mirror vibrations:
# $$\Phi_{vib} = k_{eff}\int_{t_1}^{t_3}g(t)v(t)dt$$
# where $v(t)=\frac{1}{k_{eff}}\frac{d\phi}{dt}$ is the mirror velocity and $k_eff$ is the effective wavevector

# %% [markdown]
# ## Data layout
# Data is organised into campaigns, each containing ~10^5 interferometer runs. Use only 4a onwards.
# Each `.h5` has three fields
# - `accelerometer`: `[N_a,2]` linearly proportional to the raw out from the accelerometer as a time series. 1st column is linux time, 2nd column is signal
# - `ai_kdown`: `[N_p,2]` total interferometer phase for kdown? configuration. 1st column is linux time, 2nd column is phase. Each row is the total interferometer phase for an Mach-Zehnder sequence with 2nd pulse centered at the given time
# - `ai_kup`: `[N_p,2]` total interferometer phase for kup? configuration. Same layout as `ai_kdown`
# - `(T,tau)`: `[2,]` the interferometer interrogation time `T` and the $\frac{\pi}{2}$ Raman pulse duration `tau`
#
# First we need to prepare the data.
#
# (1) Check timestamps of `ai_kdown`==`ai_kup`
# - THEY DON'T; they aren't even necessarily the same length. Assume that each corresponds to a completely different subsequence of `accelerometer`
# - Also, note that the distribution of delays between successive runs is weirdly distributed
#
# (2) For each ai_* associate a contiguous subsequence of `accelerometer`
#  - Ensure each subsequence is of equal length `N_s`
#  - Will being left/right aligned w.r.t. rounding of `ai_kdown` timestamp to `accelerometer` timestamps affect anything?
#  - Safest thing to do might be linearly interpolate `accelerometer` to ensure that `accelerometer` subsequence is correctly time-aligned with `ai_*`
#
# (3) Construct our inputs and outputs
#  - `x_input` = `[N_s,N_p]` array
#  - `y_output` = `[N_p,2]` concatenate 2nd column of `ai_kdown` and `ai_kup`
#
# ## Check
# Make sure we can reproduce original data (i.e. reproduce original $\Phi_{vib}$)
#  - Do we have this data?
#
# ## Modelling
# (1) *Model-free* Just use the inputs and labels as they are (assuming `N_s` is small enough)
#  - Pros: easy
#  - Cons: no ground-truth to compare against
#
# (2) *Explicit transfer function* Apply unknown function in Laplace space ($\mathcal{L}\{y(t)\}(Z) =H(Z)\mathcal{L}\{x(t)\}(Z)$ )
#  - Pros: ground-truth to compare against
#  - Cons: less easy

# %% [markdown]
# ## Use Processed campaign4a
# Matlab used to assign subsequences in `accelerometer` to each entry in `ai_kup` and `ai_kdown`.
# Subsequence length is 195. ~100000 entries for each of `ai_kup` and `ai_kdown`.

# %%
fname = './campaign4a_proc.h5'
f0 = h5py.File(fname,'r')
list(f0.keys())
list(f0.items())
dset = f0['/ai_kup']

# %%
# Let's define a function that will generate indices for batches
# accounting for the possibility that the size of the dataset
# will not be an even multiple of the batch size
def generate_batches(N,batch_size=32):
    # N is the number of elements in the dataset
    if N<batch_size:
        raise ValueError('batch_size must be smaller than N')
    perm = np.random.permutation(N);
    if np.mod(N,batch_size)!=0:
        # We need to append to perm so that is is an even multiple of batch_size
        perm2= np.random.permutation(N);
        perm = np.concatenate((perm,perm2[0:batch_size-np.mod(N,batch_size)]))
    
    n_batches = np.int(len(perm)/batch_size)
    batches = perm.reshape(batch_size,n_batches)
    
    return batches

def get_xy_by_inds(x,y,inds):
    # Get values from 2Dx, 1Dy arrays
    x0 = x[inds,:]
    y0 = np.array(list(map(y.__getitem__,inds))) # because Python treats 1D arrays differently from ND arrays
    y0 = y0.reshape([len(y0),1])
    return x0,y0
    
def generate_testtrain(x,y,test_fraction,batch_size=32):
    # Assumes x.shape = [n_samples,input_size], y.shape = [input_size,]
    if test_fraction<0 or test_fraction>1:
        raise ValueError('test_fraction must be between 0 and 1')
    
    n_samples  = x.shape[0]
    test_size  = np.int(np.round(n_samples*test_fraction))
    if test_size<1:
        raise ValueError('test_fraction is too small')
    train_size = np.int(n_samples-test_size)
    
    # Permute x,y
    perm = np.random.permutation(n_samples)
    permi= np.argsort(perm)
    x0,y0= get_xy_by_inds(x,y,permi)
                    
    train_x = x0[:train_size,:]
    train_y = y0[:train_size,:]
    
    test_x  = x0[train_size:,:]
    test_y  = y0[train_size:,:]
    
    batches = generate_batches(train_size,batch_size)
    
    return test_x,test_y,train_x,train_y,batches

# %%
def func_deep_learner_arbshape(x,m,n,h,is_test,global_step,prob_keep,act_func=tf.nn.relu):
    # x is the input variable, probably a TensorFlow placeholder object
    # m is the input dimension
    # n is the output dimension
    # h is a LIST of hidden neurons
    # act_func is the activation function to be applied
    # is_test is a flag is use to control batch normalisation behaviour during inferene on test data
    # iteration is the iteration counter used inside the training loop; required for batch normalisation
    
    num_layers = len(h)
    
    bn_moving_avg_updates = []

    with tf.variable_scope('func_learner'):
        # 0th hidden layer
        hidden_layer, update_moving_avg = get_layer_complete(x,m,h[0],'hidden_layer_0',is_test,prob_keep,global_step)
        bn_moving_avg_updates.append(update_moving_avg)

        # Other hidden layers
        for i in range(num_layers-1):
            hidden_layer, update_moving_avg = get_layer_complete(hidden_layer,h[i],h[i+1],'hidden_layer_'+str(i+1),is_test,prob_keep,global_step)
            bn_moving_avg_updates.append(update_moving_avg)

        # Output layer
        weights1= tf.get_variable(name='output_layer_weights',
                              shape=[h[-1],n],
                              initializer=tf.random_normal_initializer(),
                              dtype=DTYPE)

    return tf.matmul(hidden_layer,weights1), bn_moving_avg_updates

# %%
def train_RBM_complete_mccv(input_size=1,output_size=1,hidden_sizes=[5,5],x_data=None,y_data=None,
                  batch_size=32, epochs =5, test_fraction=0.1, test_interval=250, initial_learning_rate = 0.02,
                  epoch_learning_rate_decay = 0.5, epoch_learning_rate_interval = 10,
                  sgd_switch_epoch = 3,
                  prob_keep = 0.8,
                  fname_model_out='/tmp/model.ckpt'):
    # Using montecarlo crossvalidation
    config = tf.ConfigProto(
        device_count = {'GPU': 1}
    )
    
    with tf.Session(config=config) as sess:
        
        # Generate test data initially for convenience
        test_x,test_y,train_x_full,train_y_full,batches = generate_testtrain(x_data,y_data,test_fraction,batch_size)
        n_samples = len(y_data)
        max_steps = batches.shape[1]
            
        with tf.name_scope('input'):
            # Placeholder variables which will be fed data at train time
            x  = tf.placeholder(DTYPE,[None,input_size],name='x_input')
            y  = tf.placeholder(DTYPE,[None,output_size],name='y_input')
        
        with tf.name_scope('control_inputs'):
            global_step = tf.Variable(0, trainable=False,name='global_step')
            epoch_ind = tf.Variable(0,trainable=False,name='epoch_ind')
            increment_epoch_ind = tf.assign_add(epoch_ind,1,name='increment_epoch_ind')
            is_test = tf.contrib.eager.Variable(False, trainable=False,name='is_test')

        # Predictions of the NN
        y_pred, bn_moving_avg_updates = func_deep_learner_arbshape(x,input_size,output_size,hidden_sizes,is_test,global_step,1)

        with tf.name_scope('mean_squared_error'):
            mse = tf.losses.mean_squared_error(y,y_pred)
        tf.summary.scalar('mean_squared_error',mse)

        with tf.name_scope('train'):
            global_step_in_epoch = global_step - epoch_ind*max_steps
            #learning_rate = tf.train.exponential_decay(initial_learning_rate, global_step_in_epoch, decay_steps, decay_rate, staircase=True)
            learning_rate = tf.train.exponential_decay(initial_learning_rate, epoch_ind, epoch_learning_rate_interval, epoch_learning_rate_decay, staircase=True)
            tf.summary.scalar('learning_rate', learning_rate)
            train_step      = tf.train.AdamOptimizer(learning_rate).minimize(mse, global_step = global_step)
            train_step_sgd = tf.train.MomentumOptimizer(learning_rate,0.9).minimize(mse, global_step = global_step)

        # Create merged summary object and file writers
        merged_summaries = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(log_dir + '/train', sess.graph)
        test_writer = tf.summary.FileWriter(log_dir + '/test', sess.graph)
        
        # Add ops to save and restore all the variables.
        saver = tf.train.Saver()

        
        # Initialise variables
        sess.run(tf.global_variables_initializer())
        
        # Train the model
        start_time = time.time()
        old_time = start_time
        for j in range(epochs):
            # At each epoch, regenerate test data, train data, and batches
            test_x,test_y,train_x_full,train_y_full,batches = generate_testtrain(x_data,y_data,test_fraction,batch_size)
            n_batches = batches.shape[1]
            n_test = len(test_y)
            epoch_init_time = time.time()
                
            print('Starting Epoch %d, with %d batches' % (j,max_steps))
            for i in range(n_batches):
                if i % test_interval ==0:
                    # Check how our model performs against the test data
                    [summary, mse_val] = sess.run([merged_summaries,mse], feed_dict={x: test_x, y: test_y, is_test: True})
                    test_writer.add_summary(summary,i + j*max_steps)
                    curr_time = time.time()
                    print('\tEpoch %d, Step %04d, MSE: %4.3e,  LearnRate: %4.3e, Time taken : %4.3fs' % (sess.run(epoch_ind),i, mse_val, sess.run(learning_rate),curr_time-old_time))
                    old_time = curr_time
                else:
                    # Generate new sample data and train our model
                    train_x, train_y = get_xy_by_inds(train_x_full,train_y_full,batches[:,i])
                    if (np.mod(j,epoch_learning_rate_interval)<sgd_switch_epoch):
                        summary, _ = sess.run([merged_summaries, train_step], feed_dict={x: train_x, y: train_y, is_test: False})
                    else:
                        summary, _ = sess.run([merged_summaries, train_step_sgd], feed_dict={x: train_x, y: train_y, is_test: False})
                    sess.run(bn_moving_avg_updates, feed_dict={x: train_x, y: train_y, is_test: False})
                    train_writer.add_summary(summary,i+ j*max_steps)
            # End of epoch, calculate avg stats
            epoch_end_time = time.time()
            sess.run(increment_epoch_ind)
            avg_mrad = np.sqrt(mse_val)*1000
            print('Epoch %d time: %4.3fs, average error = %4.3fmrad' % (j,epoch_end_time-epoch_init_time,avg_mrad))
        train_writer.close()
        test_writer.close()     
        print('\nTotal time:\t %4.3fs' % (time.time()-start_time))
        
        save_path = saver.save(sess, fname_model_out)
        print("Model saved in path: %s" % save_path)

# %%
def train_RBM_complete_mccv_produceTrace(input_size=1,output_size=1,hidden_sizes=[5,5],x_data=None,y_data=None,
                  batch_size=32, epochs =5, test_fraction=0.1, test_interval=250, initial_learning_rate = 0.02,
                  epoch_learning_rate_decay = 0.5, epoch_learning_rate_interval = 10,
                  sgd_switch_epoch = 3,
                  prob_keep = 0.8,
                  fname_model_in='/tmp/model.ckpt'):
    # Using montecarlo crossvalidation
    config = tf.ConfigProto(
        device_count = {'GPU': 0}
    )
    
    with tf.Session(config=config) as sess:
        
        # Generate test data initially for convenience
        test_x,test_y,train_x_full,train_y_full,batches = generate_testtrain(x_data,y_data,test_fraction,batch_size)
        n_samples = len(x_data)
        max_steps = batches.shape[1]
            
        with tf.name_scope('input'):
            # Placeholder variables which will be fed data at train time
            x  = tf.placeholder(DTYPE,[None,input_size],name='x_input')
            y  = tf.placeholder(DTYPE,[None,output_size],name='y_input')
        
        with tf.name_scope('control_inputs'):
            global_step = tf.Variable(0, trainable=False,name='global_step')
            epoch_ind = tf.Variable(0,trainable=False,name='epoch_ind')
            increment_epoch_ind = tf.assign_add(epoch_ind,1,name='increment_epoch_ind')
            is_test = tf.contrib.eager.Variable(False, trainable=False,name='is_test')

        # Predictions of the NN
        y_pred, bn_moving_avg_updates = func_deep_learner_arbshape(x,input_size,output_size,hidden_sizes,is_test,global_step,1)

        with tf.name_scope('mean_squared_error'):
            mse = tf.losses.mean_squared_error(y,y_pred)
        tf.summary.scalar('mean_squared_error',mse)

        with tf.name_scope('train'):
            global_step_in_epoch = global_step - epoch_ind*max_steps
            #learning_rate = tf.train.exponential_decay(initial_learning_rate, global_step_in_epoch, decay_steps, decay_rate, staircase=True)
            learning_rate = tf.train.exponential_decay(initial_learning_rate, epoch_ind, epoch_learning_rate_interval, epoch_learning_rate_decay, staircase=True)
            tf.summary.scalar('learning_rate', learning_rate)
            train_step      = tf.train.AdamOptimizer(learning_rate).minimize(mse, global_step = global_step)
            train_step_sgd = tf.train.MomentumOptimizer(learning_rate,0.9).minimize(mse, global_step = global_step)

        # Create merged summary object and file writers
        merged_summaries = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(log_dir + '/train', sess.graph)
        test_writer = tf.summary.FileWriter(log_dir + '/test', sess.graph)
        
        # Restore all the variables.
        saver = tf.train.Saver()
        saver.restore(sess,  fname_model_in)
        
        # Run inference
        predicted_values = sess.run(y_pred, feed_dict={x: x_data, is_test: False})
    return predicted_values

# %%
def train_model_ai_kup(acc,phase):
    n_samples  = acc.shape[0]
    seq_length = acc.shape[1]
    
    input_size  = seq_length
    output_size = 1
    
    hidden_sizes = [256,128,64,32,16,8]
    batch_size  = 768
    
    mccv_steps   = 5000
    test_fraction= 0.1
    
    # sgd_switch_epoch now means that if mod(epoch_ind,epoch_learning_rate_interval)>sgd_switch_epoch, then SGD is used
    train_RBM_complete_mccv(input_size=input_size,output_size=output_size,hidden_sizes=hidden_sizes,initial_learning_rate=0.1,
                            x_data=acc,y_data=phase,batch_size=batch_size, epochs=mccv_steps,test_fraction=test_fraction,test_interval=50,
                            epoch_learning_rate_decay = 0.5, epoch_learning_rate_interval = 1000,sgd_switch_epoch = 500,
                            prob_keep = 0.6,fname_model_out='./model_1.ckpt')

# %%
def run_model_ai_kup(acc,phase):
    n_samples  = acc.shape[0]
    seq_length = acc.shape[1]
    
    input_size  = seq_length
    output_size = 1
    
    hidden_sizes = [256,128,64,32,16,8]
    batch_size  = 512
    
    mccv_steps   = 3000
    test_fraction= 0.1
    
    preds = train_RBM_complete_mccv_produceTrace(input_size=input_size,output_size=output_size,hidden_sizes=hidden_sizes,initial_learning_rate=0.1,
                            x_data=acc,y_data=phase,batch_size=batch_size, epochs=mccv_steps,test_fraction=test_fraction,test_interval=50,
                            epoch_learning_rate_decay = 0.5, epoch_learning_rate_interval = 500,sgd_switch_epoch = 2000,
                            prob_keep = 0.65,fname_model_in='./model_1.ckpt')
    
    return preds

# %%
ai_kup_phase = np.array(list(dset['phase']))
ai_kup_acc = np.array(list(dset['acc']))
ai_kup_timestamp = np.array(list(dset['timestamp']))

# %%
reset_tf()

# %%
preds = run_model_ai_kup(ai_kup_acc,ai_kup_phase)
# Out:
# INFO:tensorflow:Restoring parameters from ./model_0.ckpt

# %%
ai_kup_phase = ai_kup_phase.reshape([len(ai_kup_phase),1])
ai_kup_timestamp = ai_kup_timestamp.reshape([len(ai_kup_timestamp),1])

# %%
data_out = np.concatenate((ai_kup_timestamp,ai_kup_phase,preds),axis=1)

# %%
np.savetxt('61mrad.txt',data_out, delimiter=",")

# %%
h5out = h5py.File('61mrad.h5','w')
h5out.create_dataset('ai_kup_phase',data=ai_kup_phase)
h5out.create_dataset('ai_kup_timestamp',data=ai_kup_timestamp)
h5out.create_dataset('ai_kup_predictions',data=preds)
h5out.close()

# %% [markdown]
# https://arxiv.org/abs/1712.07628

# %%
train_model_ai_kup(ai_kup_acc,ai_kup_phase)
# Out:
# Starting Epoch 0, with 107 batches
# 	Epoch 0, Step 0000, MSE: 2.600e+01,  LearnRate: 1.000e-01, Time taken : 0.799s
# 	Epoch 0, Step 0050, MSE: 4.613e-02,  LearnRate: 1.000e-01, Time taken : 3.559s
# 	Epoch 0, Step 0100, MSE: 2.563e-02,  LearnRate: 1.000e-01, Time taken : 1.905s
# Epoch 0 time: 6.354s, average error = 160.108mrad
# Starting Epoch 1, with 107 batches
# 	Epoch 1, Step 0000, MSE: 2.483e-02,  LearnRate: 1.000e-01, Time taken : 0.585s
# 	Epoch 1, Step 0050, MSE: 2.478e-02,  LearnRate: 1.000e-01, Time taken : 1.884s
# 	Epoch 1, Step 0100, MSE: 2.470e-02,  LearnRate: 1.000e-01, Time taken : 1.987s
# Epoch 1 time: 4.355s, average error = 157.170mrad
# Starting Epoch 2, with 107 batches
# 	Epoch 2, Step 0000, MSE: 2.472e-02,  LearnRate: 1.000e-01, Time taken : 0.604s
# 	Epoch 2, Step 0050, MSE: 2.473e-02,  LearnRate: 1.000e-01, Time taken : 1.995s
# 	Epoch 2, Step 0100, MSE: 2.472e-02,  LearnRate: 1.000e-01, Time taken : 2.154s
# Epoch 2 time: 4.637s, average error = 157.217mrad
# Starting Epoch 3, with 107 batches
# 	Epoch 3, Step 0000, MSE: 2.487e-02,  LearnRate: 1.000e-01, Time taken : 0.638s
# 	Epoch 3, Step 0050, MSE: 2.479e-02,  LearnRate: 1.000e-01, Time taken : 2.114s
# 	Epoch 3, Step 0100, MSE: 2.494e-02,  LearnRate: 1.000e-01, Time taken : 2.011s
# Epoch 3 time: 4.665s, average error = 157.924mrad
# Starting Epoch 4, with 107 batches
# 	Epoch 4, Step 0000, MSE: 2.516e-02,  LearnRate: 1.000e-01, Time taken : 0.720s
# 	Epoch 4, Step 0050, MSE: 2.504e-02,  LearnRate: 1.000e-01, Time taken : 1.818s
# 	Epoch 4, Step 0100, MSE: 2.523e-02,  LearnRate: 1.000e-01, Time taken : 1.965s
# Epoch 4 time: 4.319s, average error = 158.843mrad
# Starting Epoch 5, with 107 batches
# 	Epoch 5, Step 0000, MSE: 2.471e-02,  LearnRate: 1.000e-01, Time taken : 0.615s
# 	Epoch 5, Step 0050, MSE: 2.470e-02,  LearnRate: 1.000e-01, Time taken : 1.914s
# 	Epoch 5, Step 0100, MSE: 2.468e-02,  LearnRate: 1.000e-01, Time taken : 1.834s
# Epoch 5 time: 4.236s, average error = 157.097mrad
# Starting Epoch 6, with 107 batches
# 	Epoch 6, Step 0000, MSE: 2.570e-02,  LearnRate: 1.000e-01, Time taken : 0.586s
# 	Epoch 6, Step 0050, MSE: 2.572e-02,  LearnRate: 1.000e-01, Time taken : 2.007s
# 	Epoch 6, Step 0100, MSE: 2.550e-02,  LearnRate: 1.000e-01, Time taken : 2.096s
# Epoch 6 time: 4.569s, average error = 159.700mrad
# Starting Epoch 7, with 107 batches
# 	Epoch 7, Step 0000, MSE: 2.590e-02,  LearnRate: 1.000e-01, Time taken : 0.536s
# 	Epoch 7, Step 0050, MSE: 2.596e-02,  LearnRate: 1.000e-01, Time taken : 2.067s
# 	Epoch 7, Step 0100, MSE: 2.597e-02,  LearnRate: 1.000e-01, Time taken : 1.948s
# Epoch 7 time: 4.512s, average error = 161.149mrad
# Starting Epoch 8, with 107 batches
# 	Epoch 8, Step 0000, MSE: 2.554e-02,  LearnRate: 1.000e-01, Time taken : 0.623s
# 	Epoch 8, Step 0050, MSE: 2.580e-02,  LearnRate: 1.000e-01, Time taken : 2.087s
# 	Epoch 8, Step 0100, MSE: 2.554e-02,  LearnRate: 1.000e-01, Time taken : 1.901s
# Epoch 8 time: 4.509s, average error = 159.822mrad
# Starting Epoch 9, with 107 batches
# 	Epoch 9, Step 0000, MSE: 2.524e-02,  LearnRate: 1.000e-01, Time taken : 0.673s
# 	Epoch 9, Step 0050, MSE: 2.519e-02,  LearnRate: 1.000e-01, Time taken : 2.155s
# 	Epoch 9, Step 0100, MSE: 2.516e-02,  LearnRate: 1.000e-01, Time taken : 1.942s
# Epoch 9 time: 4.597s, average error = 158.635mrad
# Starting Epoch 10, with 107 batches
# 	Epoch 10, Step 0000, MSE: 2.501e-02,  LearnRate: 1.000e-01, Time taken : 0.632s
# 	Epoch 10, Step 0050, MSE: 2.508e-02,  LearnRate: 1.000e-01, Time taken : 2.253s
# 	Epoch 10, Step 0100, MSE: 2.504e-02,  LearnRate: 1.000e-01, Time taken : 2.090s
# Epoch 10 time: 4.916s, average error = 158.235mrad
# Starting Epoch 11, with 107 batches
# 	Epoch 11, Step 0000, MSE: 2.511e-02,  LearnRate: 1.000e-01, Time taken : 0.681s
# 	Epoch 11, Step 0050, MSE: 2.511e-02,  LearnRate: 1.000e-01, Time taken : 1.926s
# 	Epoch 11, Step 0100, MSE: 2.518e-02,  LearnRate: 1.000e-01, Time taken : 2.024s
# Epoch 11 time: 4.425s, average error = 158.683mrad
# Starting Epoch 12, with 107 batches
# 	Epoch 12, Step 0000, MSE: 2.566e-02,  LearnRate: 1.000e-01, Time taken : 0.552s
# 	Epoch 12, Step 0050, MSE: 2.544e-02,  LearnRate: 1.000e-01, Time taken : 1.904s
# 	Epoch 12, Step 0100, MSE: 2.282e-02,  LearnRate: 1.000e-01, Time taken : 2.010s
# Epoch 12 time: 4.397s, average error = 151.071mrad
# Starting Epoch 13, with 107 batches
# 	Epoch 13, Step 0000, MSE: 2.051e-02,  LearnRate: 1.000e-01, Time taken : 0.599s
# 	Epoch 13, Step 0050, MSE: 1.009e-02,  LearnRate: 1.000e-01, Time taken : 1.866s
# 	Epoch 13, Step 0100, MSE: 9.533e-03,  LearnRate: 1.000e-01, Time taken : 1.835s
# Epoch 13 time: 4.190s, average error = 97.637mrad
# Starting Epoch 14, with 107 batches
# 	Epoch 14, Step 0000, MSE: 9.306e-03,  LearnRate: 1.000e-01, Time taken : 0.588s
# 	Epoch 14, Step 0050, MSE: 9.583e-03,  LearnRate: 1.000e-01, Time taken : 1.860s
# 	Epoch 14, Step 0100, MSE: 9.082e-03,  LearnRate: 1.000e-01, Time taken : 1.869s
# Epoch 14 time: 4.184s, average error = 95.299mrad
# Starting Epoch 15, with 107 batches
# 	Epoch 15, Step 0000, MSE: 9.029e-03,  LearnRate: 1.000e-01, Time taken : 0.499s
# 	Epoch 15, Step 0050, MSE: 9.974e-03,  LearnRate: 1.000e-01, Time taken : 1.897s
# 	Epoch 15, Step 0100, MSE: 9.851e-03,  LearnRate: 1.000e-01, Time taken : 1.956s
# Epoch 15 time: 4.323s, average error = 99.250mrad
# Starting Epoch 16, with 107 batches
# 	Epoch 16, Step 0000, MSE: 9.271e-03,  LearnRate: 1.000e-01, Time taken : 0.641s
# 	Epoch 16, Step 0050, MSE: 9.322e-03,  LearnRate: 1.000e-01, Time taken : 1.956s
# 	Epoch 16, Step 0100, MSE: 1.010e-02,  LearnRate: 1.000e-01, Time taken : 2.428s
# Epoch 16 time: 4.925s, average error = 100.520mrad
# Starting Epoch 17, with 107 batches
# 	Epoch 17, Step 0000, MSE: 9.442e-03,  LearnRate: 1.000e-01, Time taken : 0.648s
# 	Epoch 17, Step 0050, MSE: 9.322e-03,  LearnRate: 1.000e-01, Time taken : 1.931s
# 	Epoch 17, Step 0100, MSE: 9.408e-03,  LearnRate: 1.000e-01, Time taken : 1.873s
# Epoch 17 time: 4.320s, average error = 96.995mrad
# Starting Epoch 18, with 107 batches
# 	Epoch 18, Step 0000, MSE: 9.137e-03,  LearnRate: 1.000e-01, Time taken : 0.639s
# 	Epoch 18, Step 0050, MSE: 9.200e-03,  LearnRate: 1.000e-01, Time taken : 2.064s
# 	Epoch 18, Step 0100, MSE: 9.056e-03,  LearnRate: 1.000e-01, Time taken : 2.117s
# Epoch 18 time: 4.726s, average error = 95.162mrad
# Starting Epoch 19, with 107 batches
# 	Epoch 19, Step 0000, MSE: 9.148e-03,  LearnRate: 1.000e-01, Time taken : 0.577s
# 	Epoch 19, Step 0050, MSE: 9.455e-03,  LearnRate: 1.000e-01, Time taken : 2.073s
# 	Epoch 19, Step 0100, MSE: 9.269e-03,  LearnRate: 1.000e-01, Time taken : 2.015s
# Epoch 19 time: 4.554s, average error = 96.277mrad
# Starting Epoch 20, with 107 batches
# 	Epoch 20, Step 0000, MSE: 9.318e-03,  LearnRate: 1.000e-01, Time taken : 0.532s
# 	Epoch 20, Step 0050, MSE: 9.499e-03,  LearnRate: 1.000e-01, Time taken : 2.048s
# 	Epoch 20, Step 0100, MSE: 9.988e-03,  LearnRate: 1.000e-01, Time taken : 1.946s
# Epoch 20 time: 4.424s, average error = 99.942mrad
# Starting Epoch 21, with 107 batches
# 	Epoch 21, Step 0000, MSE: 9.096e-03,  LearnRate: 1.000e-01, Time taken : 0.578s
# 	Epoch 21, Step 0050, MSE: 9.217e-03,  LearnRate: 1.000e-01, Time taken : 2.066s
# 	Epoch 21, Step 0100, MSE: 8.972e-03,  LearnRate: 1.000e-01, Time taken : 1.903s
# Epoch 21 time: 4.441s, average error = 94.722mrad
# Starting Epoch 22, with 107 batches
# 	Epoch 22, Step 0000, MSE: 8.984e-03,  LearnRate: 1.000e-01, Time taken : 0.585s
# 	Epoch 22, Step 0050, MSE: 9.030e-03,  LearnRate: 1.000e-01, Time taken : 1.964s
# 	Epoch 22, Step 0100, MSE: 8.841e-03,  LearnRate: 1.000e-01, Time taken : 1.927s
# Epoch 22 time: 4.379s, average error = 94.026mrad
# Starting Epoch 23, with 107 batches
# 	Epoch 23, Step 0000, MSE: 9.180e-03,  LearnRate: 1.000e-01, Time taken : 0.637s
# 	Epoch 23, Step 0050, MSE: 9.369e-03,  LearnRate: 1.000e-01, Time taken : 2.027s
# 	Epoch 23, Step 0100, MSE: 8.934e-03,  LearnRate: 1.000e-01, Time taken : 1.940s
# Epoch 23 time: 4.468s, average error = 94.521mrad
# Starting Epoch 24, with 107 batches
# 	Epoch 24, Step 0000, MSE: 9.168e-03,  LearnRate: 1.000e-01, Time taken : 0.514s
# 	Epoch 24, Step 0050, MSE: 9.760e-03,  LearnRate: 1.000e-01, Time taken : 1.997s
# 	Epoch 24, Step 0100, MSE: 9.214e-03,  LearnRate: 1.000e-01, Time taken : 2.123s
# Epoch 24 time: 4.616s, average error = 95.989mrad
# Starting Epoch 25, with 107 batches
# 	Epoch 25, Step 0000, MSE: 9.332e-03,  LearnRate: 1.000e-01, Time taken : 0.596s
# 	Epoch 25, Step 0050, MSE: 9.123e-03,  LearnRate: 1.000e-01, Time taken : 1.910s
# 	Epoch 25, Step 0100, MSE: 1.012e-02,  LearnRate: 1.000e-01, Time taken : 1.993s
# Epoch 25 time: 4.350s, average error = 100.576mrad
# Starting Epoch 26, with 107 batches
# 	Epoch 26, Step 0000, MSE: 9.388e-03,  LearnRate: 1.000e-01, Time taken : 0.622s
# 	Epoch 26, Step 0050, MSE: 9.659e-03,  LearnRate: 1.000e-01, Time taken : 2.129s
# 	Epoch 26, Step 0100, MSE: 9.401e-03,  LearnRate: 1.000e-01, Time taken : 2.039s
# Epoch 26 time: 4.668s, average error = 96.958mrad
# Starting Epoch 27, with 107 batches
# 	Epoch 27, Step 0000, MSE: 8.826e-03,  LearnRate: 1.000e-01, Time taken : 0.567s
# 	Epoch 27, Step 0050, MSE: 8.992e-03,  LearnRate: 1.000e-01, Time taken : 1.859s
# 	Epoch 27, Step 0100, MSE: 8.959e-03,  LearnRate: 1.000e-01, Time taken : 1.891s
# Epoch 27 time: 4.220s, average error = 94.653mrad
# Starting Epoch 28, with 107 batches
# 	Epoch 28, Step 0000, MSE: 8.671e-03,  LearnRate: 1.000e-01, Time taken : 0.519s
# 	Epoch 28, Step 0050, MSE: 8.601e-03,  LearnRate: 1.000e-01, Time taken : 1.719s
# 	Epoch 28, Step 0100, MSE: 8.618e-03,  LearnRate: 1.000e-01, Time taken : 2.129s
# Epoch 28 time: 4.301s, average error = 92.833mrad
# Starting Epoch 29, with 107 batches
# 	Epoch 29, Step 0000, MSE: 8.481e-03,  LearnRate: 1.000e-01, Time taken : 0.656s
# 	Epoch 29, Step 0050, MSE: 8.767e-03,  LearnRate: 1.000e-01, Time taken : 2.224s
# 	Epoch 29, Step 0100, MSE: 8.420e-03,  LearnRate: 1.000e-01, Time taken : 2.160s
# Epoch 29 time: 4.968s, average error = 91.759mrad
# Starting Epoch 30, with 107 batches
# 	Epoch 30, Step 0000, MSE: 9.047e-03,  LearnRate: 1.000e-01, Time taken : 0.700s
# 	Epoch 30, Step 0050, MSE: 9.294e-03,  LearnRate: 1.000e-01, Time taken : 2.217s
# 	Epoch 30, Step 0100, MSE: 9.373e-03,  LearnRate: 1.000e-01, Time taken : 1.953s
# Epoch 30 time: 4.679s, average error = 96.816mrad
# Starting Epoch 31, with 107 batches
# 	Epoch 31, Step 0000, MSE: 8.989e-03,  LearnRate: 1.000e-01, Time taken : 0.532s
# 	Epoch 31, Step 0050, MSE: 8.695e-03,  LearnRate: 1.000e-01, Time taken : 2.089s
# 	Epoch 31, Step 0100, MSE: 9.391e-03,  LearnRate: 1.000e-01, Time taken : 2.094s
# Epoch 31 time: 4.699s, average error = 96.910mrad
# Starting Epoch 32, with 107 batches
# 	Epoch 32, Step 0000, MSE: 8.876e-03,  LearnRate: 1.000e-01, Time taken : 0.651s
# 	Epoch 32, Step 0050, MSE: 9.109e-03,  LearnRate: 1.000e-01, Time taken : 2.345s
# 	Epoch 32, Step 0100, MSE: 8.812e-03,  LearnRate: 1.000e-01, Time taken : 2.005s
# Epoch 32 time: 4.868s, average error = 93.870mrad
# Starting Epoch 33, with 107 batches
# 	Epoch 33, Step 0000, MSE: 8.613e-03,  LearnRate: 1.000e-01, Time taken : 0.573s
# 	Epoch 33, Step 0050, MSE: 9.111e-03,  LearnRate: 1.000e-01, Time taken : 2.138s
# 	Epoch 33, Step 0100, MSE: 9.683e-03,  LearnRate: 1.000e-01, Time taken : 1.934s
# Epoch 33 time: 4.542s, average error = 98.403mrad
# Starting Epoch 34, with 107 batches
# 	Epoch 34, Step 0000, MSE: 9.874e-03,  LearnRate: 1.000e-01, Time taken : 0.526s
# 	Epoch 34, Step 0050, MSE: 9.236e-03,  LearnRate: 1.000e-01, Time taken : 1.900s
# 	Epoch 34, Step 0100, MSE: 8.760e-03,  LearnRate: 1.000e-01, Time taken : 2.235s
# Epoch 34 time: 4.618s, average error = 93.595mrad
# Starting Epoch 35, with 107 batches
# 	Epoch 35, Step 0000, MSE: 9.228e-03,  LearnRate: 1.000e-01, Time taken : 0.595s
# 	Epoch 35, Step 0050, MSE: 9.211e-03,  LearnRate: 1.000e-01, Time taken : 2.160s
# 	Epoch 35, Step 0100, MSE: 8.896e-03,  LearnRate: 1.000e-01, Time taken : 2.061s
# Epoch 35 time: 4.724s, average error = 94.320mrad
# Starting Epoch 36, with 107 batches
# 	Epoch 36, Step 0000, MSE: 8.910e-03,  LearnRate: 1.000e-01, Time taken : 0.636s
# 	Epoch 36, Step 0050, MSE: 9.027e-03,  LearnRate: 1.000e-01, Time taken : 2.064s
# 	Epoch 36, Step 0100, MSE: 9.250e-03,  LearnRate: 1.000e-01, Time taken : 1.985s
# Epoch 36 time: 4.524s, average error = 96.177mrad
# Starting Epoch 37, with 107 batches
# 	Epoch 37, Step 0000, MSE: 9.256e-03,  LearnRate: 1.000e-01, Time taken : 0.572s
# 	Epoch 37, Step 0050, MSE: 8.826e-03,  LearnRate: 1.000e-01, Time taken : 2.212s
# 	Epoch 37, Step 0100, MSE: 8.909e-03,  LearnRate: 1.000e-01, Time taken : 2.045s
# Epoch 37 time: 4.702s, average error = 94.386mrad
# Starting Epoch 38, with 107 batches
# 	Epoch 38, Step 0000, MSE: 9.484e-03,  LearnRate: 1.000e-01, Time taken : 0.617s
# 	Epoch 38, Step 0050, MSE: 8.936e-03,  LearnRate: 1.000e-01, Time taken : 1.830s
# 	Epoch 38, Step 0100, MSE: 9.064e-03,  LearnRate: 1.000e-01, Time taken : 1.788s
# Epoch 38 time: 4.101s, average error = 95.203mrad
# Starting Epoch 39, with 107 batches
# 	Epoch 39, Step 0000, MSE: 8.991e-03,  LearnRate: 1.000e-01, Time taken : 0.568s
# 	Epoch 39, Step 0050, MSE: 8.827e-03,  LearnRate: 1.000e-01, Time taken : 1.923s
# 	Epoch 39, Step 0100, MSE: 9.398e-03,  LearnRate: 1.000e-01, Time taken : 2.014s
# Epoch 39 time: 4.441s, average error = 96.942mrad
# Starting Epoch 40, with 107 batches
# 	Epoch 40, Step 0000, MSE: 9.242e-03,  LearnRate: 1.000e-01, Time taken : 0.608s
# 	Epoch 40, Step 0050, MSE: 9.300e-03,  LearnRate: 1.000e-01, Time taken : 2.001s
# 	Epoch 40, Step 0100, MSE: 1.196e-02,  LearnRate: 1.000e-01, Time taken : 1.885s
# Epoch 40 time: 4.393s, average error = 109.347mrad
# Starting Epoch 41, with 107 batches
# 	Epoch 41, Step 0000, MSE: 9.437e-03,  LearnRate: 1.000e-01, Time taken : 0.649s
# 	Epoch 41, Step 0050, MSE: 8.717e-03,  LearnRate: 1.000e-01, Time taken : 1.963s
# 	Epoch 41, Step 0100, MSE: 8.647e-03,  LearnRate: 1.000e-01, Time taken : 2.073s
# Epoch 41 time: 4.519s, average error = 92.988mrad
# Starting Epoch 42, with 107 batches
# 	Epoch 42, Step 0000, MSE: 8.681e-03,  LearnRate: 1.000e-01, Time taken : 0.612s
# 	Epoch 42, Step 0050, MSE: 8.914e-03,  LearnRate: 1.000e-01, Time taken : 2.213s
# 	Epoch 42, Step 0100, MSE: 8.719e-03,  LearnRate: 1.000e-01, Time taken : 1.936s
# Epoch 42 time: 4.653s, average error = 93.377mrad
# Starting Epoch 43, with 107 batches
# 	Epoch 43, Step 0000, MSE: 8.463e-03,  LearnRate: 1.000e-01, Time taken : 0.614s
# 	Epoch 43, Step 0050, MSE: 8.494e-03,  LearnRate: 1.000e-01, Time taken : 1.976s
# 	Epoch 43, Step 0100, MSE: 9.030e-03,  LearnRate: 1.000e-01, Time taken : 1.929s
# Epoch 43 time: 4.369s, average error = 95.028mrad
# Starting Epoch 44, with 107 batches
# 	Epoch 44, Step 0000, MSE: 1.004e-02,  LearnRate: 1.000e-01, Time taken : 0.541s
# 	Epoch 44, Step 0050, MSE: 8.977e-03,  LearnRate: 1.000e-01, Time taken : 2.158s
# 	Epoch 44, Step 0100, MSE: 9.545e-03,  LearnRate: 1.000e-01, Time taken : 2.067s
# Epoch 44 time: 4.725s, average error = 97.701mrad
# Starting Epoch 45, with 107 batches
# 	Epoch 45, Step 0000, MSE: 8.944e-03,  LearnRate: 1.000e-01, Time taken : 0.640s
# 	Epoch 45, Step 0050, MSE: 8.902e-03,  LearnRate: 1.000e-01, Time taken : 2.059s
# 	Epoch 45, Step 0100, MSE: 8.840e-03,  LearnRate: 1.000e-01, Time taken : 2.098s
# Epoch 45 time: 4.740s, average error = 94.019mrad
# Starting Epoch 46, with 107 batches
# 	Epoch 46, Step 0000, MSE: 8.759e-03,  LearnRate: 1.000e-01, Time taken : 0.651s
# 	Epoch 46, Step 0050, MSE: 8.875e-03,  LearnRate: 1.000e-01, Time taken : 2.014s
# 	Epoch 46, Step 0100, MSE: 9.472e-03,  LearnRate: 1.000e-01, Time taken : 1.992s
# Epoch 46 time: 4.480s, average error = 97.324mrad
# Starting Epoch 47, with 107 batches
# 	Epoch 47, Step 0000, MSE: 1.045e-02,  LearnRate: 1.000e-01, Time taken : 0.513s
# 	Epoch 47, Step 0050, MSE: 8.708e-03,  LearnRate: 1.000e-01, Time taken : 1.814s
# 	Epoch 47, Step 0100, MSE: 9.377e-03,  LearnRate: 1.000e-01, Time taken : 1.941s
# Epoch 47 time: 4.217s, average error = 96.833mrad
# Starting Epoch 48, with 107 batches
# 	Epoch 48, Step 0000, MSE: 9.021e-03,  LearnRate: 1.000e-01, Time taken : 0.603s
# 	Epoch 48, Step 0050, MSE: 8.984e-03,  LearnRate: 1.000e-01, Time taken : 1.811s
# 	Epoch 48, Step 0100, MSE: 9.160e-03,  LearnRate: 1.000e-01, Time taken : 1.963s
# Epoch 48 time: 4.268s, average error = 95.707mrad
# Starting Epoch 49, with 107 batches
# 	Epoch 49, Step 0000, MSE: 8.613e-03,  LearnRate: 1.000e-01, Time taken : 0.547s
# 	Epoch 49, Step 0050, MSE: 9.126e-03,  LearnRate: 1.000e-01, Time taken : 2.026s
# 	Epoch 49, Step 0100, MSE: 8.850e-03,  LearnRate: 1.000e-01, Time taken : 1.828s
# Epoch 49 time: 4.335s, average error = 94.072mrad
# Starting Epoch 50, with 107 batches
# 	Epoch 50, Step 0000, MSE: 9.372e-03,  LearnRate: 1.000e-01, Time taken : 0.608s
# 	Epoch 50, Step 0050, MSE: 8.871e-03,  LearnRate: 1.000e-01, Time taken : 1.979s
# 	Epoch 50, Step 0100, MSE: 8.642e-03,  LearnRate: 1.000e-01, Time taken : 2.174s
# Epoch 50 time: 4.658s, average error = 92.963mrad
# Starting Epoch 51, with 107 batches
# 	Epoch 51, Step 0000, MSE: 8.257e-03,  LearnRate: 1.000e-01, Time taken : 0.603s
# 	Epoch 51, Step 0050, MSE: 8.993e-03,  LearnRate: 1.000e-01, Time taken : 2.136s
# 	Epoch 51, Step 0100, MSE: 9.426e-03,  LearnRate: 1.000e-01, Time taken : 1.792s
# Epoch 51 time: 4.405s, average error = 97.088mrad
# Starting Epoch 52, with 107 batches
# 	Epoch 52, Step 0000, MSE: 8.995e-03,  LearnRate: 1.000e-01, Time taken : 0.533s
# 	Epoch 52, Step 0050, MSE: 1.046e-02,  LearnRate: 1.000e-01, Time taken : 2.048s
# 	Epoch 52, Step 0100, MSE: 8.623e-03,  LearnRate: 1.000e-01, Time taken : 1.901s
# Epoch 52 time: 4.377s, average error = 92.859mrad
# Starting Epoch 53, with 107 batches
# 	Epoch 53, Step 0000, MSE: 8.686e-03,  LearnRate: 1.000e-01, Time taken : 0.561s
# 	Epoch 53, Step 0050, MSE: 8.308e-03,  LearnRate: 1.000e-01, Time taken : 1.806s
# 	Epoch 53, Step 0100, MSE: 8.543e-03,  LearnRate: 1.000e-01, Time taken : 1.884s
# Epoch 53 time: 4.113s, average error = 92.427mrad
# Starting Epoch 54, with 107 batches
# 	Epoch 54, Step 0000, MSE: 9.068e-03,  LearnRate: 1.000e-01, Time taken : 0.481s
# 	Epoch 54, Step 0050, MSE: 8.710e-03,  LearnRate: 1.000e-01, Time taken : 1.838s
# 	Epoch 54, Step 0100, MSE: 8.805e-03,  LearnRate: 1.000e-01, Time taken : 1.874s
# Epoch 54 time: 4.135s, average error = 93.836mrad
# Starting Epoch 55, with 107 batches
# 	Epoch 55, Step 0000, MSE: 9.377e-03,  LearnRate: 1.000e-01, Time taken : 0.605s
# 	Epoch 55, Step 0050, MSE: 9.342e-03,  LearnRate: 1.000e-01, Time taken : 2.083s
# 	Epoch 55, Step 0100, MSE: 9.001e-03,  LearnRate: 1.000e-01, Time taken : 1.998s
# Epoch 55 time: 4.613s, average error = 94.874mrad
# Starting Epoch 56, with 107 batches
# 	Epoch 56, Step 0000, MSE: 8.843e-03,  LearnRate: 1.000e-01, Time taken : 0.665s
# 	Epoch 56, Step 0050, MSE: 9.530e-03,  LearnRate: 1.000e-01, Time taken : 1.997s
# 	Epoch 56, Step 0100, MSE: 8.851e-03,  LearnRate: 1.000e-01, Time taken : 2.136s
# Epoch 56 time: 4.698s, average error = 94.081mrad
# Starting Epoch 57, with 107 batches
# 	Epoch 57, Step 0000, MSE: 9.097e-03,  LearnRate: 1.000e-01, Time taken : 0.668s
# 	Epoch 57, Step 0050, MSE: 9.068e-03,  LearnRate: 1.000e-01, Time taken : 2.065s
# 	Epoch 57, Step 0100, MSE: 9.144e-03,  LearnRate: 1.000e-01, Time taken : 1.983s
# Epoch 57 time: 4.549s, average error = 95.625mrad
# Starting Epoch 58, with 107 batches
# 	Epoch 58, Step 0000, MSE: 8.519e-03,  LearnRate: 1.000e-01, Time taken : 0.592s
# 	Epoch 58, Step 0050, MSE: 8.617e-03,  LearnRate: 1.000e-01, Time taken : 2.220s
# 	Epoch 58, Step 0100, MSE: 8.696e-03,  LearnRate: 1.000e-01, Time taken : 2.098s
# Epoch 58 time: 4.806s, average error = 93.253mrad
# Starting Epoch 59, with 107 batches
# 	Epoch 59, Step 0000, MSE: 8.850e-03,  LearnRate: 1.000e-01, Time taken : 0.620s
# 	Epoch 59, Step 0050, MSE: 9.051e-03,  LearnRate: 1.000e-01, Time taken : 2.030s
# 	Epoch 59, Step 0100, MSE: 8.764e-03,  LearnRate: 1.000e-01, Time taken : 1.894s
# Epoch 59 time: 4.423s, average error = 93.615mrad
# Starting Epoch 60, with 107 batches
# 	Epoch 60, Step 0000, MSE: 8.692e-03,  LearnRate: 1.000e-01, Time taken : 0.572s
# 	Epoch 60, Step 0050, MSE: 8.645e-03,  LearnRate: 1.000e-01, Time taken : 1.842s
# 	Epoch 60, Step 0100, MSE: 9.160e-03,  LearnRate: 1.000e-01, Time taken : 2.073s
# Epoch 60 time: 4.429s, average error = 95.709mrad
# Starting Epoch 61, with 107 batches
# 	Epoch 61, Step 0000, MSE: 9.336e-03,  LearnRate: 1.000e-01, Time taken : 0.604s
# 	Epoch 61, Step 0050, MSE: 8.827e-03,  LearnRate: 1.000e-01, Time taken : 2.026s
# 	Epoch 61, Step 0100, MSE: 8.747e-03,  LearnRate: 1.000e-01, Time taken : 1.893s
# Epoch 61 time: 4.375s, average error = 93.523mrad
# Starting Epoch 62, with 107 batches
# 	Epoch 62, Step 0000, MSE: 9.298e-03,  LearnRate: 1.000e-01, Time taken : 0.526s
# 	Epoch 62, Step 0050, MSE: 8.410e-03,  LearnRate: 1.000e-01, Time taken : 2.047s
# 	Epoch 62, Step 0100, MSE: 8.571e-03,  LearnRate: 1.000e-01, Time taken : 2.038s
# Epoch 62 time: 4.498s, average error = 92.582mrad
# Starting Epoch 63, with 107 batches
# 	Epoch 63, Step 0000, MSE: 9.032e-03,  LearnRate: 1.000e-01, Time taken : 0.560s
# 	Epoch 63, Step 0050, MSE: 9.080e-03,  LearnRate: 1.000e-01, Time taken : 2.174s
# 	Epoch 63, Step 0100, MSE: 8.865e-03,  LearnRate: 1.000e-01, Time taken : 2.220s
# Epoch 63 time: 4.904s, average error = 94.153mrad
# Starting Epoch 64, with 107 batches
# 	Epoch 64, Step 0000, MSE: 8.703e-03,  LearnRate: 1.000e-01, Time taken : 0.584s
# 	Epoch 64, Step 0050, MSE: 8.655e-03,  LearnRate: 1.000e-01, Time taken : 1.961s
# 	Epoch 64, Step 0100, MSE: 8.604e-03,  LearnRate: 1.000e-01, Time taken : 2.193s
# Epoch 64 time: 4.627s, average error = 92.758mrad
# Starting Epoch 65, with 107 batches
# 	Epoch 65, Step 0000, MSE: 8.379e-03,  LearnRate: 1.000e-01, Time taken : 0.590s
# 	Epoch 65, Step 0050, MSE: 8.409e-03,  LearnRate: 1.000e-01, Time taken : 2.223s
# 	Epoch 65, Step 0100, MSE: 8.549e-03,  LearnRate: 1.000e-01, Time taken : 2.162s
# Epoch 65 time: 4.902s, average error = 92.458mrad
# Starting Epoch 66, with 107 batches
# 	Epoch 66, Step 0000, MSE: 8.555e-03,  LearnRate: 1.000e-01, Time taken : 0.661s
# 	Epoch 66, Step 0050, MSE: 8.821e-03,  LearnRate: 1.000e-01, Time taken : 2.039s
# 	Epoch 66, Step 0100, MSE: 8.964e-03,  LearnRate: 1.000e-01, Time taken : 1.892s
# Epoch 66 time: 4.403s, average error = 94.678mrad
# Starting Epoch 67, with 107 batches
# 	Epoch 67, Step 0000, MSE: 8.496e-03,  LearnRate: 1.000e-01, Time taken : 0.514s
# 	Epoch 67, Step 0050, MSE: 8.588e-03,  LearnRate: 1.000e-01, Time taken : 1.977s
# 	Epoch 67, Step 0100, MSE: 8.722e-03,  LearnRate: 1.000e-01, Time taken : 2.063s
# Epoch 67 time: 4.566s, average error = 93.393mrad
# Starting Epoch 68, with 107 batches
# 	Epoch 68, Step 0000, MSE: 8.788e-03,  LearnRate: 1.000e-01, Time taken : 0.748s
# 	Epoch 68, Step 0050, MSE: 8.665e-03,  LearnRate: 1.000e-01, Time taken : 2.228s
# 	Epoch 68, Step 0100, MSE: 8.700e-03,  LearnRate: 1.000e-01, Time taken : 1.909s
# Epoch 68 time: 4.675s, average error = 93.272mrad
# Starting Epoch 69, with 107 batches
# 	Epoch 69, Step 0000, MSE: 8.399e-03,  LearnRate: 1.000e-01, Time taken : 0.640s
# 	Epoch 69, Step 0050, MSE: 8.534e-03,  LearnRate: 1.000e-01, Time taken : 2.293s
# 	Epoch 69, Step 0100, MSE: 8.574e-03,  LearnRate: 1.000e-01, Time taken : 1.845s
# Epoch 69 time: 4.642s, average error = 92.593mrad
# Starting Epoch 70, with 107 batches
# 	Epoch 70, Step 0000, MSE: 8.703e-03,  LearnRate: 1.000e-01, Time taken : 0.575s
# 	Epoch 70, Step 0050, MSE: 8.583e-03,  LearnRate: 1.000e-01, Time taken : 1.967s
# 	Epoch 70, Step 0100, MSE: 8.636e-03,  LearnRate: 1.000e-01, Time taken : 1.958s
# Epoch 70 time: 4.387s, average error = 92.933mrad
# Starting Epoch 71, with 107 batches
# 	Epoch 71, Step 0000, MSE: 8.208e-03,  LearnRate: 1.000e-01, Time taken : 0.543s
# 	Epoch 71, Step 0050, MSE: 8.300e-03,  LearnRate: 1.000e-01, Time taken : 1.923s
# 	Epoch 71, Step 0100, MSE: 8.457e-03,  LearnRate: 1.000e-01, Time taken : 1.882s
# Epoch 71 time: 4.308s, average error = 91.961mrad
# Starting Epoch 72, with 107 batches
# 	Epoch 72, Step 0000, MSE: 8.140e-03,  LearnRate: 1.000e-01, Time taken : 0.626s
# 	Epoch 72, Step 0050, MSE: 8.182e-03,  LearnRate: 1.000e-01, Time taken : 2.038s
# 	Epoch 72, Step 0100, MSE: 8.354e-03,  LearnRate: 1.000e-01, Time taken : 2.021s
# Epoch 72 time: 4.561s, average error = 91.399mrad
# Starting Epoch 73, with 107 batches
# 	Epoch 73, Step 0000, MSE: 8.951e-03,  LearnRate: 1.000e-01, Time taken : 0.601s
# 	Epoch 73, Step 0050, MSE: 8.739e-03,  LearnRate: 1.000e-01, Time taken : 1.903s
# 	Epoch 73, Step 0100, MSE: 8.863e-03,  LearnRate: 1.000e-01, Time taken : 1.953s
# Epoch 73 time: 4.336s, average error = 94.144mrad
# Starting Epoch 74, with 107 batches
# 	Epoch 74, Step 0000, MSE: 8.854e-03,  LearnRate: 1.000e-01, Time taken : 0.617s
# 	Epoch 74, Step 0050, MSE: 8.714e-03,  LearnRate: 1.000e-01, Time taken : 2.017s
# 	Epoch 74, Step 0100, MSE: 8.911e-03,  LearnRate: 1.000e-01, Time taken : 1.933s
# Epoch 74 time: 4.439s, average error = 94.399mrad
# Starting Epoch 75, with 107 batches
# 	Epoch 75, Step 0000, MSE: 8.669e-03,  LearnRate: 1.000e-01, Time taken : 0.570s
# 	Epoch 75, Step 0050, MSE: 8.327e-03,  LearnRate: 1.000e-01, Time taken : 2.032s
# 	Epoch 75, Step 0100, MSE: 8.554e-03,  LearnRate: 1.000e-01, Time taken : 2.168s
# Epoch 75 time: 4.706s, average error = 92.488mrad
# Starting Epoch 76, with 107 batches
# 	Epoch 76, Step 0000, MSE: 8.866e-03,  LearnRate: 1.000e-01, Time taken : 0.697s
# 	Epoch 76, Step 0050, MSE: 8.848e-03,  LearnRate: 1.000e-01, Time taken : 2.267s
# 	Epoch 76, Step 0100, MSE: 8.747e-03,  LearnRate: 1.000e-01, Time taken : 2.124s
# Epoch 76 time: 4.921s, average error = 93.527mrad
# Starting Epoch 77, with 107 batches
# 	Epoch 77, Step 0000, MSE: 8.474e-03,  LearnRate: 1.000e-01, Time taken : 0.561s
# 	Epoch 77, Step 0050, MSE: 8.498e-03,  LearnRate: 1.000e-01, Time taken : 2.042s
# 	Epoch 77, Step 0100, MSE: 8.506e-03,  LearnRate: 1.000e-01, Time taken : 2.195s
# Epoch 77 time: 4.704s, average error = 92.228mrad
# Starting Epoch 78, with 107 batches
# 	Epoch 78, Step 0000, MSE: 8.103e-03,  LearnRate: 1.000e-01, Time taken : 0.584s
# 	Epoch 78, Step 0050, MSE: 8.486e-03,  LearnRate: 1.000e-01, Time taken : 2.266s
# 	Epoch 78, Step 0100, MSE: 8.365e-03,  LearnRate: 1.000e-01, Time taken : 1.991s
# Epoch 78 time: 4.796s, average error = 91.459mrad
# Starting Epoch 79, with 107 batches
# 	Epoch 79, Step 0000, MSE: 8.733e-03,  LearnRate: 1.000e-01, Time taken : 0.649s
# 	Epoch 79, Step 0050, MSE: 8.768e-03,  LearnRate: 1.000e-01, Time taken : 2.024s
# 	Epoch 79, Step 0100, MSE: 8.809e-03,  LearnRate: 1.000e-01, Time taken : 1.963s
# Epoch 79 time: 4.476s, average error = 93.858mrad
# Starting Epoch 80, with 107 batches
# 	Epoch 80, Step 0000, MSE: 8.448e-03,  LearnRate: 1.000e-01, Time taken : 0.584s
# 	Epoch 80, Step 0050, MSE: 8.740e-03,  LearnRate: 1.000e-01, Time taken : 2.022s
# 	Epoch 80, Step 0100, MSE: 8.691e-03,  LearnRate: 1.000e-01, Time taken : 1.849s
# Epoch 80 time: 4.351s, average error = 93.228mrad
# Starting Epoch 81, with 107 batches
# 	Epoch 81, Step 0000, MSE: 8.206e-03,  LearnRate: 1.000e-01, Time taken : 0.507s
# 	Epoch 81, Step 0050, MSE: 8.340e-03,  LearnRate: 1.000e-01, Time taken : 1.945s
# 	Epoch 81, Step 0100, MSE: 8.351e-03,  LearnRate: 1.000e-01, Time taken : 2.081s
# Epoch 81 time: 4.543s, average error = 91.385mrad
# Starting Epoch 82, with 107 batches
# 	Epoch 82, Step 0000, MSE: 8.305e-03,  LearnRate: 1.000e-01, Time taken : 0.723s
# 	Epoch 82, Step 0050, MSE: 8.611e-03,  LearnRate: 1.000e-01, Time taken : 2.130s
# 	Epoch 82, Step 0100, MSE: 8.440e-03,  LearnRate: 1.000e-01, Time taken : 2.010s
# Epoch 82 time: 4.658s, average error = 91.870mrad
# Starting Epoch 83, with 107 batches
# 	Epoch 83, Step 0000, MSE: 8.599e-03,  LearnRate: 1.000e-01, Time taken : 0.553s
# 	Epoch 83, Step 0050, MSE: 8.807e-03,  LearnRate: 1.000e-01, Time taken : 2.095s
# 	Epoch 83, Step 0100, MSE: 8.602e-03,  LearnRate: 1.000e-01, Time taken : 1.916s
# Epoch 83 time: 4.523s, average error = 92.745mrad
# Starting Epoch 84, with 107 batches
# 	Epoch 84, Step 0000, MSE: 8.401e-03,  LearnRate: 1.000e-01, Time taken : 0.635s
# 	Epoch 84, Step 0050, MSE: 8.474e-03,  LearnRate: 1.000e-01, Time taken : 2.189s
# 	Epoch 84, Step 0100, MSE: 8.367e-03,  LearnRate: 1.000e-01, Time taken : 2.227s
# Epoch 84 time: 4.912s, average error = 91.470mrad
# Starting Epoch 85, with 107 batches
# 	Epoch 85, Step 0000, MSE: 8.244e-03,  LearnRate: 1.000e-01, Time taken : 0.588s
# 	Epoch 85, Step 0050, MSE: 8.066e-03,  LearnRate: 1.000e-01, Time taken : 1.894s
# 	Epoch 85, Step 0100, MSE: 8.226e-03,  LearnRate: 1.000e-01, Time taken : 2.073s
# Epoch 85 time: 4.413s, average error = 90.696mrad
# Starting Epoch 86, with 107 batches
# 	Epoch 86, Step 0000, MSE: 8.307e-03,  LearnRate: 1.000e-01, Time taken : 0.496s
# 	Epoch 86, Step 0050, MSE: 8.590e-03,  LearnRate: 1.000e-01, Time taken : 1.935s
# 	Epoch 86, Step 0100, MSE: 8.595e-03,  LearnRate: 1.000e-01, Time taken : 2.069s
# Epoch 86 time: 4.443s, average error = 92.711mrad
# Starting Epoch 87, with 107 batches
# 	Epoch 87, Step 0000, MSE: 8.413e-03,  LearnRate: 1.000e-01, Time taken : 0.593s
# 	Epoch 87, Step 0050, MSE: 8.609e-03,  LearnRate: 1.000e-01, Time taken : 2.051s
# 	Epoch 87, Step 0100, MSE: 8.519e-03,  LearnRate: 1.000e-01, Time taken : 2.059s
# Epoch 87 time: 4.578s, average error = 92.298mrad
# Starting Epoch 88, with 107 batches
# 	Epoch 88, Step 0000, MSE: 8.350e-03,  LearnRate: 1.000e-01, Time taken : 0.561s
# 	Epoch 88, Step 0050, MSE: 8.683e-03,  LearnRate: 1.000e-01, Time taken : 1.882s
# 	Epoch 88, Step 0100, MSE: 8.664e-03,  LearnRate: 1.000e-01, Time taken : 2.151s
# Epoch 88 time: 4.533s, average error = 93.080mrad
# Starting Epoch 89, with 107 batches
# 	Epoch 89, Step 0000, MSE: 8.181e-03,  LearnRate: 1.000e-01, Time taken : 0.672s
# 	Epoch 89, Step 0050, MSE: 8.279e-03,  LearnRate: 1.000e-01, Time taken : 2.147s
# 	Epoch 89, Step 0100, MSE: 8.501e-03,  LearnRate: 1.000e-01, Time taken : 2.156s
# Epoch 89 time: 4.834s, average error = 92.198mrad
# Starting Epoch 90, with 107 batches
# 	Epoch 90, Step 0000, MSE: 7.887e-03,  LearnRate: 1.000e-01, Time taken : 0.609s
# 	Epoch 90, Step 0050, MSE: 8.061e-03,  LearnRate: 1.000e-01, Time taken : 1.971s
# 	Epoch 90, Step 0100, MSE: 8.023e-03,  LearnRate: 1.000e-01, Time taken : 2.099s
# Epoch 90 time: 4.541s, average error = 89.571mrad
# Starting Epoch 91, with 107 batches
# 	Epoch 91, Step 0000, MSE: 8.352e-03,  LearnRate: 1.000e-01, Time taken : 0.626s
# 	Epoch 91, Step 0050, MSE: 8.413e-03,  LearnRate: 1.000e-01, Time taken : 2.103s
# 	Epoch 91, Step 0100, MSE: 8.471e-03,  LearnRate: 1.000e-01, Time taken : 2.004s
# Epoch 91 time: 4.598s, average error = 92.036mrad
# Starting Epoch 92, with 107 batches
# 	Epoch 92, Step 0000, MSE: 8.099e-03,  LearnRate: 1.000e-01, Time taken : 0.490s
# 	Epoch 92, Step 0050, MSE: 8.309e-03,  LearnRate: 1.000e-01, Time taken : 1.816s
# 	Epoch 92, Step 0100, MSE: 8.272e-03,  LearnRate: 1.000e-01, Time taken : 1.864s
# Epoch 92 time: 4.114s, average error = 90.950mrad
# Starting Epoch 93, with 107 batches
# 	Epoch 93, Step 0000, MSE: 8.477e-03,  LearnRate: 1.000e-01, Time taken : 0.561s
# 	Epoch 93, Step 0050, MSE: 8.606e-03,  LearnRate: 1.000e-01, Time taken : 1.823s
# 	Epoch 93, Step 0100, MSE: 8.433e-03,  LearnRate: 1.000e-01, Time taken : 1.899s
# Epoch 93 time: 4.163s, average error = 91.831mrad
# Starting Epoch 94, with 107 batches
# 	Epoch 94, Step 0000, MSE: 8.454e-03,  LearnRate: 1.000e-01, Time taken : 0.498s
# 	Epoch 94, Step 0050, MSE: 8.456e-03,  LearnRate: 1.000e-01, Time taken : 2.017s
# 	Epoch 94, Step 0100, MSE: 8.617e-03,  LearnRate: 1.000e-01, Time taken : 2.311s
# Epoch 94 time: 4.804s, average error = 92.828mrad
# Starting Epoch 95, with 107 batches
# 	Epoch 95, Step 0000, MSE: 8.164e-03,  LearnRate: 1.000e-01, Time taken : 0.602s
# 	Epoch 95, Step 0050, MSE: 8.596e-03,  LearnRate: 1.000e-01, Time taken : 1.966s
# 	Epoch 95, Step 0100, MSE: 8.460e-03,  LearnRate: 1.000e-01, Time taken : 2.092s
# Epoch 95 time: 4.571s, average error = 91.980mrad
# Starting Epoch 96, with 107 batches
# 	Epoch 96, Step 0000, MSE: 7.962e-03,  LearnRate: 1.000e-01, Time taken : 0.565s
# 	Epoch 96, Step 0050, MSE: 7.983e-03,  LearnRate: 1.000e-01, Time taken : 1.954s
# 	Epoch 96, Step 0100, MSE: 8.166e-03,  LearnRate: 1.000e-01, Time taken : 1.988s
# Epoch 96 time: 4.416s, average error = 90.365mrad
# Starting Epoch 97, with 107 batches
# 	Epoch 97, Step 0000, MSE: 8.607e-03,  LearnRate: 1.000e-01, Time taken : 0.552s
# 	Epoch 97, Step 0050, MSE: 8.530e-03,  LearnRate: 1.000e-01, Time taken : 1.988s
# 	Epoch 97, Step 0100, MSE: 8.702e-03,  LearnRate: 1.000e-01, Time taken : 1.847s
# Epoch 97 time: 4.274s, average error = 93.282mrad
# Starting Epoch 98, with 107 batches
# 	Epoch 98, Step 0000, MSE: 8.692e-03,  LearnRate: 1.000e-01, Time taken : 0.576s
# 	Epoch 98, Step 0050, MSE: 8.352e-03,  LearnRate: 1.000e-01, Time taken : 2.018s
# 	Epoch 98, Step 0100, MSE: 8.515e-03,  LearnRate: 1.000e-01, Time taken : 2.005s
# Epoch 98 time: 4.499s, average error = 92.275mrad
# Starting Epoch 99, with 107 batches
# 	Epoch 99, Step 0000, MSE: 8.569e-03,  LearnRate: 1.000e-01, Time taken : 0.585s
# 	Epoch 99, Step 0050, MSE: 8.482e-03,  LearnRate: 1.000e-01, Time taken : 1.877s
# 	Epoch 99, Step 0100, MSE: 8.449e-03,  LearnRate: 1.000e-01, Time taken : 1.957s
# Epoch 99 time: 4.302s, average error = 91.920mrad
# Starting Epoch 100, with 107 batches
# 	Epoch 100, Step 0000, MSE: 8.612e-03,  LearnRate: 1.000e-01, Time taken : 0.589s
# 	Epoch 100, Step 0050, MSE: 8.105e-03,  LearnRate: 1.000e-01, Time taken : 2.059s
# 	Epoch 100, Step 0100, MSE: 8.255e-03,  LearnRate: 1.000e-01, Time taken : 1.890s
# Epoch 100 time: 4.424s, average error = 90.855mrad
# Starting Epoch 101, with 107 batches
# 	Epoch 101, Step 0000, MSE: 8.451e-03,  LearnRate: 1.000e-01, Time taken : 0.600s
# 	Epoch 101, Step 0050, MSE: 8.886e-03,  LearnRate: 1.000e-01, Time taken : 1.960s
# 	Epoch 101, Step 0100, MSE: 8.726e-03,  LearnRate: 1.000e-01, Time taken : 1.984s
# Epoch 101 time: 4.454s, average error = 93.411mrad
# Starting Epoch 102, with 107 batches
# 	Epoch 102, Step 0000, MSE: 7.925e-03,  LearnRate: 1.000e-01, Time taken : 0.629s
# 	Epoch 102, Step 0050, MSE: 8.090e-03,  LearnRate: 1.000e-01, Time taken : 1.799s
# 	Epoch 102, Step 0100, MSE: 7.935e-03,  LearnRate: 1.000e-01, Time taken : 1.969s
# Epoch 102 time: 4.254s, average error = 89.079mrad
# Starting Epoch 103, with 107 batches
# 	Epoch 103, Step 0000, MSE: 8.040e-03,  LearnRate: 1.000e-01, Time taken : 0.589s
# 	Epoch 103, Step 0050, MSE: 8.346e-03,  LearnRate: 1.000e-01, Time taken : 2.075s
# 	Epoch 103, Step 0100, MSE: 8.780e-03,  LearnRate: 1.000e-01, Time taken : 2.106s
# Epoch 103 time: 4.649s, average error = 93.702mrad
# Starting Epoch 104, with 107 batches
# 	Epoch 104, Step 0000, MSE: 7.900e-03,  LearnRate: 1.000e-01, Time taken : 0.586s
# 	Epoch 104, Step 0050, MSE: 8.052e-03,  LearnRate: 1.000e-01, Time taken : 1.941s
# 	Epoch 104, Step 0100, MSE: 8.272e-03,  LearnRate: 1.000e-01, Time taken : 2.311s
# Epoch 104 time: 4.805s, average error = 90.951mrad
# Starting Epoch 105, with 107 batches
# 	Epoch 105, Step 0000, MSE: 8.208e-03,  LearnRate: 1.000e-01, Time taken : 0.670s
# 	Epoch 105, Step 0050, MSE: 8.212e-03,  LearnRate: 1.000e-01, Time taken : 2.023s
# 	Epoch 105, Step 0100, MSE: 8.517e-03,  LearnRate: 1.000e-01, Time taken : 1.831s
# Epoch 105 time: 4.418s, average error = 92.290mrad
# Starting Epoch 106, with 107 batches
# 	Epoch 106, Step 0000, MSE: 8.218e-03,  LearnRate: 1.000e-01, Time taken : 0.621s
# 	Epoch 106, Step 0050, MSE: 8.391e-03,  LearnRate: 1.000e-01, Time taken : 1.928s
# 	Epoch 106, Step 0100, MSE: 8.701e-03,  LearnRate: 1.000e-01, Time taken : 1.833s
# Epoch 106 time: 4.232s, average error = 93.280mrad
# Starting Epoch 107, with 107 batches
# 	Epoch 107, Step 0000, MSE: 8.282e-03,  LearnRate: 1.000e-01, Time taken : 0.614s
# 	Epoch 107, Step 0050, MSE: 8.268e-03,  LearnRate: 1.000e-01, Time taken : 1.996s
# 	Epoch 107, Step 0100, MSE: 8.311e-03,  LearnRate: 1.000e-01, Time taken : 2.282s
# Epoch 107 time: 4.807s, average error = 91.166mrad
# Starting Epoch 108, with 107 batches
# 	Epoch 108, Step 0000, MSE: 8.509e-03,  LearnRate: 1.000e-01, Time taken : 0.627s
# 	Epoch 108, Step 0050, MSE: 8.334e-03,  LearnRate: 1.000e-01, Time taken : 1.886s
# 	Epoch 108, Step 0100, MSE: 8.466e-03,  LearnRate: 1.000e-01, Time taken : 1.894s
# Epoch 108 time: 4.238s, average error = 92.008mrad
# Starting Epoch 109, with 107 batches
# 	Epoch 109, Step 0000, MSE: 7.811e-03,  LearnRate: 1.000e-01, Time taken : 0.532s
# 	Epoch 109, Step 0050, MSE: 8.256e-03,  LearnRate: 1.000e-01, Time taken : 1.929s
# 	Epoch 109, Step 0100, MSE: 8.030e-03,  LearnRate: 1.000e-01, Time taken : 2.076s
# Epoch 109 time: 4.495s, average error = 89.612mrad
# Starting Epoch 110, with 107 batches
# 	Epoch 110, Step 0000, MSE: 7.939e-03,  LearnRate: 1.000e-01, Time taken : 0.600s
# 	Epoch 110, Step 0050, MSE: 8.168e-03,  LearnRate: 1.000e-01, Time taken : 1.921s
# 	Epoch 110, Step 0100, MSE: 8.102e-03,  LearnRate: 1.000e-01, Time taken : 2.007s
# Epoch 110 time: 4.423s, average error = 90.009mrad
# Starting Epoch 111, with 107 batches
# 	Epoch 111, Step 0000, MSE: 8.343e-03,  LearnRate: 1.000e-01, Time taken : 0.569s
# 	Epoch 111, Step 0050, MSE: 8.305e-03,  LearnRate: 1.000e-01, Time taken : 2.045s
# 	Epoch 111, Step 0100, MSE: 8.509e-03,  LearnRate: 1.000e-01, Time taken : 1.840s
# Epoch 111 time: 4.336s, average error = 92.247mrad
# Starting Epoch 112, with 107 batches
# 	Epoch 112, Step 0000, MSE: 8.053e-03,  LearnRate: 1.000e-01, Time taken : 0.543s
# 	Epoch 112, Step 0050, MSE: 8.434e-03,  LearnRate: 1.000e-01, Time taken : 1.878s
# 	Epoch 112, Step 0100, MSE: 8.225e-03,  LearnRate: 1.000e-01, Time taken : 2.074s
# Epoch 112 time: 4.474s, average error = 90.689mrad
# Starting Epoch 113, with 107 batches
# 	Epoch 113, Step 0000, MSE: 8.476e-03,  LearnRate: 1.000e-01, Time taken : 0.651s
# 	Epoch 113, Step 0050, MSE: 8.007e-03,  LearnRate: 1.000e-01, Time taken : 2.247s
# 	Epoch 113, Step 0100, MSE: 8.227e-03,  LearnRate: 1.000e-01, Time taken : 2.011s
# Epoch 113 time: 4.750s, average error = 90.704mrad
# Starting Epoch 114, with 107 batches
# 	Epoch 114, Step 0000, MSE: 8.246e-03,  LearnRate: 1.000e-01, Time taken : 0.568s
# 	Epoch 114, Step 0050, MSE: 8.182e-03,  LearnRate: 1.000e-01, Time taken : 2.073s
# 	Epoch 114, Step 0100, MSE: 8.240e-03,  LearnRate: 1.000e-01, Time taken : 1.928s
# Epoch 114 time: 4.524s, average error = 90.777mrad
# Starting Epoch 115, with 107 batches
# 	Epoch 115, Step 0000, MSE: 7.780e-03,  LearnRate: 1.000e-01, Time taken : 0.606s
# 	Epoch 115, Step 0050, MSE: 8.165e-03,  LearnRate: 1.000e-01, Time taken : 2.118s
# 	Epoch 115, Step 0100, MSE: 8.311e-03,  LearnRate: 1.000e-01, Time taken : 2.083s
# Epoch 115 time: 4.678s, average error = 91.162mrad
# Starting Epoch 116, with 107 batches
# 	Epoch 116, Step 0000, MSE: 7.495e-03,  LearnRate: 1.000e-01, Time taken : 0.547s
# 	Epoch 116, Step 0050, MSE: 8.004e-03,  LearnRate: 1.000e-01, Time taken : 1.934s
# 	Epoch 116, Step 0100, MSE: 8.120e-03,  LearnRate: 1.000e-01, Time taken : 2.001s
# Epoch 116 time: 4.377s, average error = 90.110mrad
# Starting Epoch 117, with 107 batches
# 	Epoch 117, Step 0000, MSE: 8.009e-03,  LearnRate: 1.000e-01, Time taken : 0.558s
# 	Epoch 117, Step 0050, MSE: 8.135e-03,  LearnRate: 1.000e-01, Time taken : 1.971s
# 	Epoch 117, Step 0100, MSE: 8.296e-03,  LearnRate: 1.000e-01, Time taken : 1.938s
# Epoch 117 time: 4.429s, average error = 91.084mrad
# Starting Epoch 118, with 107 batches
# 	Epoch 118, Step 0000, MSE: 7.917e-03,  LearnRate: 1.000e-01, Time taken : 0.590s
# 	Epoch 118, Step 0050, MSE: 7.925e-03,  LearnRate: 1.000e-01, Time taken : 1.823s
# 	Epoch 118, Step 0100, MSE: 8.142e-03,  LearnRate: 1.000e-01, Time taken : 1.989s
# Epoch 118 time: 4.252s, average error = 90.234mrad
# Starting Epoch 119, with 107 batches
# 	Epoch 119, Step 0000, MSE: 7.548e-03,  LearnRate: 1.000e-01, Time taken : 0.589s
# 	Epoch 119, Step 0050, MSE: 7.800e-03,  LearnRate: 1.000e-01, Time taken : 2.044s
# 	Epoch 119, Step 0100, MSE: 7.972e-03,  LearnRate: 1.000e-01, Time taken : 1.839s
# Epoch 119 time: 4.352s, average error = 89.285mrad
# Starting Epoch 120, with 107 batches
# 	Epoch 120, Step 0000, MSE: 7.717e-03,  LearnRate: 1.000e-01, Time taken : 0.602s
# 	Epoch 120, Step 0050, MSE: 7.946e-03,  LearnRate: 1.000e-01, Time taken : 2.103s
# 	Epoch 120, Step 0100, MSE: 8.127e-03,  LearnRate: 1.000e-01, Time taken : 1.890s
# Epoch 120 time: 4.515s, average error = 90.152mrad
# Starting Epoch 121, with 107 batches
# 	Epoch 121, Step 0000, MSE: 7.694e-03,  LearnRate: 1.000e-01, Time taken : 0.588s
# 	Epoch 121, Step 0050, MSE: 7.741e-03,  LearnRate: 1.000e-01, Time taken : 1.949s
# 	Epoch 121, Step 0100, MSE: 7.939e-03,  LearnRate: 1.000e-01, Time taken : 1.910s
# Epoch 121 time: 4.359s, average error = 89.099mrad
# Starting Epoch 122, with 107 batches
# 	Epoch 122, Step 0000, MSE: 7.626e-03,  LearnRate: 1.000e-01, Time taken : 0.620s
# 	Epoch 122, Step 0050, MSE: 7.910e-03,  LearnRate: 1.000e-01, Time taken : 2.099s
# 	Epoch 122, Step 0100, MSE: 8.684e-03,  LearnRate: 1.000e-01, Time taken : 2.097s
# Epoch 122 time: 4.695s, average error = 93.186mrad
# Starting Epoch 123, with 107 batches
# 	Epoch 123, Step 0000, MSE: 8.591e-03,  LearnRate: 1.000e-01, Time taken : 0.586s
# 	Epoch 123, Step 0050, MSE: 8.636e-03,  LearnRate: 1.000e-01, Time taken : 1.923s
# 	Epoch 123, Step 0100, MSE: 8.106e-03,  LearnRate: 1.000e-01, Time taken : 1.992s
# Epoch 123 time: 4.366s, average error = 90.033mrad
# Starting Epoch 124, with 107 batches
# 	Epoch 124, Step 0000, MSE: 7.715e-03,  LearnRate: 1.000e-01, Time taken : 0.593s
# 	Epoch 124, Step 0050, MSE: 7.875e-03,  LearnRate: 1.000e-01, Time taken : 1.802s
# 	Epoch 124, Step 0100, MSE: 7.739e-03,  LearnRate: 1.000e-01, Time taken : 1.829s
# Epoch 124 time: 4.101s, average error = 87.974mrad
# Starting Epoch 125, with 107 batches
# 	Epoch 125, Step 0000, MSE: 8.053e-03,  LearnRate: 1.000e-01, Time taken : 0.551s
# 	Epoch 125, Step 0050, MSE: 8.155e-03,  LearnRate: 1.000e-01, Time taken : 1.902s
# 	Epoch 125, Step 0100, MSE: 8.186e-03,  LearnRate: 1.000e-01, Time taken : 1.827s
# Epoch 125 time: 4.173s, average error = 90.479mrad
# Starting Epoch 126, with 107 batches
# 	Epoch 126, Step 0000, MSE: 7.584e-03,  LearnRate: 1.000e-01, Time taken : 0.554s
# 	Epoch 126, Step 0050, MSE: 8.202e-03,  LearnRate: 1.000e-01, Time taken : 2.201s
# 	Epoch 126, Step 0100, MSE: 7.999e-03,  LearnRate: 1.000e-01, Time taken : 1.703s
# Epoch 126 time: 4.412s, average error = 89.440mrad
# Starting Epoch 127, with 107 batches
# 	Epoch 127, Step 0000, MSE: 7.802e-03,  LearnRate: 1.000e-01, Time taken : 0.533s
# 	Epoch 127, Step 0050, MSE: 8.268e-03,  LearnRate: 1.000e-01, Time taken : 2.196s
# 	Epoch 127, Step 0100, MSE: 8.175e-03,  LearnRate: 1.000e-01, Time taken : 1.849s
# Epoch 127 time: 4.458s, average error = 90.416mrad
# Starting Epoch 128, with 107 batches
# 	Epoch 128, Step 0000, MSE: 7.805e-03,  LearnRate: 1.000e-01, Time taken : 0.601s
# 	Epoch 128, Step 0050, MSE: 8.018e-03,  LearnRate: 1.000e-01, Time taken : 1.975s
# 	Epoch 128, Step 0100, MSE: 8.060e-03,  LearnRate: 1.000e-01, Time taken : 1.881s
# Epoch 128 time: 4.357s, average error = 89.775mrad
# Starting Epoch 129, with 107 batches
# 	Epoch 129, Step 0000, MSE: 8.048e-03,  LearnRate: 1.000e-01, Time taken : 0.514s
# 	Epoch 129, Step 0050, MSE: 7.941e-03,  LearnRate: 1.000e-01, Time taken : 1.914s
# 	Epoch 129, Step 0100, MSE: 8.295e-03,  LearnRate: 1.000e-01, Time taken : 1.866s
# Epoch 129 time: 4.224s, average error = 91.079mrad
# Starting Epoch 130, with 107 batches
# 	Epoch 130, Step 0000, MSE: 7.713e-03,  LearnRate: 1.000e-01, Time taken : 0.479s
# 	Epoch 130, Step 0050, MSE: 7.965e-03,  LearnRate: 1.000e-01, Time taken : 1.902s
# 	Epoch 130, Step 0100, MSE: 8.287e-03,  LearnRate: 1.000e-01, Time taken : 1.901s
# Epoch 130 time: 4.265s, average error = 91.036mrad
# Starting Epoch 131, with 107 batches
# 	Epoch 131, Step 0000, MSE: 7.766e-03,  LearnRate: 1.000e-01, Time taken : 0.640s
# 	Epoch 131, Step 0050, MSE: 8.281e-03,  LearnRate: 1.000e-01, Time taken : 1.982s
# 	Epoch 131, Step 0100, MSE: 7.883e-03,  LearnRate: 1.000e-01, Time taken : 1.816s
# Epoch 131 time: 4.299s, average error = 88.785mrad
# Starting Epoch 132, with 107 batches
# 	Epoch 132, Step 0000, MSE: 7.802e-03,  LearnRate: 1.000e-01, Time taken : 0.549s
# 	Epoch 132, Step 0050, MSE: 7.939e-03,  LearnRate: 1.000e-01, Time taken : 1.751s
# 	Epoch 132, Step 0100, MSE: 8.217e-03,  LearnRate: 1.000e-01, Time taken : 1.793s
# Epoch 132 time: 4.019s, average error = 90.648mrad
# Starting Epoch 133, with 107 batches
# 	Epoch 133, Step 0000, MSE: 8.027e-03,  LearnRate: 1.000e-01, Time taken : 0.547s
# 	Epoch 133, Step 0050, MSE: 8.052e-03,  LearnRate: 1.000e-01, Time taken : 1.808s
# 	Epoch 133, Step 0100, MSE: 7.849e-03,  LearnRate: 1.000e-01, Time taken : 1.801s
# Epoch 133 time: 4.043s, average error = 88.594mrad
# Starting Epoch 134, with 107 batches
# 	Epoch 134, Step 0000, MSE: 7.356e-03,  LearnRate: 1.000e-01, Time taken : 0.548s
# 	Epoch 134, Step 0050, MSE: 7.649e-03,  LearnRate: 1.000e-01, Time taken : 1.839s
# 	Epoch 134, Step 0100, MSE: 7.696e-03,  LearnRate: 1.000e-01, Time taken : 1.878s
# Epoch 134 time: 4.158s, average error = 87.725mrad
# Starting Epoch 135, with 107 batches
# 	Epoch 135, Step 0000, MSE: 7.802e-03,  LearnRate: 1.000e-01, Time taken : 0.585s
# 	Epoch 135, Step 0050, MSE: 7.849e-03,  LearnRate: 1.000e-01, Time taken : 2.038s
# 	Epoch 135, Step 0100, MSE: 7.655e-03,  LearnRate: 1.000e-01, Time taken : 2.014s
# Epoch 135 time: 4.541s, average error = 87.492mrad
# Starting Epoch 136, with 107 batches
# 	Epoch 136, Step 0000, MSE: 7.736e-03,  LearnRate: 1.000e-01, Time taken : 0.591s
# 	Epoch 136, Step 0050, MSE: 7.971e-03,  LearnRate: 1.000e-01, Time taken : 1.901s
# 	Epoch 136, Step 0100, MSE: 8.222e-03,  LearnRate: 1.000e-01, Time taken : 1.783s
# Epoch 136 time: 4.146s, average error = 90.677mrad
# Starting Epoch 137, with 107 batches
# 	Epoch 137, Step 0000, MSE: 7.466e-03,  LearnRate: 1.000e-01, Time taken : 0.603s
# 	Epoch 137, Step 0050, MSE: 8.042e-03,  LearnRate: 1.000e-01, Time taken : 1.855s
# 	Epoch 137, Step 0100, MSE: 7.990e-03,  LearnRate: 1.000e-01, Time taken : 1.891s
# Epoch 137 time: 4.256s, average error = 89.389mrad
# Starting Epoch 138, with 107 batches
# 	Epoch 138, Step 0000, MSE: 7.215e-03,  LearnRate: 1.000e-01, Time taken : 0.624s
# 	Epoch 138, Step 0050, MSE: 7.445e-03,  LearnRate: 1.000e-01, Time taken : 1.896s
# 	Epoch 138, Step 0100, MSE: 8.181e-03,  LearnRate: 1.000e-01, Time taken : 1.941s
# Epoch 138 time: 4.354s, average error = 90.450mrad
# Starting Epoch 139, with 107 batches
# 	Epoch 139, Step 0000, MSE: 7.349e-03,  LearnRate: 1.000e-01, Time taken : 0.611s
# 	Epoch 139, Step 0050, MSE: 7.617e-03,  LearnRate: 1.000e-01, Time taken : 2.070s
# 	Epoch 139, Step 0100, MSE: 7.539e-03,  LearnRate: 1.000e-01, Time taken : 1.945s
# Epoch 139 time: 4.504s, average error = 86.827mrad
# Starting Epoch 140, with 107 batches
# 	Epoch 140, Step 0000, MSE: 7.443e-03,  LearnRate: 1.000e-01, Time taken : 0.598s
# 	Epoch 140, Step 0050, MSE: 7.523e-03,  LearnRate: 1.000e-01, Time taken : 2.096s
# 	Epoch 140, Step 0100, MSE: 8.248e-03,  LearnRate: 1.000e-01, Time taken : 1.918s
# Epoch 140 time: 4.545s, average error = 90.818mrad
# Starting Epoch 141, with 107 batches
# 	Epoch 141, Step 0000, MSE: 7.393e-03,  LearnRate: 1.000e-01, Time taken : 0.613s
# 	Epoch 141, Step 0050, MSE: 7.680e-03,  LearnRate: 1.000e-01, Time taken : 2.129s
# 	Epoch 141, Step 0100, MSE: 7.678e-03,  LearnRate: 1.000e-01, Time taken : 1.874s
# Epoch 141 time: 4.535s, average error = 87.626mrad
# Starting Epoch 142, with 107 batches
# 	Epoch 142, Step 0000, MSE: 7.273e-03,  LearnRate: 1.000e-01, Time taken : 0.610s
# 	Epoch 142, Step 0050, MSE: 7.199e-03,  LearnRate: 1.000e-01, Time taken : 1.894s
# 	Epoch 142, Step 0100, MSE: 7.165e-03,  LearnRate: 1.000e-01, Time taken : 1.882s
# Epoch 142 time: 4.270s, average error = 84.648mrad
# Starting Epoch 143, with 107 batches
# 	Epoch 143, Step 0000, MSE: 7.178e-03,  LearnRate: 1.000e-01, Time taken : 0.616s
# 	Epoch 143, Step 0050, MSE: 7.440e-03,  LearnRate: 1.000e-01, Time taken : 2.129s
# 	Epoch 143, Step 0100, MSE: 7.873e-03,  LearnRate: 1.000e-01, Time taken : 2.030s
# Epoch 143 time: 4.659s, average error = 88.729mrad
# Starting Epoch 144, with 107 batches
# 	Epoch 144, Step 0000, MSE: 7.081e-03,  LearnRate: 1.000e-01, Time taken : 0.501s
# 	Epoch 144, Step 0050, MSE: 7.193e-03,  LearnRate: 1.000e-01, Time taken : 1.926s
# 	Epoch 144, Step 0100, MSE: 7.388e-03,  LearnRate: 1.000e-01, Time taken : 2.099s
# Epoch 144 time: 4.436s, average error = 85.955mrad
# Starting Epoch 145, with 107 batches
# ...
# 	Epoch 1123, Step 0100, MSE: 4.915e-03,  LearnRate: 5.000e-02, Time taken : 1.851s
# Epoch 1123 time: 4.230s, average error = 70.109mrad
# Starting Epoch 1124, with 107 batches
# 	Epoch 1124, Step 0000, MSE: 4.487e-03,  LearnRate: 5.000e-02, Time taken : 0.764s
# 	Epoch 1124, Step 0050, MSE: 4.706e-03,  LearnRate: 5.000e-02, Time taken : 1.996s
# 	Epoch 1124, Step 0100, MSE: 4.745e-03,  LearnRate: 5.000e-02, Time taken : 2.039s
# Epoch 1124 time: 4.462s, average error = 68.884mrad
# Starting Epoch 1125, with 107 batches
# 	Epoch 1125, Step 0000, MSE: 4.512e-03,  LearnRate: 5.000e-02, Time taken : 0.552s
# 	Epoch 1125, Step 0050, MSE: 4.532e-03,  LearnRate: 5.000e-02, Time taken : 2.003s
# 	Epoch 1125, Step 0100, MSE: 4.597e-03,  LearnRate: 5.000e-02, Time taken : 2.026s
# Epoch 1125 time: 4.662s, average error = 67.801mrad
# Starting Epoch 1126, with 107 batches
# 	Epoch 1126, Step 0000, MSE: 4.659e-03,  LearnRate: 5.000e-02, Time taken : 0.974s
# 	Epoch 1126, Step 0050, MSE: 4.714e-03,  LearnRate: 5.000e-02, Time taken : 2.028s
# 	Epoch 1126, Step 0100, MSE: 4.901e-03,  LearnRate: 5.000e-02, Time taken : 2.028s
# Epoch 1126 time: 4.617s, average error = 70.010mrad
# Starting Epoch 1127, with 107 batches
# 	Epoch 1127, Step 0000, MSE: 4.488e-03,  LearnRate: 5.000e-02, Time taken : 0.724s
# 	Epoch 1127, Step 0050, MSE: 4.743e-03,  LearnRate: 5.000e-02, Time taken : 2.333s
# 	Epoch 1127, Step 0100, MSE: 4.596e-03,  LearnRate: 5.000e-02, Time taken : 1.979s
# Epoch 1127 time: 4.920s, average error = 67.791mrad
# Starting Epoch 1128, with 107 batches
# 	Epoch 1128, Step 0000, MSE: 4.486e-03,  LearnRate: 5.000e-02, Time taken : 0.799s
# 	Epoch 1128, Step 0050, MSE: 4.667e-03,  LearnRate: 5.000e-02, Time taken : 2.155s
# 	Epoch 1128, Step 0100, MSE: 4.853e-03,  LearnRate: 5.000e-02, Time taken : 2.097s
# Epoch 1128 time: 4.712s, average error = 69.660mrad
# Starting Epoch 1129, with 107 batches
# 	Epoch 1129, Step 0000, MSE: 4.486e-03,  LearnRate: 5.000e-02, Time taken : 0.594s
# 	Epoch 1129, Step 0050, MSE: 4.880e-03,  LearnRate: 5.000e-02, Time taken : 2.159s
# 	Epoch 1129, Step 0100, MSE: 4.788e-03,  LearnRate: 5.000e-02, Time taken : 2.169s
# Epoch 1129 time: 4.809s, average error = 69.197mrad
# Starting Epoch 1130, with 107 batches
# 	Epoch 1130, Step 0000, MSE: 4.421e-03,  LearnRate: 5.000e-02, Time taken : 0.846s
# 	Epoch 1130, Step 0050, MSE: 4.971e-03,  LearnRate: 5.000e-02, Time taken : 2.005s
# 	Epoch 1130, Step 0100, MSE: 4.642e-03,  LearnRate: 5.000e-02, Time taken : 2.065s
# Epoch 1130 time: 4.545s, average error = 68.133mrad
# Starting Epoch 1131, with 107 batches
# 	Epoch 1131, Step 0000, MSE: 4.807e-03,  LearnRate: 5.000e-02, Time taken : 0.511s
# 	Epoch 1131, Step 0050, MSE: 4.711e-03,  LearnRate: 5.000e-02, Time taken : 1.893s
# 	Epoch 1131, Step 0100, MSE: 4.689e-03,  LearnRate: 5.000e-02, Time taken : 1.952s
# Epoch 1131 time: 4.290s, average error = 68.475mrad
# Starting Epoch 1132, with 107 batches
# 	Epoch 1132, Step 0000, MSE: 4.481e-03,  LearnRate: 5.000e-02, Time taken : 0.746s
# 	Epoch 1132, Step 0050, MSE: 4.652e-03,  LearnRate: 5.000e-02, Time taken : 1.868s
# 	Epoch 1132, Step 0100, MSE: 4.809e-03,  LearnRate: 5.000e-02, Time taken : 1.848s
# Epoch 1132 time: 4.240s, average error = 69.347mrad
# Starting Epoch 1133, with 107 batches
# 	Epoch 1133, Step 0000, MSE: 4.484e-03,  LearnRate: 5.000e-02, Time taken : 0.628s
# 	Epoch 1133, Step 0050, MSE: 4.625e-03,  LearnRate: 5.000e-02, Time taken : 1.891s
# 	Epoch 1133, Step 0100, MSE: 4.621e-03,  LearnRate: 5.000e-02, Time taken : 2.024s
# Epoch 1133 time: 4.387s, average error = 67.978mrad
# Starting Epoch 1134, with 107 batches
# 	Epoch 1134, Step 0000, MSE: 4.348e-03,  LearnRate: 5.000e-02, Time taken : 0.622s
# 	Epoch 1134, Step 0050, MSE: 4.534e-03,  LearnRate: 5.000e-02, Time taken : 2.081s
# 	Epoch 1134, Step 0100, MSE: 4.663e-03,  LearnRate: 5.000e-02, Time taken : 2.134s
# Epoch 1134 time: 4.709s, average error = 68.284mrad
# Starting Epoch 1135, with 107 batches
# 	Epoch 1135, Step 0000, MSE: 4.610e-03,  LearnRate: 5.000e-02, Time taken : 0.749s
# 	Epoch 1135, Step 0050, MSE: 4.828e-03,  LearnRate: 5.000e-02, Time taken : 2.193s
# 	Epoch 1135, Step 0100, MSE: 4.906e-03,  LearnRate: 5.000e-02, Time taken : 1.945s
# Epoch 1135 time: 4.660s, average error = 70.040mrad
# Starting Epoch 1136, with 107 batches
# 	Epoch 1136, Step 0000, MSE: 4.803e-03,  LearnRate: 5.000e-02, Time taken : 0.579s
# 	Epoch 1136, Step 0050, MSE: 4.696e-03,  LearnRate: 5.000e-02, Time taken : 1.801s
# 	Epoch 1136, Step 0100, MSE: 4.746e-03,  LearnRate: 5.000e-02, Time taken : 1.838s
# Epoch 1136 time: 4.093s, average error = 68.888mrad
# Starting Epoch 1137, with 107 batches
# 	Epoch 1137, Step 0000, MSE: 4.544e-03,  LearnRate: 5.000e-02, Time taken : 0.768s
# 	Epoch 1137, Step 0050, MSE: 4.636e-03,  LearnRate: 5.000e-02, Time taken : 2.020s
# 	Epoch 1137, Step 0100, MSE: 4.696e-03,  LearnRate: 5.000e-02, Time taken : 1.864s
# Epoch 1137 time: 4.409s, average error = 68.531mrad
# Starting Epoch 1138, with 107 batches
# 	Epoch 1138, Step 0000, MSE: 4.637e-03,  LearnRate: 5.000e-02, Time taken : 0.542s
# 	Epoch 1138, Step 0050, MSE: 4.564e-03,  LearnRate: 5.000e-02, Time taken : 1.895s
# 	Epoch 1138, Step 0100, MSE: 4.775e-03,  LearnRate: 5.000e-02, Time taken : 2.282s
# Epoch 1138 time: 4.662s, average error = 69.101mrad
# Starting Epoch 1139, with 107 batches
# 	Epoch 1139, Step 0000, MSE: 4.524e-03,  LearnRate: 5.000e-02, Time taken : 0.755s
# 	Epoch 1139, Step 0050, MSE: 4.739e-03,  LearnRate: 5.000e-02, Time taken : 1.996s
# 	Epoch 1139, Step 0100, MSE: 4.797e-03,  LearnRate: 5.000e-02, Time taken : 2.128s
# Epoch 1139 time: 4.636s, average error = 69.258mrad
# Starting Epoch 1140, with 107 batches
# 	Epoch 1140, Step 0000, MSE: 4.704e-03,  LearnRate: 5.000e-02, Time taken : 0.620s
# 	Epoch 1140, Step 0050, MSE: 4.940e-03,  LearnRate: 5.000e-02, Time taken : 2.267s
# 	Epoch 1140, Step 0100, MSE: 4.849e-03,  LearnRate: 5.000e-02, Time taken : 2.246s
# Epoch 1140 time: 5.025s, average error = 69.638mrad
# Starting Epoch 1141, with 107 batches
# 	Epoch 1141, Step 0000, MSE: 4.444e-03,  LearnRate: 5.000e-02, Time taken : 0.747s
# 	Epoch 1141, Step 0050, MSE: 4.667e-03,  LearnRate: 5.000e-02, Time taken : 2.106s
# 	Epoch 1141, Step 0100, MSE: 4.720e-03,  LearnRate: 5.000e-02, Time taken : 1.867s
# Epoch 1141 time: 4.457s, average error = 68.700mrad
# Starting Epoch 1142, with 107 batches
# 	Epoch 1142, Step 0000, MSE: 4.552e-03,  LearnRate: 5.000e-02, Time taken : 0.581s
# 	Epoch 1142, Step 0050, MSE: 4.665e-03,  LearnRate: 5.000e-02, Time taken : 1.856s
# 	Epoch 1142, Step 0100, MSE: 5.165e-03,  LearnRate: 5.000e-02, Time taken : 1.971s
# Epoch 1142 time: 4.314s, average error = 71.869mrad
# Starting Epoch 1143, with 107 batches
# 	Epoch 1143, Step 0000, MSE: 4.571e-03,  LearnRate: 5.000e-02, Time taken : 0.673s
# 	Epoch 1143, Step 0050, MSE: 4.622e-03,  LearnRate: 5.000e-02, Time taken : 2.018s
# 	Epoch 1143, Step 0100, MSE: 4.730e-03,  LearnRate: 5.000e-02, Time taken : 2.045s
# Epoch 1143 time: 4.579s, average error = 68.776mrad
# Starting Epoch 1144, with 107 batches
# 	Epoch 1144, Step 0000, MSE: 4.591e-03,  LearnRate: 5.000e-02, Time taken : 0.831s
# 	Epoch 1144, Step 0050, MSE: 4.642e-03,  LearnRate: 5.000e-02, Time taken : 1.992s
# 	Epoch 1144, Step 0100, MSE: 4.680e-03,  LearnRate: 5.000e-02, Time taken : 1.940s
# Epoch 1144 time: 4.457s, average error = 68.414mrad
# Starting Epoch 1145, with 107 batches
# 	Epoch 1145, Step 0000, MSE: 4.616e-03,  LearnRate: 5.000e-02, Time taken : 0.664s
# 	Epoch 1145, Step 0050, MSE: 4.833e-03,  LearnRate: 5.000e-02, Time taken : 2.258s
# 	Epoch 1145, Step 0100, MSE: 4.740e-03,  LearnRate: 5.000e-02, Time taken : 2.167s
# Epoch 1145 time: 4.945s, average error = 68.850mrad
# Starting Epoch 1146, with 107 batches
# 	Epoch 1146, Step 0000, MSE: 4.693e-03,  LearnRate: 5.000e-02, Time taken : 0.627s
# 	Epoch 1146, Step 0050, MSE: 4.695e-03,  LearnRate: 5.000e-02, Time taken : 2.040s
# 	Epoch 1146, Step 0100, MSE: 4.923e-03,  LearnRate: 5.000e-02, Time taken : 1.975s
# Epoch 1146 time: 4.580s, average error = 70.166mrad
# Starting Epoch 1147, with 107 batches
# 	Epoch 1147, Step 0000, MSE: 4.677e-03,  LearnRate: 5.000e-02, Time taken : 0.859s
# 	Epoch 1147, Step 0050, MSE: 4.882e-03,  LearnRate: 5.000e-02, Time taken : 2.007s
# 	Epoch 1147, Step 0100, MSE: 5.095e-03,  LearnRate: 5.000e-02, Time taken : 1.997s
# Epoch 1147 time: 4.505s, average error = 71.377mrad
# Starting Epoch 1148, with 107 batches
# 	Epoch 1148, Step 0000, MSE: 4.495e-03,  LearnRate: 5.000e-02, Time taken : 0.498s
# 	Epoch 1148, Step 0050, MSE: 4.617e-03,  LearnRate: 5.000e-02, Time taken : 2.123s
# 	Epoch 1148, Step 0100, MSE: 4.670e-03,  LearnRate: 5.000e-02, Time taken : 2.191s
# Epoch 1148 time: 4.764s, average error = 68.339mrad
# Starting Epoch 1149, with 107 batches
# 	Epoch 1149, Step 0000, MSE: 4.634e-03,  LearnRate: 5.000e-02, Time taken : 0.619s
# 	Epoch 1149, Step 0050, MSE: 4.789e-03,  LearnRate: 5.000e-02, Time taken : 1.973s
# 	Epoch 1149, Step 0100, MSE: 4.973e-03,  LearnRate: 5.000e-02, Time taken : 2.159s
# Epoch 1149 time: 4.640s, average error = 70.522mrad
# Starting Epoch 1150, with 107 batches
# 	Epoch 1150, Step 0000, MSE: 4.636e-03,  LearnRate: 5.000e-02, Time taken : 0.631s
# 	Epoch 1150, Step 0050, MSE: 4.819e-03,  LearnRate: 5.000e-02, Time taken : 1.857s
# 	Epoch 1150, Step 0100, MSE: 4.967e-03,  LearnRate: 5.000e-02, Time taken : 1.909s
# Epoch 1150 time: 4.254s, average error = 70.476mrad
# Starting Epoch 1151, with 107 batches
# 	Epoch 1151, Step 0000, MSE: 4.976e-03,  LearnRate: 5.000e-02, Time taken : 0.619s
# 	Epoch 1151, Step 0050, MSE: 4.962e-03,  LearnRate: 5.000e-02, Time taken : 1.895s
# 	Epoch 1151, Step 0100, MSE: 4.908e-03,  LearnRate: 5.000e-02, Time taken : 2.040s
# Epoch 1151 time: 4.476s, average error = 70.054mrad
# Starting Epoch 1152, with 107 batches
# 	Epoch 1152, Step 0000, MSE: 4.537e-03,  LearnRate: 5.000e-02, Time taken : 0.638s
# 	Epoch 1152, Step 0050, MSE: 4.873e-03,  LearnRate: 5.000e-02, Time taken : 1.956s
# 	Epoch 1152, Step 0100, MSE: 4.753e-03,  LearnRate: 5.000e-02, Time taken : 2.172s
# Epoch 1152 time: 4.666s, average error = 68.940mrad
# Starting Epoch 1153, with 107 batches
# 	Epoch 1153, Step 0000, MSE: 4.503e-03,  LearnRate: 5.000e-02, Time taken : 0.603s
# 	Epoch 1153, Step 0050, MSE: 4.600e-03,  LearnRate: 5.000e-02, Time taken : 2.306s
# 	Epoch 1153, Step 0100, MSE: 4.691e-03,  LearnRate: 5.000e-02, Time taken : 2.317s
# Epoch 1153 time: 5.078s, average error = 68.491mrad
# Starting Epoch 1154, with 107 batches
# 	Epoch 1154, Step 0000, MSE: 4.614e-03,  LearnRate: 5.000e-02, Time taken : 0.688s
# 	Epoch 1154, Step 0050, MSE: 4.773e-03,  LearnRate: 5.000e-02, Time taken : 1.857s
# 	Epoch 1154, Step 0100, MSE: 4.768e-03,  LearnRate: 5.000e-02, Time taken : 2.040s
# Epoch 1154 time: 4.396s, average error = 69.053mrad
# Starting Epoch 1155, with 107 batches
# 	Epoch 1155, Step 0000, MSE: 4.598e-03,  LearnRate: 5.000e-02, Time taken : 0.694s
# 	Epoch 1155, Step 0050, MSE: 4.582e-03,  LearnRate: 5.000e-02, Time taken : 2.074s
# 	Epoch 1155, Step 0100, MSE: 4.567e-03,  LearnRate: 5.000e-02, Time taken : 2.026s
# Epoch 1155 time: 4.601s, average error = 67.582mrad
# Starting Epoch 1156, with 107 batches
# 	Epoch 1156, Step 0000, MSE: 4.505e-03,  LearnRate: 5.000e-02, Time taken : 0.518s
# 	Epoch 1156, Step 0050, MSE: 4.725e-03,  LearnRate: 5.000e-02, Time taken : 1.977s
# 	Epoch 1156, Step 0100, MSE: 4.746e-03,  LearnRate: 5.000e-02, Time taken : 2.037s
# Epoch 1156 time: 4.533s, average error = 68.888mrad
# Starting Epoch 1157, with 107 batches
# 	Epoch 1157, Step 0000, MSE: 4.739e-03,  LearnRate: 5.000e-02, Time taken : 0.807s
# 	Epoch 1157, Step 0050, MSE: 4.600e-03,  LearnRate: 5.000e-02, Time taken : 2.154s
# 	Epoch 1157, Step 0100, MSE: 4.638e-03,  LearnRate: 5.000e-02, Time taken : 2.198s
# Epoch 1157 time: 4.838s, average error = 68.106mrad
# Starting Epoch 1158, with 107 batches
# 	Epoch 1158, Step 0000, MSE: 4.492e-03,  LearnRate: 5.000e-02, Time taken : 0.630s
# 	Epoch 1158, Step 0050, MSE: 4.584e-03,  LearnRate: 5.000e-02, Time taken : 2.042s
# 	Epoch 1158, Step 0100, MSE: 4.521e-03,  LearnRate: 5.000e-02, Time taken : 2.146s
# Epoch 1158 time: 4.705s, average error = 67.237mrad
# Starting Epoch 1159, with 107 batches
# 	Epoch 1159, Step 0000, MSE: 4.591e-03,  LearnRate: 5.000e-02, Time taken : 0.643s
# 	Epoch 1159, Step 0050, MSE: 4.736e-03,  LearnRate: 5.000e-02, Time taken : 2.226s
# 	Epoch 1159, Step 0100, MSE: 4.834e-03,  LearnRate: 5.000e-02, Time taken : 2.244s
# Epoch 1159 time: 5.000s, average error = 69.526mrad
# Starting Epoch 1160, with 107 batches
# 	Epoch 1160, Step 0000, MSE: 4.687e-03,  LearnRate: 5.000e-02, Time taken : 0.792s
# 	Epoch 1160, Step 0050, MSE: 4.829e-03,  LearnRate: 5.000e-02, Time taken : 2.051s
# 	Epoch 1160, Step 0100, MSE: 4.915e-03,  LearnRate: 5.000e-02, Time taken : 2.081s
# Epoch 1160 time: 4.609s, average error = 70.108mrad
# Starting Epoch 1161, with 107 batches
# 	Epoch 1161, Step 0000, MSE: 4.492e-03,  LearnRate: 5.000e-02, Time taken : 0.590s
# 	Epoch 1161, Step 0050, MSE: 4.657e-03,  LearnRate: 5.000e-02, Time taken : 2.212s
# 	Epoch 1161, Step 0100, MSE: 5.208e-03,  LearnRate: 5.000e-02, Time taken : 2.167s
# Epoch 1161 time: 4.892s, average error = 72.168mrad
# Starting Epoch 1162, with 107 batches
# 	Epoch 1162, Step 0000, MSE: 4.689e-03,  LearnRate: 5.000e-02, Time taken : 0.619s
# 	Epoch 1162, Step 0050, MSE: 4.631e-03,  LearnRate: 5.000e-02, Time taken : 2.067s
# 	Epoch 1162, Step 0100, MSE: 4.769e-03,  LearnRate: 5.000e-02, Time taken : 2.001s
# Epoch 1162 time: 4.575s, average error = 69.061mrad
# Starting Epoch 1163, with 107 batches
# 	Epoch 1163, Step 0000, MSE: 4.807e-03,  LearnRate: 5.000e-02, Time taken : 0.611s
# 	Epoch 1163, Step 0050, MSE: 4.940e-03,  LearnRate: 5.000e-02, Time taken : 2.105s
# 	Epoch 1163, Step 0100, MSE: 5.255e-03,  LearnRate: 5.000e-02, Time taken : 2.330s
# Epoch 1163 time: 4.898s, average error = 72.491mrad
# Starting Epoch 1164, with 107 batches
# 	Epoch 1164, Step 0000, MSE: 4.454e-03,  LearnRate: 5.000e-02, Time taken : 0.584s
# 	Epoch 1164, Step 0050, MSE: 4.641e-03,  LearnRate: 5.000e-02, Time taken : 1.868s
# 	Epoch 1164, Step 0100, MSE: 4.679e-03,  LearnRate: 5.000e-02, Time taken : 2.175s
# Epoch 1164 time: 4.557s, average error = 68.405mrad
# Starting Epoch 1165, with 107 batches
# 	Epoch 1165, Step 0000, MSE: 4.474e-03,  LearnRate: 5.000e-02, Time taken : 0.545s
# 	Epoch 1165, Step 0050, MSE: 4.777e-03,  LearnRate: 5.000e-02, Time taken : 2.356s
# 	Epoch 1165, Step 0100, MSE: 4.718e-03,  LearnRate: 5.000e-02, Time taken : 1.985s
# Epoch 1165 time: 4.780s, average error = 68.689mrad
# Starting Epoch 1166, with 107 batches
# 	Epoch 1166, Step 0000, MSE: 4.561e-03,  LearnRate: 5.000e-02, Time taken : 0.779s
# 	Epoch 1166, Step 0050, MSE: 4.544e-03,  LearnRate: 5.000e-02, Time taken : 2.058s
# 	Epoch 1166, Step 0100, MSE: 4.628e-03,  LearnRate: 5.000e-02, Time taken : 2.054s
# Epoch 1166 time: 4.684s, average error = 68.031mrad
# Starting Epoch 1167, with 107 batches
# 	Epoch 1167, Step 0000, MSE: 4.562e-03,  LearnRate: 5.000e-02, Time taken : 0.680s
# 	Epoch 1167, Step 0050, MSE: 4.568e-03,  LearnRate: 5.000e-02, Time taken : 2.415s
# 	Epoch 1167, Step 0100, MSE: 4.655e-03,  LearnRate: 5.000e-02, Time taken : 2.001s
# Epoch 1167 time: 4.907s, average error = 68.229mrad
# Starting Epoch 1168, with 107 batches
# 	Epoch 1168, Step 0000, MSE: 4.803e-03,  LearnRate: 5.000e-02, Time taken : 0.546s
# 	Epoch 1168, Step 0050, MSE: 4.677e-03,  LearnRate: 5.000e-02, Time taken : 2.225s
# 	Epoch 1168, Step 0100, MSE: 4.692e-03,  LearnRate: 5.000e-02, Time taken : 2.186s
# Epoch 1168 time: 4.923s, average error = 68.496mrad
# Starting Epoch 1169, with 107 batches
# 	Epoch 1169, Step 0000, MSE: 4.682e-03,  LearnRate: 5.000e-02, Time taken : 0.638s
# 	Epoch 1169, Step 0050, MSE: 4.814e-03,  LearnRate: 5.000e-02, Time taken : 2.020s
# 	Epoch 1169, Step 0100, MSE: 4.910e-03,  LearnRate: 5.000e-02, Time taken : 2.314s
# Epoch 1169 time: 4.841s, average error = 70.068mrad
# Starting Epoch 1170, with 107 batches
# 	Epoch 1170, Step 0000, MSE: 4.372e-03,  LearnRate: 5.000e-02, Time taken : 0.663s
# 	Epoch 1170, Step 0050, MSE: 4.727e-03,  LearnRate: 5.000e-02, Time taken : 2.320s
