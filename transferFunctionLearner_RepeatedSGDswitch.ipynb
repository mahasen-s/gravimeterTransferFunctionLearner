# %% [markdown]
# ## Deep learning prototype model
# Tensorflow implementation of a fully connected deep net for arbitrarily shaped input and output layers, with the following features:
# - Easy control of net topology and hyperparameters
# - Abstracted functions for retrieving/constructing training data
# - Exponential decay of learning rate
# - Dropout regularisation
# - Batch normalisation
# - Automatic logging of bulk statistics of each layer through tensorboard (and convenient functions to attach logging to custom functions)
#
#
# ## Visualising progress
# To inspect the training progress, run
#
# >  `>tensorboard --logdir=<log_dir>`
#
#
# from the terminal, where `log_dir` as as defined above
#
# ## Requirements
# - TensorFlow 1.8
# - numpy
# - subprocess

# %%
import tensorflow as tf
import numpy as np
from subprocess import call
import time, math
import h5py
# Out:
# /home/mahasen/anaconda3/envs/intel_3.6_TF_1.8/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Setting dtype for tensorflow and numpy environments
DTYPE = tf.float64
DTYPE_np = np.float64
log_dir = '/mnt/dataDrive3/mahasen/tmp/funclearn' # Directory where we dump tensorboard log files

# Useful function for resetting logdir and tensorflow graph
def reset_tf():
    call(["rm","-rf",log_dir+'/'])
    tf.reset_default_graph()
    
    
# Define some functions for initialising layers with appropriate statistics    
def get_weights(shape,dtype):
    # Returns trainable weight variable, initialised from truncated (+\- 2std. dev. only) standard normal distribution
    return tf.Variable(tf.truncated_normal(shape, dtype=dtype),name='weights')

def get_biases(shape,dtype):
    # Returns trainable bias variable, initialised arbitrarily as a small constant
    return tf.Variable(tf.constant(0.01, shape=shape, dtype=dtype),name='biases')

def get_bn_offset(shape,dtype):
    # Returns trainable bias/offset variable for batch normalisation
    return tf.Variable(tf.truncated_normal(shape=shape, dtype=dtype),name='beta_offset')

def get_bn_scale(shape,dtype):
    # Returns trainable scale variable for batch normalisation
    return tf.Variable(tf.constant(1.0, shape=shape, dtype=dtype),name='gamma_scale')


def variable_summaries(var):
    # Attaches mean, stddev, max, min, and a histogram of an input var to a tensor
    # Useful for TensorBoard visualisation
    with tf.name_scope('summaries'):
        mean = tf.reduce_mean(var,name='mean')
        stddev = tf.sqrt(tf.reduce_mean(tf.square(var-mean)),name='stddev')
        
        tf.summary.scalar('mean',mean)
        tf.summary.scalar('stddev',stddev)
        tf.summary.scalar('max',tf.reduce_max(var))
        tf.summary.scalar('min',tf.reduce_min(var))
        tf.summary.histogram('histogram', var)
        
def batchnorm(logits, is_test, offset, scale, iteration):
    # Get summary statistics of this batch
    mean, variance    = tf.nn.moments(logits, [0],name='moments')
    
    # We'll use an exponential moving average over the training iterations during test time
    # This is a tool to do that
    exp_moving_avg    = tf.train.ExponentialMovingAverage(0.9999, iteration)
    update_moving_avg = exp_moving_avg.apply([mean, variance])
    
    # If this is the test, we use the m,v values we obtained from the exponential moving average 
    # over mean, variance that we obtained from training. otherwise use the batch mean, variance
    mean_cond        = tf.cond(is_test, lambda: exp_moving_avg.average(mean), lambda: mean, name='mean_cond')
    variance_cond    = tf.cond(is_test, lambda: exp_moving_avg.average(variance), lambda: variance, name='variance_cond')
    
    # This applies the following normalisation: x-> scale*(x-mean(x))/(variance_epsilon+std(x)) + offset
    logits_bn = tf.nn.batch_normalization(logits, mean_cond, variance_cond, offset, scale, variance_epsilon=1e-5,name='logits_batchnormed')
    
    return logits_bn, update_moving_avg

def get_layer_complete(input_tensor,input_dim, output_dim, layer_name, is_test, prob_keep, global_step, act_func=tf.nn.relu):
    with tf.name_scope(layer_name):
        with tf.name_scope('weights'):
            weights = get_weights([input_dim, output_dim],DTYPE)
            variable_summaries(weights)
        with tf.name_scope('biases'):
            biases = get_biases([output_dim],DTYPE)
            variable_summaries(biases)
        with tf.name_scope('batchnorm'):
            offset = get_bn_offset([output_dim], DTYPE)
            scale  = get_bn_scale([output_dim], DTYPE)
        
        logits = tf.add(tf.matmul(input_tensor, weights),biases,name='logits')
        tf.summary.histogram('logits', logits)
        logits_bn, update_moving_avg = batchnorm(logits, is_test, offset, scale, global_step)
        tf.summary.histogram('logits_batchNormed', logits_bn)
        activated = act_func(logits_bn, name='activation')
        dropped_out = tf.nn.dropout(activated,prob_keep,name='dropout')
        tf.summary.histogram('activations', activated)
        return dropped_out, update_moving_avg 
    
def func_deep_learner_complete(x,m,n,h,is_test,global_step,prob_keep,act_func=tf.nn.relu,num_layers=5):
    # x is the input variable, probably a TensorFlow placeholder object
    # m is the input dimension
    # n is the output dimension
    # h is the number of hidden neurons
    # act_func is the activation function to be applied
    # is_test is a flag is use to control batch normalisation behaviour during inferene on test data
    # iteration is the iteration counter used inside the training loop; required for batch normalisation
    
    bn_moving_avg_updates = []

    with tf.variable_scope('func_learner'):
        # 0th hidden layer
        hidden_layer, update_moving_avg = get_layer_complete(x,m,h,'hidden_layer_0',is_test,prob_keep,global_step)
        bn_moving_avg_updates.append(update_moving_avg)

        # Other hidden layers
        for i in range(num_layers-1):
            hidden_layer, update_moving_avg = get_layer_complete(hidden_layer,h,h,'hidden_layer_'+str(i+1),is_test,prob_keep,global_step)
            bn_moving_avg_updates.append(update_moving_avg)

        # Output layer
        weights1= tf.get_variable(name='output_layer_weights',
                              shape=[h,n],
                              initializer=tf.random_normal_initializer(),
                              dtype=DTYPE)

    return tf.matmul(hidden_layer,weights1), bn_moving_avg_updates

def train_RBM_complete(input_size=1,output_size=1,hidden_size=1,num_layers=5,model_func=None,unknown_func=None,
                  test_x=None, test_y = None, generate_training_samples_fun=None,
                  batch_size=25, max_steps = 1000, epochs =5,
                  initial_learning_rate = 0.02, decay_rate = 1/math.e, decay_steps=1000,
                  prob_keep = 0.8):
    
    with tf.Session() as sess:
            
        with tf.name_scope('input'):
            # Placeholder variables which will be fed data at train time
            x  = tf.placeholder(DTYPE,[None,input_size],name='x_input')
            y  = tf.placeholder(DTYPE,[None,output_size],name='y_input')
        
        with tf.name_scope('control_inputs'):
            global_step = tf.Variable(0, trainable=False,name='global_step')
            epoch_ind = tf.Variable(0,trainable=False,name='epoch_ind')
            increment_epoch_ind = tf.assign_add(epoch_ind,1,name='increment_epoch_ind')
            is_test = tf.contrib.eager.Variable(False, trainable=False,name='is_test')

        # Predictions of the NN
        y_pred, bn_moving_avg_updates = func_deep_learner_complete(x,input_size,output_size,hidden_size,is_test,global_step,1,num_layers=num_layers)

        # Should add dropout!

        with tf.name_scope('mean_squared_error'):
            mse = tf.losses.mean_squared_error(y,y_pred)
        tf.summary.scalar('mean_squared_error',mse)

        with tf.name_scope('train'):
            global_step_in_epoch = global_step - epoch_ind*max_steps
            learning_rate = tf.train.exponential_decay(initial_learning_rate, global_step_in_epoch, decay_steps, decay_rate, staircase=True)
            tf.summary.scalar('learning_rate', learning_rate)
            train_step = tf.train.AdamOptimizer(learning_rate).minimize(mse, global_step = global_step)

        # Create merged summary object and file writers
        merged_summaries = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(log_dir + '/train', sess.graph)
        test_writer = tf.summary.FileWriter(log_dir + '/test', sess.graph)
        
        # Initialise variables
        sess.run(tf.global_variables_initializer())
        
        # Train the model
        start_time = time.time()
        old_time = start_time
        for j in range(epochs):
            for i in range(max_steps):
                if i % 100 ==0:
                    # Check how our model performs against the test data
                    [summary, mse_val] = sess.run([merged_summaries,mse], feed_dict={x: test_x, y: test_y, is_test: True})
                    test_writer.add_summary(summary,i + j*max_steps)
                    curr_time = time.time()
                    print('Epoch %d, Step %04d, MSE: %4.3e,  LearnRate: %4.3e, Time taken : %4.3fs' % (sess.run(epoch_ind),i, mse_val, sess.run(learning_rate),curr_time-old_time))
                    old_time = curr_time
                else:
                    # Generate new sample data and train our model
                    train_x, train_y = generate_training_samples_fun(epoch_ind, global_step)
                    summary, _ = sess.run([merged_summaries, train_step], feed_dict={x: train_x, y: train_y, is_test: False})
                    sess.run(bn_moving_avg_updates, feed_dict={x: train_x, y: train_y, is_test: False})
                    train_writer.add_summary(summary,i+ j*max_steps)
            sess.run(increment_epoch_ind)
        train_writer.close()
        test_writer.close()     
        print('\nTotal time:\t %4.3fs' % (time.time()-start_time))

# %% [markdown]
# ## Theory

# %% [markdown]
# Consider a Mach-Zehnder interferometer with interrogation time $T$ and pulse duration $\tau$. The total interferometer phase is given by:
# $$\Delta\Phi = \phi_{eff}^1 - 2\phi_{eff}^2 + \phi_{eff}^3 + \left(\mathrm{arg}(\Theta_0^1)-\mathrm{arg}(\Theta^3_0)\right)$$
# where $\phi_{eff}^i$ describes the "light phase at the atomic positions during the three Raman pulses". $\Theta_0^i$ descibes secondary phase shifts due to "different light shifts between the first and last pulse".
#
# Define the sensitivity function $g(t)$ as the effect on the total interferometer phase due to a phase jump $\delta\phi$ at time $t$. For the three-pulse Mach-Zehnder, with second pulse centered at $t=0$, $g(t)$ is given by:
# $$g(t) = \begin{cases}
# \sin(\Omega_rt), & 0<t\leq\tau \\
# 1, & \tau<t\leq T+\tau\\
# -\sin(\Omega_r(T-t)), & T+\tau<t\leq T+2\tau \\
# 0, & t>T+2\tau
# \end{cases}$$
#
# For finite Raman pulse duration (i.e. $\tau>0$), the total interferometer phase is given by:
# $$\Delta\Phi = \int_{-(T_2\tau)}^{(T+2\tau)}g(t)\frac{d\phi(t)}{dt}dt$$
#
# To perform post-correction, we separtely calculate the phase offset caused by mirror vibrations:
# $$\Phi_{vib} = k_{eff}\int_{t_1}^{t_3}g(t)v(t)dt$$
# where $v(t)=\frac{1}{k_{eff}}\frac{d\phi}{dt}$ is the mirror velocity and $k_eff$ is the effective wavevector

# %% [markdown]
# ## Data layout
# Data is organised into campaigns, each containing ~10^5 interferometer runs. Use only 4a onwards.
# Each `.h5` has three fields
# - `accelerometer`: `[N_a,2]` linearly proportional to the raw out from the accelerometer as a time series. 1st column is linux time, 2nd column is signal
# - `ai_kdown`: `[N_p,2]` total interferometer phase for kdown? configuration. 1st column is linux time, 2nd column is phase. Each row is the total interferometer phase for an Mach-Zehnder sequence with 2nd pulse centered at the given time
# - `ai_kup`: `[N_p,2]` total interferometer phase for kup? configuration. Same layout as `ai_kdown`
# - `(T,tau)`: `[2,]` the interferometer interrogation time `T` and the $\frac{\pi}{2}$ Raman pulse duration `tau`
#
# First we need to prepare the data.
#
# (1) Check timestamps of `ai_kdown`==`ai_kup`
# - THEY DON'T; they aren't even necessarily the same length. Assume that each corresponds to a completely different subsequence of `accelerometer`
# - Also, note that the distribution of delays between successive runs is weirdly distributed
#
# (2) For each ai_* associate a contiguous subsequence of `accelerometer`
#  - Ensure each subsequence is of equal length `N_s`
#  - Will being left/right aligned w.r.t. rounding of `ai_kdown` timestamp to `accelerometer` timestamps affect anything?
#  - Safest thing to do might be linearly interpolate `accelerometer` to ensure that `accelerometer` subsequence is correctly time-aligned with `ai_*`
#
# (3) Construct our inputs and outputs
#  - `x_input` = `[N_s,N_p]` array
#  - `y_output` = `[N_p,2]` concatenate 2nd column of `ai_kdown` and `ai_kup`
#
# ## Check
# Make sure we can reproduce original data (i.e. reproduce original $\Phi_{vib}$)
#  - Do we have this data?
#
# ## Modelling
# (1) *Model-free* Just use the inputs and labels as they are (assuming `N_s` is small enough)
#  - Pros: easy
#  - Cons: no ground-truth to compare against
#
# (2) *Explicit transfer function* Apply unknown function in Laplace space ($\mathcal{L}\{y(t)\}(Z) =H(Z)\mathcal{L}\{x(t)\}(Z)$ )
#  - Pros: ground-truth to compare against
#  - Cons: less easy

# %% [markdown]
# ## Use Processed campaign4a
# Matlab used to assign subsequences in `accelerometer` to each entry in `ai_kup` and `ai_kdown`.
# Subsequence length is 195. ~100000 entries for each of `ai_kup` and `ai_kdown`.

# %%
# Let's define a function that will generate indices for batches
# accounting for the possibility that the size of the dataset
# will not be an even multiple of the batch size
def generate_batches(N,batch_size=32):
    # N is the number of elements in the dataset
    if N<batch_size:
        raise ValueError('batch_size must be smaller than N')
    perm = np.random.permutation(N);
    if np.mod(N,batch_size)!=0:
        # We need to append to perm so that is is an even multiple of batch_size
        perm2= np.random.permutation(N);
        perm = np.concatenate((perm,perm2[0:batch_size-np.mod(N,batch_size)]))
    
    n_batches = np.int(len(perm)/batch_size)
    batches = perm.reshape(batch_size,n_batches)
    
    return batches

def get_xy_by_inds(x,y,inds):
    # Get values from 2Dx, 1Dy arrays
    x0 = x[inds,:]
    y0 = np.array(list(map(y.__getitem__,inds))) # because Python treats 1D arrays differently from ND arrays
    y0 = y0.reshape([len(y0),1])
    return x0,y0
    
def generate_testtrain(x,y,test_fraction,batch_size=32):
    # Assumes x.shape = [n_samples,input_size], y.shape = [input_size,]
    if test_fraction<0 or test_fraction>1:
        raise ValueError('test_fraction must be between 0 and 1')
    
    n_samples  = x.shape[0]
    test_size  = np.int(np.round(n_samples*test_fraction))
    if test_size<1:
        raise ValueError('test_fraction is too small')
    train_size = np.int(n_samples-test_size)
    
    # Permute x,y
    perm = np.random.permutation(n_samples)
    permi= np.argsort(perm)
    x0,y0= get_xy_by_inds(x,y,permi)
                    
    train_x = x0[:train_size,:]
    train_y = y0[:train_size,:]
    
    test_x  = x0[train_size:,:]
    test_y  = y0[train_size:,:]
    
    batches = generate_batches(train_size,batch_size)
    
    return test_x,test_y,train_x,train_y,batches

# %%
def func_deep_learner_arbshape(x,m,n,h,is_test,global_step,prob_keep,act_func=tf.nn.relu):
    # x is the input variable, probably a TensorFlow placeholder object
    # m is the input dimension
    # n is the output dimension
    # h is a LIST of hidden neurons
    # act_func is the activation function to be applied
    # is_test is a flag is use to control batch normalisation behaviour during inferene on test data
    # iteration is the iteration counter used inside the training loop; required for batch normalisation
    
    num_layers = len(h)
    
    bn_moving_avg_updates = []

    with tf.variable_scope('func_learner'):
        # 0th hidden layer
        hidden_layer, update_moving_avg = get_layer_complete(x,m,h[0],'hidden_layer_0',is_test,prob_keep,global_step)
        bn_moving_avg_updates.append(update_moving_avg)

        # Other hidden layers
        for i in range(num_layers-1):
            hidden_layer, update_moving_avg = get_layer_complete(hidden_layer,h[i],h[i+1],'hidden_layer_'+str(i+1),is_test,prob_keep,global_step)
            bn_moving_avg_updates.append(update_moving_avg)

        # Output layer
        weights1= tf.get_variable(name='output_layer_weights',
                              shape=[h[-1],n],
                              initializer=tf.random_normal_initializer(),
                              dtype=DTYPE)

    return tf.matmul(hidden_layer,weights1), bn_moving_avg_updates

# %%
def train_RBM_complete_mccv(input_size=1,output_size=1,hidden_sizes=[5,5],x_data=None,y_data=None,
                  batch_size=32, epochs =5, test_fraction=0.1, test_interval=250, initial_learning_rate = 0.02,
                  epoch_learning_rate_decay = 0.5, epoch_learning_rate_interval = 10,
                  sgd_switch_epoch = 3,
                  prob_keep = 0.8,
                  fname_model_out='/tmp/model.ckpt'):
    # Using montecarlo crossvalidation
    config = tf.ConfigProto(
        device_count = {'GPU': 1}
    )
    
    with tf.Session(config=config) as sess:
        
        # Generate test data initially for convenience
        test_x,test_y,train_x_full,train_y_full,batches = generate_testtrain(x_data,y_data,test_fraction,batch_size)
        n_samples = len(y_data)
        max_steps = batches.shape[1]
            
        with tf.name_scope('input'):
            # Placeholder variables which will be fed data at train time
            x  = tf.placeholder(DTYPE,[None,input_size],name='x_input')
            y  = tf.placeholder(DTYPE,[None,output_size],name='y_input')
        
        with tf.name_scope('control_inputs'):
            global_step = tf.Variable(0, trainable=False,name='global_step')
            epoch_ind = tf.Variable(0,trainable=False,name='epoch_ind')
            increment_epoch_ind = tf.assign_add(epoch_ind,1,name='increment_epoch_ind')
            is_test = tf.contrib.eager.Variable(False, trainable=False,name='is_test')

        # Predictions of the NN
        y_pred, bn_moving_avg_updates = func_deep_learner_arbshape(x,input_size,output_size,hidden_sizes,is_test,global_step,1)

        with tf.name_scope('mean_squared_error'):
            mse = tf.losses.mean_squared_error(y,y_pred)
        tf.summary.scalar('mean_squared_error',mse)

        with tf.name_scope('train'):
            global_step_in_epoch = global_step - epoch_ind*max_steps
            #learning_rate = tf.train.exponential_decay(initial_learning_rate, global_step_in_epoch, decay_steps, decay_rate, staircase=True)
            learning_rate = tf.train.exponential_decay(initial_learning_rate, epoch_ind, epoch_learning_rate_interval, epoch_learning_rate_decay, staircase=True)
            tf.summary.scalar('learning_rate', learning_rate)
            train_step      = tf.train.AdamOptimizer(learning_rate).minimize(mse, global_step = global_step)
            #train_step = tf.train.MomentumOptimizer(learning_rate,0.9,use_nesterov=True).minimize(mse, global_step = global_step)
            train_step_sgd = tf.train.MomentumOptimizer(learning_rate,0.9,use_nesterov=True).minimize(mse, global_step = global_step)

        # Create merged summary object and file writers
        merged_summaries = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(log_dir + '/train', sess.graph)
        test_writer = tf.summary.FileWriter(log_dir + '/test', sess.graph)
        
        # Add ops to save and restore all the variables.
        saver = tf.train.Saver()

        
        # Initialise variables
        sess.run(tf.global_variables_initializer())
        
        # Train the model
        start_time = time.time()
        old_time = start_time
        for j in range(epochs):
            # At each epoch, regenerate test data, train data, and batches
            test_x,test_y,train_x_full,train_y_full,batches = generate_testtrain(x_data,y_data,test_fraction,batch_size)
            n_batches = batches.shape[1]
            n_test = len(test_y)
            epoch_init_time = time.time()
                
            print('Starting Epoch %d, with %d batches' % (j,max_steps))
            for i in range(n_batches):
                if i % test_interval ==0:
                    # Check how our model performs against the test data
                    [summary, mse_val] = sess.run([merged_summaries,mse], feed_dict={x: test_x, y: test_y, is_test: True})
                    test_writer.add_summary(summary,i + j*max_steps)
                    curr_time = time.time()
                    print('\tEpoch %d, Step %04d, MSE: %4.3e,  LearnRate: %4.3e, Time taken : %4.3fs' % (sess.run(epoch_ind),i, mse_val, sess.run(learning_rate),curr_time-old_time))
                    old_time = curr_time
                else:
                    # Generate new sample data and train our model
                    train_x, train_y = get_xy_by_inds(train_x_full,train_y_full,batches[:,i])
                    if (np.mod(j,epoch_learning_rate_interval)<sgd_switch_epoch):
                        summary, _ = sess.run([merged_summaries, train_step], feed_dict={x: train_x, y: train_y, is_test: False})
                    else:
                        summary, _ = sess.run([merged_summaries, train_step_sgd], feed_dict={x: train_x, y: train_y, is_test: False})
                    sess.run(bn_moving_avg_updates, feed_dict={x: train_x, y: train_y, is_test: False})
                    train_writer.add_summary(summary,i+ j*max_steps)
            # End of epoch, calculate avg stats
            epoch_end_time = time.time()
            sess.run(increment_epoch_ind)
            avg_mrad = np.sqrt(mse_val)*1000
            print('Epoch %d time: %4.3fs, average error = %4.3fmrad' % (j,epoch_end_time-epoch_init_time,avg_mrad))
        train_writer.close()
        test_writer.close()     
        print('\nTotal time:\t %4.3fs' % (time.time()-start_time))
        
        save_path = saver.save(sess, fname_model_out)
        print("Model saved in path: %s" % save_path)

# %%
def train_RBM_complete_mccv_inference(input_size=1,output_size=1,hidden_sizes=[5,5],x_data=None,y_data=None,
                  fname_model_in='/tmp/model.ckpt'):
    # Using montecarlo crossvalidation
    config = tf.ConfigProto(
        device_count = {'GPU': 0}
    )
    
    with tf.Session(config=config) as sess:

            
        with tf.name_scope('input'):
            # Placeholder variables which will be fed data at train time
            x  = tf.placeholder(DTYPE,[None,input_size],name='x_input')
            y  = tf.placeholder(DTYPE,[None,output_size],name='y_input')
        
        with tf.name_scope('control_inputs'):
            global_step = tf.Variable(0, trainable=False,name='global_step')
            epoch_ind = tf.Variable(0,trainable=False,name='epoch_ind')
            increment_epoch_ind = tf.assign_add(epoch_ind,1,name='increment_epoch_ind')
            is_test = tf.contrib.eager.Variable(False, trainable=False,name='is_test')

        # Predictions of the NN
        y_pred, bn_moving_avg_updates = func_deep_learner_arbshape(x,input_size,output_size,hidden_sizes,is_test,global_step,1)
        
        # Restore all the variables.
        saver = tf.train.Saver()
        saver.restore(sess,  fname_model_in)
        
        # Run inference
        predicted_values = sess.run(y_pred, feed_dict={x: x_data, is_test: False})
    return predicted_values

# %%
def train_model_ai_kup(acc,phase):
    n_samples  = acc.shape[0]
    seq_length = acc.shape[1]
    
    input_size  = seq_length
    output_size = 1
    
    hidden_sizes = [256,128,96,64,32,16,8]
    batch_size  = 768
    
    mccv_steps   = 5000
    test_fraction= 0.1
    
    # sgd_switch_epoch now means that if mod(epoch_ind,epoch_learning_rate_interval)>sgd_switch_epoch, then SGD is used
    train_RBM_complete_mccv(input_size=input_size,output_size=output_size,hidden_sizes=hidden_sizes,initial_learning_rate=0.1,
                            x_data=acc,y_data=phase,batch_size=batch_size, epochs=mccv_steps,test_fraction=test_fraction,test_interval=50,
                            epoch_learning_rate_decay = 0.5, epoch_learning_rate_interval = 1000,sgd_switch_epoch = 750,
                            prob_keep = 0.6,fname_model_out='./model_SGD_Nesterov_2.ckpt')

# %%
def run_model_ai_kup(acc,phase):
    n_samples  = acc.shape[0]
    seq_length = acc.shape[1]
    
    input_size  = seq_length
    output_size = 1
    
    hidden_sizes = [256,128,96,64,32,16,8]
    
    preds = train_RBM_complete_mccv_produceTrace(input_size=input_size,output_size=output_size,hidden_sizes=hidden_sizes,
                            x_data=acc,y_data=phase,fname_model_in='./model_SGD_Nesterov_2.ckpt')
    
    return preds

# %%
fname = './campaign4a_proc_trunc.h5'
f0 = h5py.File(fname,'r')
dset_up = f0['/ai_kup']
dset_down = f0['/ai_kdown']

# %%
ai_kup_phase = np.array(list(dset_up['phase']))
ai_kup_acc = np.array(list(dset_up['acc']))
ai_kup_timestamp = np.array(list(dset_up['timestamp']))

ai_kdown_phase = np.array(list(dset_down['phase']))
ai_kdown_acc = np.array(list(dset_down['acc']))
ai_kdown_timestamp = np.array(list(dset_down['timestamp']))

# %%
list(dset_up.items())
# Out:
# [('acc', <HDF5 dataset "acc": shape (90660, 195), type "<f8">),
#  ('avg_30min', <HDF5 dataset "avg_30min": shape (90660,), type "<f8">),
#  ('phase', <HDF5 dataset "phase": shape (90660,), type "<f8">),
#  ('timestamp', <HDF5 dataset "timestamp": shape (90660,), type "<f8">)]

# %%
# Run inference
reset_tf()
preds_up= run_model_ai_kup(ai_kup_acc,ai_kup_phase)
reset_tf()
preds_down= run_model_ai_kup(ai_kdown_acc,ai_kdown_phase)
# Out:
# INFO:tensorflow:Restoring parameters from ./model_SGD_Nesterov_2.ckpt
# INFO:tensorflow:Restoring parameters from ./model_SGD_Nesterov_2.ckpt

# %%
# Write to file
with h5py.File('./campaign4a_proc_trunc_preds.h5','a') as file:
    file.create_dataset('/ai_kup/preds', data=preds_up.reshape(len(preds_up)), dtype='float64')
    file.create_dataset('/ai_kdown/preds', data=preds_down.reshape(len(preds_down)), dtype='float64')

# %%
fname2 = './campaign4a_proc_trunc_preds.h5'
with h5py.File(fname2,'r') as file:
    print(list(file.keys()))
    print(list(file['/ai_kup'].items()))
# Out:
# ['T', 'ai_kdown', 'ai_kup', 'tau']
# [('acc', <HDF5 dataset "acc": shape (90660, 195), type "<f8">), ('avg_30min', <HDF5 dataset "avg_30min": shape (90660,), type "<f8">), ('phase', <HDF5 dataset "phase": shape (90660,), type "<f8">), ('preds', <HDF5 dataset "preds": shape (90660,), type "<f8">), ('timestamp', <HDF5 dataset "timestamp": shape (90660,), type "<f8">)]

# %%
list(f1.keys())
# Out:
# ['T', 'ai_kdown', 'ai_kup', 'tau']

# %%
f1.close()

# %%
reset_tf()

# %%
preds_up.reshape(len(preds_up)).shape
# Out:
# (90660,)

# %%
ai_kup_phase = ai_kup_phase.reshape([len(ai_kup_phase),1])
ai_kup_timestamp = ai_kup_timestamp.reshape([len(ai_kup_timestamp),1])

# %%
data_out = np.concatenate((ai_kup_timestamp,ai_kup_phase,preds),axis=1)

# %%
np.savetxt('61mrad.txt',data_out, delimiter=",")

# %%
h5out = h5py.File('61mrad.h5','w')
h5out.create_dataset('ai_kup_phase',data=ai_kup_phase)
h5out.create_dataset('ai_kup_timestamp',data=ai_kup_timestamp)
h5out.create_dataset('ai_kup_predictions',data=preds)
h5out.close()

# %% [markdown]
# https://arxiv.org/abs/1712.07628

# %%
train_model_ai_kup(ai_kup_acc,ai_kup_phase)
# Out:
# Starting Epoch 0, with 107 batches
# 	Epoch 0, Step 0000, MSE: 5.464e+00,  LearnRate: 1.000e-01, Time taken : 1.274s
# 	Epoch 0, Step 0050, MSE: 2.577e-02,  LearnRate: 1.000e-01, Time taken : 4.411s
# 	Epoch 0, Step 0100, MSE: 2.573e-02,  LearnRate: 1.000e-01, Time taken : 2.350s
# Epoch 0 time: 7.803s, average error = 160.412mrad
# Starting Epoch 1, with 107 batches
# 	Epoch 1, Step 0000, MSE: 2.592e-02,  LearnRate: 1.000e-01, Time taken : 1.007s
# 	Epoch 1, Step 0050, MSE: 2.580e-02,  LearnRate: 1.000e-01, Time taken : 2.529s
# 	Epoch 1, Step 0100, MSE: 2.585e-02,  LearnRate: 1.000e-01, Time taken : 2.280s
# Epoch 1 time: 5.357s, average error = 160.783mrad
# Starting Epoch 2, with 107 batches
# 	Epoch 2, Step 0000, MSE: 2.546e-02,  LearnRate: 1.000e-01, Time taken : 1.068s
# 	Epoch 2, Step 0050, MSE: 2.618e-02,  LearnRate: 1.000e-01, Time taken : 2.500s
# 	Epoch 2, Step 0100, MSE: 2.550e-02,  LearnRate: 1.000e-01, Time taken : 2.263s
# Epoch 2 time: 5.338s, average error = 159.676mrad
# Starting Epoch 3, with 107 batches
# 	Epoch 3, Step 0000, MSE: 2.585e-02,  LearnRate: 1.000e-01, Time taken : 1.034s
# 	Epoch 3, Step 0050, MSE: 2.616e-02,  LearnRate: 1.000e-01, Time taken : 2.451s
# 	Epoch 3, Step 0100, MSE: 2.580e-02,  LearnRate: 1.000e-01, Time taken : 2.204s
# Epoch 3 time: 5.243s, average error = 160.621mrad
# Starting Epoch 4, with 107 batches
# 	Epoch 4, Step 0000, MSE: 2.541e-02,  LearnRate: 1.000e-01, Time taken : 1.181s
# 	Epoch 4, Step 0050, MSE: 2.537e-02,  LearnRate: 1.000e-01, Time taken : 2.210s
# 	Epoch 4, Step 0100, MSE: 2.562e-02,  LearnRate: 1.000e-01, Time taken : 2.440s
# Epoch 4 time: 5.262s, average error = 160.050mrad
# Starting Epoch 5, with 107 batches
# 	Epoch 5, Step 0000, MSE: 2.520e-02,  LearnRate: 1.000e-01, Time taken : 0.959s
# 	Epoch 5, Step 0050, MSE: 2.491e-02,  LearnRate: 1.000e-01, Time taken : 2.207s
# 	Epoch 5, Step 0100, MSE: 2.505e-02,  LearnRate: 1.000e-01, Time taken : 2.234s
# Epoch 5 time: 5.048s, average error = 158.279mrad
# Starting Epoch 6, with 107 batches
# 	Epoch 6, Step 0000, MSE: 2.532e-02,  LearnRate: 1.000e-01, Time taken : 0.976s
# 	Epoch 6, Step 0050, MSE: 2.545e-02,  LearnRate: 1.000e-01, Time taken : 2.363s
# 	Epoch 6, Step 0100, MSE: 2.534e-02,  LearnRate: 1.000e-01, Time taken : 2.280s
# Epoch 6 time: 5.290s, average error = 159.171mrad
# Starting Epoch 7, with 107 batches
# 	Epoch 7, Step 0000, MSE: 2.604e-02,  LearnRate: 1.000e-01, Time taken : 2.978s
# 	Epoch 7, Step 0050, MSE: 2.613e-02,  LearnRate: 1.000e-01, Time taken : 2.500s
# 	Epoch 7, Step 0100, MSE: 2.583e-02,  LearnRate: 1.000e-01, Time taken : 2.388s
# Epoch 7 time: 5.635s, average error = 160.716mrad
# Starting Epoch 8, with 107 batches
# 	Epoch 8, Step 0000, MSE: 2.591e-02,  LearnRate: 1.000e-01, Time taken : 2.793s
# 	Epoch 8, Step 0050, MSE: 2.583e-02,  LearnRate: 1.000e-01, Time taken : 2.276s
# 	Epoch 8, Step 0100, MSE: 1.421e-02,  LearnRate: 1.000e-01, Time taken : 2.244s
# Epoch 8 time: 5.171s, average error = 119.212mrad
# Starting Epoch 9, with 107 batches
# 	Epoch 9, Step 0000, MSE: 1.280e-02,  LearnRate: 1.000e-01, Time taken : 1.126s
# 	Epoch 9, Step 0050, MSE: 1.058e-02,  LearnRate: 1.000e-01, Time taken : 2.252s
# 	Epoch 9, Step 0100, MSE: 9.569e-03,  LearnRate: 1.000e-01, Time taken : 2.151s
# Epoch 9 time: 5.022s, average error = 97.819mrad
# Starting Epoch 10, with 107 batches
# 	Epoch 10, Step 0000, MSE: 1.050e-02,  LearnRate: 1.000e-01, Time taken : 0.970s
# 	Epoch 10, Step 0050, MSE: 1.081e-02,  LearnRate: 1.000e-01, Time taken : 2.351s
# 	Epoch 10, Step 0100, MSE: 9.663e-03,  LearnRate: 1.000e-01, Time taken : 2.411s
# Epoch 10 time: 5.358s, average error = 98.302mrad
# Starting Epoch 11, with 107 batches
# 	Epoch 11, Step 0000, MSE: 9.753e-03,  LearnRate: 1.000e-01, Time taken : 0.843s
# 	Epoch 11, Step 0050, MSE: 9.147e-03,  LearnRate: 1.000e-01, Time taken : 2.271s
# 	Epoch 11, Step 0100, MSE: 9.654e-03,  LearnRate: 1.000e-01, Time taken : 2.354s
# Epoch 11 time: 5.205s, average error = 98.254mrad
# Starting Epoch 12, with 107 batches
# 	Epoch 12, Step 0000, MSE: 9.223e-03,  LearnRate: 1.000e-01, Time taken : 0.955s
# 	Epoch 12, Step 0050, MSE: 9.298e-03,  LearnRate: 1.000e-01, Time taken : 2.424s
# 	Epoch 12, Step 0100, MSE: 9.671e-03,  LearnRate: 1.000e-01, Time taken : 2.347s
# Epoch 12 time: 5.381s, average error = 98.339mrad
# Starting Epoch 13, with 107 batches
# 	Epoch 13, Step 0000, MSE: 9.103e-03,  LearnRate: 1.000e-01, Time taken : 0.759s
# 	Epoch 13, Step 0050, MSE: 9.440e-03,  LearnRate: 1.000e-01, Time taken : 2.242s
# 	Epoch 13, Step 0100, MSE: 9.026e-03,  LearnRate: 1.000e-01, Time taken : 2.220s
# Epoch 13 time: 4.973s, average error = 95.003mrad
# Starting Epoch 14, with 107 batches
# 	Epoch 14, Step 0000, MSE: 1.058e-02,  LearnRate: 1.000e-01, Time taken : 0.894s
# 	Epoch 14, Step 0050, MSE: 9.154e-03,  LearnRate: 1.000e-01, Time taken : 2.318s
# 	Epoch 14, Step 0100, MSE: 9.564e-03,  LearnRate: 1.000e-01, Time taken : 2.373s
# Epoch 14 time: 5.287s, average error = 97.795mrad
# Starting Epoch 15, with 107 batches
# 	Epoch 15, Step 0000, MSE: 9.800e-03,  LearnRate: 1.000e-01, Time taken : 1.074s
# 	Epoch 15, Step 0050, MSE: 9.528e-03,  LearnRate: 1.000e-01, Time taken : 2.374s
# 	Epoch 15, Step 0100, MSE: 9.022e-03,  LearnRate: 1.000e-01, Time taken : 2.408s
# Epoch 15 time: 5.339s, average error = 94.985mrad
# Starting Epoch 16, with 107 batches
# 	Epoch 16, Step 0000, MSE: 9.802e-03,  LearnRate: 1.000e-01, Time taken : 0.946s
# 	Epoch 16, Step 0050, MSE: 9.771e-03,  LearnRate: 1.000e-01, Time taken : 2.453s
# 	Epoch 16, Step 0100, MSE: 9.331e-03,  LearnRate: 1.000e-01, Time taken : 2.022s
# Epoch 16 time: 5.045s, average error = 96.599mrad
# Starting Epoch 17, with 107 batches
# 	Epoch 17, Step 0000, MSE: 8.846e-03,  LearnRate: 1.000e-01, Time taken : 1.322s
# 	Epoch 17, Step 0050, MSE: 8.864e-03,  LearnRate: 1.000e-01, Time taken : 2.258s
# 	Epoch 17, Step 0100, MSE: 9.196e-03,  LearnRate: 1.000e-01, Time taken : 2.223s
# Epoch 17 time: 5.026s, average error = 95.897mrad
# Starting Epoch 18, with 107 batches
# 	Epoch 18, Step 0000, MSE: 9.297e-03,  LearnRate: 1.000e-01, Time taken : 3.218s
# 	Epoch 18, Step 0050, MSE: 9.182e-03,  LearnRate: 1.000e-01, Time taken : 2.211s
# 	Epoch 18, Step 0100, MSE: 9.502e-03,  LearnRate: 1.000e-01, Time taken : 2.216s
# Epoch 18 time: 5.023s, average error = 97.479mrad
# Starting Epoch 19, with 107 batches
# 	Epoch 19, Step 0000, MSE: 9.061e-03,  LearnRate: 1.000e-01, Time taken : 1.085s
# 	Epoch 19, Step 0050, MSE: 9.157e-03,  LearnRate: 1.000e-01, Time taken : 2.259s
# 	Epoch 19, Step 0100, MSE: 9.061e-03,  LearnRate: 1.000e-01, Time taken : 2.352s
# Epoch 19 time: 5.218s, average error = 95.187mrad
# Starting Epoch 20, with 107 batches
# 	Epoch 20, Step 0000, MSE: 9.046e-03,  LearnRate: 1.000e-01, Time taken : 0.984s
# 	Epoch 20, Step 0050, MSE: 8.724e-03,  LearnRate: 1.000e-01, Time taken : 2.240s
# 	Epoch 20, Step 0100, MSE: 8.964e-03,  LearnRate: 1.000e-01, Time taken : 2.314s
# Epoch 20 time: 5.143s, average error = 94.677mrad
# Starting Epoch 21, with 107 batches
# 	Epoch 21, Step 0000, MSE: 8.417e-03,  LearnRate: 1.000e-01, Time taken : 0.877s
# 	Epoch 21, Step 0050, MSE: 8.675e-03,  LearnRate: 1.000e-01, Time taken : 2.188s
# 	Epoch 21, Step 0100, MSE: 9.082e-03,  LearnRate: 1.000e-01, Time taken : 2.160s
# Epoch 21 time: 4.926s, average error = 95.301mrad
# Starting Epoch 22, with 107 batches
# 	Epoch 22, Step 0000, MSE: 9.030e-03,  LearnRate: 1.000e-01, Time taken : 0.876s
# 	Epoch 22, Step 0050, MSE: 9.215e-03,  LearnRate: 1.000e-01, Time taken : 2.351s
# 	Epoch 22, Step 0100, MSE: 9.166e-03,  LearnRate: 1.000e-01, Time taken : 2.314s
# Epoch 22 time: 5.263s, average error = 95.741mrad
# Starting Epoch 23, with 107 batches
# 	Epoch 23, Step 0000, MSE: 8.992e-03,  LearnRate: 1.000e-01, Time taken : 0.805s
# 	Epoch 23, Step 0050, MSE: 8.799e-03,  LearnRate: 1.000e-01, Time taken : 2.242s
# 	Epoch 23, Step 0100, MSE: 8.821e-03,  LearnRate: 1.000e-01, Time taken : 2.180s
# Epoch 23 time: 4.925s, average error = 93.923mrad
# Starting Epoch 24, with 107 batches
# 	Epoch 24, Step 0000, MSE: 8.793e-03,  LearnRate: 1.000e-01, Time taken : 0.896s
# 	Epoch 24, Step 0050, MSE: 9.080e-03,  LearnRate: 1.000e-01, Time taken : 2.434s
# 	Epoch 24, Step 0100, MSE: 9.033e-03,  LearnRate: 1.000e-01, Time taken : 2.312s
# Epoch 24 time: 5.320s, average error = 95.044mrad
# Starting Epoch 25, with 107 batches
# 	Epoch 25, Step 0000, MSE: 8.975e-03,  LearnRate: 1.000e-01, Time taken : 0.871s
# 	Epoch 25, Step 0050, MSE: 8.743e-03,  LearnRate: 1.000e-01, Time taken : 2.294s
# 	Epoch 25, Step 0100, MSE: 8.701e-03,  LearnRate: 1.000e-01, Time taken : 2.347s
# Epoch 25 time: 5.204s, average error = 93.280mrad
# Starting Epoch 26, with 107 batches
# 	Epoch 26, Step 0000, MSE: 9.004e-03,  LearnRate: 1.000e-01, Time taken : 1.864s
# 	Epoch 26, Step 0050, MSE: 9.079e-03,  LearnRate: 1.000e-01, Time taken : 2.355s
# 	Epoch 26, Step 0100, MSE: 9.003e-03,  LearnRate: 1.000e-01, Time taken : 2.628s
# Epoch 26 time: 5.626s, average error = 94.885mrad
# Starting Epoch 27, with 107 batches
# 	Epoch 27, Step 0000, MSE: 8.503e-03,  LearnRate: 1.000e-01, Time taken : 1.489s
# 	Epoch 27, Step 0050, MSE: 8.746e-03,  LearnRate: 1.000e-01, Time taken : 2.324s
# 	Epoch 27, Step 0100, MSE: 8.722e-03,  LearnRate: 1.000e-01, Time taken : 2.230s
# Epoch 27 time: 5.193s, average error = 93.389mrad
# Starting Epoch 28, with 107 batches
# 	Epoch 28, Step 0000, MSE: 8.674e-03,  LearnRate: 1.000e-01, Time taken : 1.994s
# 	Epoch 28, Step 0050, MSE: 8.595e-03,  LearnRate: 1.000e-01, Time taken : 2.198s
# 	Epoch 28, Step 0100, MSE: 8.865e-03,  LearnRate: 1.000e-01, Time taken : 2.595s
# Epoch 28 time: 5.398s, average error = 94.155mrad
# Starting Epoch 29, with 107 batches
# 	Epoch 29, Step 0000, MSE: 8.783e-03,  LearnRate: 1.000e-01, Time taken : 0.970s
# 	Epoch 29, Step 0050, MSE: 8.880e-03,  LearnRate: 1.000e-01, Time taken : 2.248s
# 	Epoch 29, Step 0100, MSE: 8.683e-03,  LearnRate: 1.000e-01, Time taken : 2.166s
# Epoch 29 time: 5.021s, average error = 93.184mrad
# Starting Epoch 30, with 107 batches
# 	Epoch 30, Step 0000, MSE: 8.507e-03,  LearnRate: 1.000e-01, Time taken : 1.499s
# 	Epoch 30, Step 0050, MSE: 8.796e-03,  LearnRate: 1.000e-01, Time taken : 2.250s
# 	Epoch 30, Step 0100, MSE: 8.647e-03,  LearnRate: 1.000e-01, Time taken : 2.286s
# Epoch 30 time: 5.131s, average error = 92.989mrad
# Starting Epoch 31, with 107 batches
# 	Epoch 31, Step 0000, MSE: 8.913e-03,  LearnRate: 1.000e-01, Time taken : 1.081s
# 	Epoch 31, Step 0050, MSE: 8.749e-03,  LearnRate: 1.000e-01, Time taken : 2.309s
# 	Epoch 31, Step 0100, MSE: 8.743e-03,  LearnRate: 1.000e-01, Time taken : 2.309s
# Epoch 31 time: 5.234s, average error = 93.502mrad
# Starting Epoch 32, with 107 batches
# 	Epoch 32, Step 0000, MSE: 8.595e-03,  LearnRate: 1.000e-01, Time taken : 4.248s
# 	Epoch 32, Step 0050, MSE: 8.732e-03,  LearnRate: 1.000e-01, Time taken : 2.221s
# 	Epoch 32, Step 0100, MSE: 8.705e-03,  LearnRate: 1.000e-01, Time taken : 2.273s
# Epoch 32 time: 5.089s, average error = 93.302mrad
# Starting Epoch 33, with 107 batches
# 	Epoch 33, Step 0000, MSE: 9.049e-03,  LearnRate: 1.000e-01, Time taken : 2.845s
# 	Epoch 33, Step 0050, MSE: 9.104e-03,  LearnRate: 1.000e-01, Time taken : 2.163s
# 	Epoch 33, Step 0100, MSE: 9.060e-03,  LearnRate: 1.000e-01, Time taken : 2.189s
# Epoch 33 time: 4.959s, average error = 95.185mrad
# Starting Epoch 34, with 107 batches
# 	Epoch 34, Step 0000, MSE: 8.707e-03,  LearnRate: 1.000e-01, Time taken : 0.971s
# 	Epoch 34, Step 0050, MSE: 8.625e-03,  LearnRate: 1.000e-01, Time taken : 2.338s
# 	Epoch 34, Step 0100, MSE: 8.727e-03,  LearnRate: 1.000e-01, Time taken : 2.315s
# Epoch 34 time: 5.279s, average error = 93.419mrad
# Starting Epoch 35, with 107 batches
# 	Epoch 35, Step 0000, MSE: 8.903e-03,  LearnRate: 1.000e-01, Time taken : 0.897s
# 	Epoch 35, Step 0050, MSE: 9.003e-03,  LearnRate: 1.000e-01, Time taken : 2.574s
# 	Epoch 35, Step 0100, MSE: 8.923e-03,  LearnRate: 1.000e-01, Time taken : 2.333s
# Epoch 35 time: 5.516s, average error = 94.463mrad
# Starting Epoch 36, with 107 batches
# 	Epoch 36, Step 0000, MSE: 8.550e-03,  LearnRate: 1.000e-01, Time taken : 0.864s
# 	Epoch 36, Step 0050, MSE: 8.745e-03,  LearnRate: 1.000e-01, Time taken : 2.406s
# 	Epoch 36, Step 0100, MSE: 8.953e-03,  LearnRate: 1.000e-01, Time taken : 2.234s
# Epoch 36 time: 5.220s, average error = 94.622mrad
# Starting Epoch 37, with 107 batches
# 	Epoch 37, Step 0000, MSE: 8.629e-03,  LearnRate: 1.000e-01, Time taken : 0.924s
# 	Epoch 37, Step 0050, MSE: 8.847e-03,  LearnRate: 1.000e-01, Time taken : 2.124s
# 	Epoch 37, Step 0100, MSE: 8.564e-03,  LearnRate: 1.000e-01, Time taken : 2.177s
# Epoch 37 time: 4.838s, average error = 92.543mrad
# Starting Epoch 38, with 107 batches
# 	Epoch 38, Step 0000, MSE: 8.833e-03,  LearnRate: 1.000e-01, Time taken : 0.762s
# 	Epoch 38, Step 0050, MSE: 8.932e-03,  LearnRate: 1.000e-01, Time taken : 2.183s
# 	Epoch 38, Step 0100, MSE: 8.997e-03,  LearnRate: 1.000e-01, Time taken : 2.180s
# Epoch 38 time: 4.911s, average error = 94.852mrad
# Starting Epoch 39, with 107 batches
# 	Epoch 39, Step 0000, MSE: 8.715e-03,  LearnRate: 1.000e-01, Time taken : 0.812s
# 	Epoch 39, Step 0050, MSE: 8.741e-03,  LearnRate: 1.000e-01, Time taken : 2.105s
# 	Epoch 39, Step 0100, MSE: 8.717e-03,  LearnRate: 1.000e-01, Time taken : 2.200s
# Epoch 39 time: 4.835s, average error = 93.364mrad
# Starting Epoch 40, with 107 batches
# 	Epoch 40, Step 0000, MSE: 8.685e-03,  LearnRate: 1.000e-01, Time taken : 0.827s
# 	Epoch 40, Step 0050, MSE: 8.814e-03,  LearnRate: 1.000e-01, Time taken : 2.220s
# 	Epoch 40, Step 0100, MSE: 8.718e-03,  LearnRate: 1.000e-01, Time taken : 2.174s
# Epoch 40 time: 4.982s, average error = 93.370mrad
# Starting Epoch 41, with 107 batches
# 	Epoch 41, Step 0000, MSE: 8.866e-03,  LearnRate: 1.000e-01, Time taken : 1.820s
# 	Epoch 41, Step 0050, MSE: 9.096e-03,  LearnRate: 1.000e-01, Time taken : 2.289s
# 	Epoch 41, Step 0100, MSE: 9.412e-03,  LearnRate: 1.000e-01, Time taken : 2.237s
# Epoch 41 time: 5.136s, average error = 97.017mrad
# Starting Epoch 42, with 107 batches
# 	Epoch 42, Step 0000, MSE: 9.060e-03,  LearnRate: 1.000e-01, Time taken : 0.828s
# 	Epoch 42, Step 0050, MSE: 8.982e-03,  LearnRate: 1.000e-01, Time taken : 2.173s
# 	Epoch 42, Step 0100, MSE: 8.918e-03,  LearnRate: 1.000e-01, Time taken : 2.401s
# Epoch 42 time: 5.116s, average error = 94.433mrad
# Starting Epoch 43, with 107 batches
# 	Epoch 43, Step 0000, MSE: 8.919e-03,  LearnRate: 1.000e-01, Time taken : 0.952s
# 	Epoch 43, Step 0050, MSE: 8.838e-03,  LearnRate: 1.000e-01, Time taken : 2.446s
# 	Epoch 43, Step 0100, MSE: 8.952e-03,  LearnRate: 1.000e-01, Time taken : 2.219s
# Epoch 43 time: 5.240s, average error = 94.614mrad
# Starting Epoch 44, with 107 batches
# 	Epoch 44, Step 0000, MSE: 8.789e-03,  LearnRate: 1.000e-01, Time taken : 0.801s
# 	Epoch 44, Step 0050, MSE: 8.814e-03,  LearnRate: 1.000e-01, Time taken : 2.626s
# 	Epoch 44, Step 0100, MSE: 8.857e-03,  LearnRate: 1.000e-01, Time taken : 2.291s
# Epoch 44 time: 5.467s, average error = 94.114mrad
# Starting Epoch 45, with 107 batches
# 	Epoch 45, Step 0000, MSE: 8.293e-03,  LearnRate: 1.000e-01, Time taken : 2.027s
# 	Epoch 45, Step 0050, MSE: 8.439e-03,  LearnRate: 1.000e-01, Time taken : 2.461s
# 	Epoch 45, Step 0100, MSE: 8.547e-03,  LearnRate: 1.000e-01, Time taken : 2.549s
# Epoch 45 time: 5.667s, average error = 92.448mrad
# Starting Epoch 46, with 107 batches
# 	Epoch 46, Step 0000, MSE: 8.546e-03,  LearnRate: 1.000e-01, Time taken : 0.871s
# 	Epoch 46, Step 0050, MSE: 8.645e-03,  LearnRate: 1.000e-01, Time taken : 2.318s
# 	Epoch 46, Step 0100, MSE: 8.601e-03,  LearnRate: 1.000e-01, Time taken : 2.178s
# Epoch 46 time: 5.082s, average error = 92.744mrad
# Starting Epoch 47, with 107 batches
# 	Epoch 47, Step 0000, MSE: 8.786e-03,  LearnRate: 1.000e-01, Time taken : 1.704s
# 	Epoch 47, Step 0050, MSE: 8.670e-03,  LearnRate: 1.000e-01, Time taken : 2.301s
# 	Epoch 47, Step 0100, MSE: 8.733e-03,  LearnRate: 1.000e-01, Time taken : 2.183s
# Epoch 47 time: 5.087s, average error = 93.448mrad
# Starting Epoch 48, with 107 batches
# 	Epoch 48, Step 0000, MSE: 8.711e-03,  LearnRate: 1.000e-01, Time taken : 0.913s
# 	Epoch 48, Step 0050, MSE: 8.452e-03,  LearnRate: 1.000e-01, Time taken : 2.556s
# 	Epoch 48, Step 0100, MSE: 8.553e-03,  LearnRate: 1.000e-01, Time taken : 2.349s
# Epoch 48 time: 5.537s, average error = 92.485mrad
# Starting Epoch 49, with 107 batches
# 	Epoch 49, Step 0000, MSE: 8.885e-03,  LearnRate: 1.000e-01, Time taken : 1.691s
# 	Epoch 49, Step 0050, MSE: 8.755e-03,  LearnRate: 1.000e-01, Time taken : 2.252s
# 	Epoch 49, Step 0100, MSE: 9.196e-03,  LearnRate: 1.000e-01, Time taken : 2.175s
# Epoch 49 time: 4.987s, average error = 95.897mrad
# Starting Epoch 50, with 107 batches
# 	Epoch 50, Step 0000, MSE: 8.598e-03,  LearnRate: 1.000e-01, Time taken : 0.880s
# 	Epoch 50, Step 0050, MSE: 8.630e-03,  LearnRate: 1.000e-01, Time taken : 2.299s
# 	Epoch 50, Step 0100, MSE: 8.499e-03,  LearnRate: 1.000e-01, Time taken : 2.181s
# Epoch 50 time: 5.049s, average error = 92.189mrad
# Starting Epoch 51, with 107 batches
# 	Epoch 51, Step 0000, MSE: 8.662e-03,  LearnRate: 1.000e-01, Time taken : 1.157s
# 	Epoch 51, Step 0050, MSE: 8.485e-03,  LearnRate: 1.000e-01, Time taken : 2.278s
# 	Epoch 51, Step 0100, MSE: 8.667e-03,  LearnRate: 1.000e-01, Time taken : 2.158s
# Epoch 51 time: 4.924s, average error = 93.097mrad
# Starting Epoch 52, with 107 batches
# 	Epoch 52, Step 0000, MSE: 8.779e-03,  LearnRate: 1.000e-01, Time taken : 0.830s
# 	Epoch 52, Step 0050, MSE: 8.690e-03,  LearnRate: 1.000e-01, Time taken : 2.109s
# 	Epoch 52, Step 0100, MSE: 8.869e-03,  LearnRate: 1.000e-01, Time taken : 2.517s
# Epoch 52 time: 5.203s, average error = 94.177mrad
# Starting Epoch 53, with 107 batches
# 	Epoch 53, Step 0000, MSE: 8.842e-03,  LearnRate: 1.000e-01, Time taken : 1.735s
# 	Epoch 53, Step 0050, MSE: 8.988e-03,  LearnRate: 1.000e-01, Time taken : 2.127s
# 	Epoch 53, Step 0100, MSE: 8.900e-03,  LearnRate: 1.000e-01, Time taken : 2.097s
# Epoch 53 time: 4.782s, average error = 94.341mrad
# Starting Epoch 54, with 107 batches
# 	Epoch 54, Step 0000, MSE: 8.625e-03,  LearnRate: 1.000e-01, Time taken : 0.783s
# 	Epoch 54, Step 0050, MSE: 8.609e-03,  LearnRate: 1.000e-01, Time taken : 2.130s
# 	Epoch 54, Step 0100, MSE: 8.567e-03,  LearnRate: 1.000e-01, Time taken : 2.447s
# Epoch 54 time: 5.113s, average error = 92.556mrad
# Starting Epoch 55, with 107 batches
# 	Epoch 55, Step 0000, MSE: 8.578e-03,  LearnRate: 1.000e-01, Time taken : 1.597s
# 	Epoch 55, Step 0050, MSE: 8.659e-03,  LearnRate: 1.000e-01, Time taken : 2.165s
# 	Epoch 55, Step 0100, MSE: 8.435e-03,  LearnRate: 1.000e-01, Time taken : 2.400s
# Epoch 55 time: 5.130s, average error = 91.840mrad
# Starting Epoch 56, with 107 batches
# 	Epoch 56, Step 0000, MSE: 8.535e-03,  LearnRate: 1.000e-01, Time taken : 1.025s
# 	Epoch 56, Step 0050, MSE: 8.659e-03,  LearnRate: 1.000e-01, Time taken : 2.288s
# 	Epoch 56, Step 0100, MSE: 8.909e-03,  LearnRate: 1.000e-01, Time taken : 2.185s
# Epoch 56 time: 5.126s, average error = 94.386mrad
# Starting Epoch 57, with 107 batches
# 	Epoch 57, Step 0000, MSE: 8.144e-03,  LearnRate: 1.000e-01, Time taken : 0.983s
# 	Epoch 57, Step 0050, MSE: 8.126e-03,  LearnRate: 1.000e-01, Time taken : 2.512s
# 	Epoch 57, Step 0100, MSE: 8.208e-03,  LearnRate: 1.000e-01, Time taken : 2.128s
# Epoch 57 time: 5.230s, average error = 90.595mrad
# Starting Epoch 58, with 107 batches
# 	Epoch 58, Step 0000, MSE: 8.987e-03,  LearnRate: 1.000e-01, Time taken : 1.902s
# 	Epoch 58, Step 0050, MSE: 8.780e-03,  LearnRate: 1.000e-01, Time taken : 2.346s
# 	Epoch 58, Step 0100, MSE: 8.732e-03,  LearnRate: 1.000e-01, Time taken : 2.245s
# Epoch 58 time: 5.180s, average error = 93.443mrad
# Starting Epoch 59, with 107 batches
# 	Epoch 59, Step 0000, MSE: 8.368e-03,  LearnRate: 1.000e-01, Time taken : 2.638s
# 	Epoch 59, Step 0050, MSE: 8.548e-03,  LearnRate: 1.000e-01, Time taken : 2.381s
# 	Epoch 59, Step 0100, MSE: 8.440e-03,  LearnRate: 1.000e-01, Time taken : 2.230s
# Epoch 59 time: 5.214s, average error = 91.871mrad
# Starting Epoch 60, with 107 batches
# 	Epoch 60, Step 0000, MSE: 8.421e-03,  LearnRate: 1.000e-01, Time taken : 1.390s
# 	Epoch 60, Step 0050, MSE: 8.204e-03,  LearnRate: 1.000e-01, Time taken : 2.369s
# 	Epoch 60, Step 0100, MSE: 8.225e-03,  LearnRate: 1.000e-01, Time taken : 2.326s
# Epoch 60 time: 5.267s, average error = 90.690mrad
# Starting Epoch 61, with 107 batches
# 	Epoch 61, Step 0000, MSE: 8.286e-03,  LearnRate: 1.000e-01, Time taken : 1.990s
# 	Epoch 61, Step 0050, MSE: 8.216e-03,  LearnRate: 1.000e-01, Time taken : 2.261s
# 	Epoch 61, Step 0100, MSE: 8.524e-03,  LearnRate: 1.000e-01, Time taken : 2.178s
# Epoch 61 time: 5.032s, average error = 92.328mrad
# Starting Epoch 62, with 107 batches
# 	Epoch 62, Step 0000, MSE: 8.429e-03,  LearnRate: 1.000e-01, Time taken : 1.103s
# 	Epoch 62, Step 0050, MSE: 8.652e-03,  LearnRate: 1.000e-01, Time taken : 2.443s
# 	Epoch 62, Step 0100, MSE: 9.105e-03,  LearnRate: 1.000e-01, Time taken : 2.205s
# Epoch 62 time: 5.313s, average error = 95.421mrad
# Starting Epoch 63, with 107 batches
# 	Epoch 63, Step 0000, MSE: 8.315e-03,  LearnRate: 1.000e-01, Time taken : 0.939s
# 	Epoch 63, Step 0050, MSE: 8.172e-03,  LearnRate: 1.000e-01, Time taken : 2.219s
# 	Epoch 63, Step 0100, MSE: 8.744e-03,  LearnRate: 1.000e-01, Time taken : 2.237s
# Epoch 63 time: 5.026s, average error = 93.510mrad
# Starting Epoch 64, with 107 batches
# 	Epoch 64, Step 0000, MSE: 8.206e-03,  LearnRate: 1.000e-01, Time taken : 1.231s
# 	Epoch 64, Step 0050, MSE: 8.234e-03,  LearnRate: 1.000e-01, Time taken : 2.190s
# 	Epoch 64, Step 0100, MSE: 8.392e-03,  LearnRate: 1.000e-01, Time taken : 2.194s
# Epoch 64 time: 4.969s, average error = 91.606mrad
# Starting Epoch 65, with 107 batches
# 	Epoch 65, Step 0000, MSE: 8.204e-03,  LearnRate: 1.000e-01, Time taken : 0.882s
# 	Epoch 65, Step 0050, MSE: 8.257e-03,  LearnRate: 1.000e-01, Time taken : 2.267s
# 	Epoch 65, Step 0100, MSE: 8.359e-03,  LearnRate: 1.000e-01, Time taken : 2.195s
# Epoch 65 time: 5.042s, average error = 91.430mrad
# Starting Epoch 66, with 107 batches
# 	Epoch 66, Step 0000, MSE: 8.756e-03,  LearnRate: 1.000e-01, Time taken : 1.319s
# 	Epoch 66, Step 0050, MSE: 8.873e-03,  LearnRate: 1.000e-01, Time taken : 2.146s
# 	Epoch 66, Step 0100, MSE: 8.991e-03,  LearnRate: 1.000e-01, Time taken : 2.166s
# Epoch 66 time: 4.853s, average error = 94.820mrad
# Starting Epoch 67, with 107 batches
# 	Epoch 67, Step 0000, MSE: 8.263e-03,  LearnRate: 1.000e-01, Time taken : 0.890s
# 	Epoch 67, Step 0050, MSE: 8.662e-03,  LearnRate: 1.000e-01, Time taken : 2.159s
# 	Epoch 67, Step 0100, MSE: 8.475e-03,  LearnRate: 1.000e-01, Time taken : 2.250s
# Epoch 67 time: 4.936s, average error = 92.062mrad
# Starting Epoch 68, with 107 batches
# 	Epoch 68, Step 0000, MSE: 8.500e-03,  LearnRate: 1.000e-01, Time taken : 1.015s
# 	Epoch 68, Step 0050, MSE: 8.596e-03,  LearnRate: 1.000e-01, Time taken : 2.243s
# 	Epoch 68, Step 0100, MSE: 8.706e-03,  LearnRate: 1.000e-01, Time taken : 2.430s
# Epoch 68 time: 5.243s, average error = 93.307mrad
# Starting Epoch 69, with 107 batches
# 	Epoch 69, Step 0000, MSE: 8.872e-03,  LearnRate: 1.000e-01, Time taken : 0.985s
# 	Epoch 69, Step 0050, MSE: 8.966e-03,  LearnRate: 1.000e-01, Time taken : 2.314s
# 	Epoch 69, Step 0100, MSE: 8.615e-03,  LearnRate: 1.000e-01, Time taken : 2.174s
# Epoch 69 time: 5.076s, average error = 92.817mrad
# Starting Epoch 70, with 107 batches
# 	Epoch 70, Step 0000, MSE: 8.238e-03,  LearnRate: 1.000e-01, Time taken : 1.202s
# 	Epoch 70, Step 0050, MSE: 8.389e-03,  LearnRate: 1.000e-01, Time taken : 2.199s
# 	Epoch 70, Step 0100, MSE: 8.487e-03,  LearnRate: 1.000e-01, Time taken : 2.176s
# Epoch 70 time: 4.960s, average error = 92.126mrad
# Starting Epoch 71, with 107 batches
# 	Epoch 71, Step 0000, MSE: 8.412e-03,  LearnRate: 1.000e-01, Time taken : 0.804s
# 	Epoch 71, Step 0050, MSE: 8.701e-03,  LearnRate: 1.000e-01, Time taken : 2.105s
# 	Epoch 71, Step 0100, MSE: 8.933e-03,  LearnRate: 1.000e-01, Time taken : 2.198s
# Epoch 71 time: 4.837s, average error = 94.515mrad
# Starting Epoch 72, with 107 batches
# 	Epoch 72, Step 0000, MSE: 8.448e-03,  LearnRate: 1.000e-01, Time taken : 1.193s
# 	Epoch 72, Step 0050, MSE: 8.564e-03,  LearnRate: 1.000e-01, Time taken : 2.177s
# 	Epoch 72, Step 0100, MSE: 8.248e-03,  LearnRate: 1.000e-01, Time taken : 2.296s
# Epoch 72 time: 5.046s, average error = 90.816mrad
# Starting Epoch 73, with 107 batches
# 	Epoch 73, Step 0000, MSE: 8.869e-03,  LearnRate: 1.000e-01, Time taken : 0.894s
# 	Epoch 73, Step 0050, MSE: 8.825e-03,  LearnRate: 1.000e-01, Time taken : 2.205s
# 	Epoch 73, Step 0100, MSE: 8.874e-03,  LearnRate: 1.000e-01, Time taken : 2.231s
# Epoch 73 time: 4.990s, average error = 94.204mrad
# Starting Epoch 74, with 107 batches
# 	Epoch 74, Step 0000, MSE: 8.361e-03,  LearnRate: 1.000e-01, Time taken : 1.338s
# 	Epoch 74, Step 0050, MSE: 8.393e-03,  LearnRate: 1.000e-01, Time taken : 2.243s
# 	Epoch 74, Step 0100, MSE: 8.269e-03,  LearnRate: 1.000e-01, Time taken : 2.427s
# Epoch 74 time: 5.239s, average error = 90.934mrad
# Starting Epoch 75, with 107 batches
# 	Epoch 75, Step 0000, MSE: 7.974e-03,  LearnRate: 1.000e-01, Time taken : 4.140s
# 	Epoch 75, Step 0050, MSE: 8.223e-03,  LearnRate: 1.000e-01, Time taken : 2.322s
# 	Epoch 75, Step 0100, MSE: 8.398e-03,  LearnRate: 1.000e-01, Time taken : 2.358s
# Epoch 75 time: 5.286s, average error = 91.641mrad
# Starting Epoch 76, with 107 batches
# 	Epoch 76, Step 0000, MSE: 8.806e-03,  LearnRate: 1.000e-01, Time taken : 2.548s
# 	Epoch 76, Step 0050, MSE: 8.222e-03,  LearnRate: 1.000e-01, Time taken : 2.363s
# 	Epoch 76, Step 0100, MSE: 8.338e-03,  LearnRate: 1.000e-01, Time taken : 2.264s
# Epoch 76 time: 5.183s, average error = 91.314mrad
# Starting Epoch 77, with 107 batches
# 	Epoch 77, Step 0000, MSE: 7.959e-03,  LearnRate: 1.000e-01, Time taken : 1.162s
# 	Epoch 77, Step 0050, MSE: 8.176e-03,  LearnRate: 1.000e-01, Time taken : 2.264s
# 	Epoch 77, Step 0100, MSE: 8.223e-03,  LearnRate: 1.000e-01, Time taken : 2.153s
# Epoch 77 time: 4.940s, average error = 90.680mrad
# Starting Epoch 78, with 107 batches
# 	Epoch 78, Step 0000, MSE: 8.383e-03,  LearnRate: 1.000e-01, Time taken : 1.424s
# 	Epoch 78, Step 0050, MSE: 8.908e-03,  LearnRate: 1.000e-01, Time taken : 2.269s
# 	Epoch 78, Step 0100, MSE: 8.801e-03,  LearnRate: 1.000e-01, Time taken : 2.293s
# Epoch 78 time: 5.157s, average error = 93.813mrad
# Starting Epoch 79, with 107 batches
# 	Epoch 79, Step 0000, MSE: 7.820e-03,  LearnRate: 1.000e-01, Time taken : 1.238s
# 	Epoch 79, Step 0050, MSE: 8.230e-03,  LearnRate: 1.000e-01, Time taken : 2.230s
# 	Epoch 79, Step 0100, MSE: 8.478e-03,  LearnRate: 1.000e-01, Time taken : 2.520s
# Epoch 79 time: 5.354s, average error = 92.076mrad
# Starting Epoch 80, with 107 batches
# 	Epoch 80, Step 0000, MSE: 9.402e-03,  LearnRate: 1.000e-01, Time taken : 1.437s
# 	Epoch 80, Step 0050, MSE: 8.781e-03,  LearnRate: 1.000e-01, Time taken : 2.485s
# 	Epoch 80, Step 0100, MSE: 8.682e-03,  LearnRate: 1.000e-01, Time taken : 2.227s
# Epoch 80 time: 5.323s, average error = 93.177mrad
# Starting Epoch 81, with 107 batches
# 	Epoch 81, Step 0000, MSE: 8.453e-03,  LearnRate: 1.000e-01, Time taken : 0.970s
# 	Epoch 81, Step 0050, MSE: 8.179e-03,  LearnRate: 1.000e-01, Time taken : 2.339s
# 	Epoch 81, Step 0100, MSE: 8.195e-03,  LearnRate: 1.000e-01, Time taken : 2.421s
# Epoch 81 time: 5.352s, average error = 90.525mrad
# Starting Epoch 82, with 107 batches
# 	Epoch 82, Step 0000, MSE: 8.222e-03,  LearnRate: 1.000e-01, Time taken : 0.889s
# 	Epoch 82, Step 0050, MSE: 8.587e-03,  LearnRate: 1.000e-01, Time taken : 2.292s
# 	Epoch 82, Step 0100, MSE: 8.734e-03,  LearnRate: 1.000e-01, Time taken : 2.260s
# Epoch 82 time: 5.131s, average error = 93.455mrad
# Starting Epoch 83, with 107 batches
# 	Epoch 83, Step 0000, MSE: 8.184e-03,  LearnRate: 1.000e-01, Time taken : 0.813s
# 	Epoch 83, Step 0050, MSE: 8.149e-03,  LearnRate: 1.000e-01, Time taken : 2.126s
# 	Epoch 83, Step 0100, MSE: 8.535e-03,  LearnRate: 1.000e-01, Time taken : 2.047s
# Epoch 83 time: 4.691s, average error = 92.383mrad
# Starting Epoch 84, with 107 batches
# 	Epoch 84, Step 0000, MSE: 8.413e-03,  LearnRate: 1.000e-01, Time taken : 0.794s
# 	Epoch 84, Step 0050, MSE: 8.299e-03,  LearnRate: 1.000e-01, Time taken : 2.143s
# 	Epoch 84, Step 0100, MSE: 8.484e-03,  LearnRate: 1.000e-01, Time taken : 2.128s
# Epoch 84 time: 4.819s, average error = 92.107mrad
# Starting Epoch 85, with 107 batches
# 	Epoch 85, Step 0000, MSE: 8.540e-03,  LearnRate: 1.000e-01, Time taken : 0.824s
# 	Epoch 85, Step 0050, MSE: 8.399e-03,  LearnRate: 1.000e-01, Time taken : 2.306s
# 	Epoch 85, Step 0100, MSE: 8.425e-03,  LearnRate: 1.000e-01, Time taken : 2.188s
# Epoch 85 time: 5.051s, average error = 91.789mrad
# Starting Epoch 86, with 107 batches
# 	Epoch 86, Step 0000, MSE: 8.202e-03,  LearnRate: 1.000e-01, Time taken : 0.910s
# 	Epoch 86, Step 0050, MSE: 8.376e-03,  LearnRate: 1.000e-01, Time taken : 2.198s
# 	Epoch 86, Step 0100, MSE: 8.522e-03,  LearnRate: 1.000e-01, Time taken : 2.236s
# Epoch 86 time: 5.000s, average error = 92.317mrad
# Starting Epoch 87, with 107 batches
# 	Epoch 87, Step 0000, MSE: 7.964e-03,  LearnRate: 1.000e-01, Time taken : 0.945s
# 	Epoch 87, Step 0050, MSE: 8.193e-03,  LearnRate: 1.000e-01, Time taken : 2.484s
# 	Epoch 87, Step 0100, MSE: 8.659e-03,  LearnRate: 1.000e-01, Time taken : 2.089s
# Epoch 87 time: 5.275s, average error = 93.053mrad
# Starting Epoch 88, with 107 batches
# 	Epoch 88, Step 0000, MSE: 7.957e-03,  LearnRate: 1.000e-01, Time taken : 0.869s
# 	Epoch 88, Step 0050, MSE: 8.065e-03,  LearnRate: 1.000e-01, Time taken : 2.216s
# 	Epoch 88, Step 0100, MSE: 8.265e-03,  LearnRate: 1.000e-01, Time taken : 2.399s
# Epoch 88 time: 5.144s, average error = 90.911mrad
# Starting Epoch 89, with 107 batches
# 	Epoch 89, Step 0000, MSE: 7.714e-03,  LearnRate: 1.000e-01, Time taken : 0.993s
# 	Epoch 89, Step 0050, MSE: 7.923e-03,  LearnRate: 1.000e-01, Time taken : 2.205s
# 	Epoch 89, Step 0100, MSE: 7.947e-03,  LearnRate: 1.000e-01, Time taken : 2.410s
# Epoch 89 time: 5.241s, average error = 89.147mrad
# Starting Epoch 90, with 107 batches
# 	Epoch 90, Step 0000, MSE: 7.590e-03,  LearnRate: 1.000e-01, Time taken : 0.943s
# 	Epoch 90, Step 0050, MSE: 8.027e-03,  LearnRate: 1.000e-01, Time taken : 2.661s
# 	Epoch 90, Step 0100, MSE: 7.944e-03,  LearnRate: 1.000e-01, Time taken : 2.287s
# Epoch 90 time: 5.670s, average error = 89.129mrad
# Starting Epoch 91, with 107 batches
# 	Epoch 91, Step 0000, MSE: 7.863e-03,  LearnRate: 1.000e-01, Time taken : 1.011s
# 	Epoch 91, Step 0050, MSE: 7.828e-03,  LearnRate: 1.000e-01, Time taken : 2.369s
# 	Epoch 91, Step 0100, MSE: 8.212e-03,  LearnRate: 1.000e-01, Time taken : 2.449s
# Epoch 91 time: 5.442s, average error = 90.619mrad
# Starting Epoch 92, with 107 batches
# 	Epoch 92, Step 0000, MSE: 7.724e-03,  LearnRate: 1.000e-01, Time taken : 0.979s
# 	Epoch 92, Step 0050, MSE: 8.110e-03,  LearnRate: 1.000e-01, Time taken : 2.220s
# 	Epoch 92, Step 0100, MSE: 8.161e-03,  LearnRate: 1.000e-01, Time taken : 2.293s
# Epoch 92 time: 5.096s, average error = 90.336mrad
# Starting Epoch 93, with 107 batches
# 	Epoch 93, Step 0000, MSE: 7.801e-03,  LearnRate: 1.000e-01, Time taken : 0.818s
# 	Epoch 93, Step 0050, MSE: 7.927e-03,  LearnRate: 1.000e-01, Time taken : 2.204s
# 	Epoch 93, Step 0100, MSE: 8.218e-03,  LearnRate: 1.000e-01, Time taken : 2.199s
# Epoch 93 time: 4.945s, average error = 90.654mrad
# Starting Epoch 94, with 107 batches
# 	Epoch 94, Step 0000, MSE: 7.833e-03,  LearnRate: 1.000e-01, Time taken : 0.958s
# 	Epoch 94, Step 0050, MSE: 8.019e-03,  LearnRate: 1.000e-01, Time taken : 2.358s
# 	Epoch 94, Step 0100, MSE: 8.605e-03,  LearnRate: 1.000e-01, Time taken : 2.411s
# Epoch 94 time: 5.440s, average error = 92.763mrad
# Starting Epoch 95, with 107 batches
# 	Epoch 95, Step 0000, MSE: 7.404e-03,  LearnRate: 1.000e-01, Time taken : 0.980s
# 	Epoch 95, Step 0050, MSE: 7.634e-03,  LearnRate: 1.000e-01, Time taken : 2.211s
# 	Epoch 95, Step 0100, MSE: 7.771e-03,  LearnRate: 1.000e-01, Time taken : 2.288s
# Epoch 95 time: 5.168s, average error = 88.156mrad
# Starting Epoch 96, with 107 batches
# 	Epoch 96, Step 0000, MSE: 7.965e-03,  LearnRate: 1.000e-01, Time taken : 1.043s
# 	Epoch 96, Step 0050, MSE: 8.102e-03,  LearnRate: 1.000e-01, Time taken : 2.675s
# 	Epoch 96, Step 0100, MSE: 8.592e-03,  LearnRate: 1.000e-01, Time taken : 2.119s
# Epoch 96 time: 5.403s, average error = 92.695mrad
# Starting Epoch 97, with 107 batches
# 	Epoch 97, Step 0000, MSE: 7.935e-03,  LearnRate: 1.000e-01, Time taken : 0.858s
# 	Epoch 97, Step 0050, MSE: 7.904e-03,  LearnRate: 1.000e-01, Time taken : 2.165s
# 	Epoch 97, Step 0100, MSE: 8.002e-03,  LearnRate: 1.000e-01, Time taken : 2.139s
# Epoch 97 time: 4.854s, average error = 89.452mrad
# Starting Epoch 98, with 107 batches
# 	Epoch 98, Step 0000, MSE: 7.885e-03,  LearnRate: 1.000e-01, Time taken : 0.873s
# 	Epoch 98, Step 0050, MSE: 8.147e-03,  LearnRate: 1.000e-01, Time taken : 2.187s
# 	Epoch 98, Step 0100, MSE: 8.311e-03,  LearnRate: 1.000e-01, Time taken : 2.381s
# Epoch 98 time: 5.138s, average error = 91.164mrad
# Starting Epoch 99, with 107 batches
# 	Epoch 99, Step 0000, MSE: 7.340e-03,  LearnRate: 1.000e-01, Time taken : 0.818s
# 	Epoch 99, Step 0050, MSE: 7.781e-03,  LearnRate: 1.000e-01, Time taken : 2.272s
# 	Epoch 99, Step 0100, MSE: 8.174e-03,  LearnRate: 1.000e-01, Time taken : 2.103s
# Epoch 99 time: 4.979s, average error = 90.412mrad
# Starting Epoch 100, with 107 batches
# 	Epoch 100, Step 0000, MSE: 8.097e-03,  LearnRate: 1.000e-01, Time taken : 0.839s
# 	Epoch 100, Step 0050, MSE: 8.247e-03,  LearnRate: 1.000e-01, Time taken : 2.223s
# 	Epoch 100, Step 0100, MSE: 8.325e-03,  LearnRate: 1.000e-01, Time taken : 2.028s
# Epoch 100 time: 4.751s, average error = 91.242mrad
# Starting Epoch 101, with 107 batches
# 	Epoch 101, Step 0000, MSE: 8.134e-03,  LearnRate: 1.000e-01, Time taken : 1.314s
# 	Epoch 101, Step 0050, MSE: 7.888e-03,  LearnRate: 1.000e-01, Time taken : 2.080s
# 	Epoch 101, Step 0100, MSE: 7.893e-03,  LearnRate: 1.000e-01, Time taken : 2.206s
# Epoch 101 time: 4.839s, average error = 88.841mrad
# Starting Epoch 102, with 107 batches
# 	Epoch 102, Step 0000, MSE: 7.781e-03,  LearnRate: 1.000e-01, Time taken : 0.891s
# 	Epoch 102, Step 0050, MSE: 8.132e-03,  LearnRate: 1.000e-01, Time taken : 2.401s
# 	Epoch 102, Step 0100, MSE: 8.190e-03,  LearnRate: 1.000e-01, Time taken : 2.282s
# Epoch 102 time: 5.289s, average error = 90.497mrad
# Starting Epoch 103, with 107 batches
# 	Epoch 103, Step 0000, MSE: 7.485e-03,  LearnRate: 1.000e-01, Time taken : 1.323s
# 	Epoch 103, Step 0050, MSE: 7.833e-03,  LearnRate: 1.000e-01, Time taken : 2.181s
# 	Epoch 103, Step 0100, MSE: 8.371e-03,  LearnRate: 1.000e-01, Time taken : 2.372s
# Epoch 103 time: 5.164s, average error = 91.492mrad
# Starting Epoch 104, with 107 batches
# 	Epoch 104, Step 0000, MSE: 8.090e-03,  LearnRate: 1.000e-01, Time taken : 0.935s
# 	Epoch 104, Step 0050, MSE: 7.796e-03,  LearnRate: 1.000e-01, Time taken : 2.225s
# 	Epoch 104, Step 0100, MSE: 8.079e-03,  LearnRate: 1.000e-01, Time taken : 2.250s
# Epoch 104 time: 5.038s, average error = 89.885mrad
# Starting Epoch 105, with 107 batches
# 	Epoch 105, Step 0000, MSE: 7.322e-03,  LearnRate: 1.000e-01, Time taken : 1.338s
# 	Epoch 105, Step 0050, MSE: 7.505e-03,  LearnRate: 1.000e-01, Time taken : 2.549s
# 	Epoch 105, Step 0100, MSE: 7.760e-03,  LearnRate: 1.000e-01, Time taken : 2.268s
# Epoch 105 time: 5.409s, average error = 88.093mrad
# Starting Epoch 106, with 107 batches
# 	Epoch 106, Step 0000, MSE: 7.217e-03,  LearnRate: 1.000e-01, Time taken : 2.138s
# 	Epoch 106, Step 0050, MSE: 7.463e-03,  LearnRate: 1.000e-01, Time taken : 2.366s
# 	Epoch 106, Step 0100, MSE: 7.700e-03,  LearnRate: 1.000e-01, Time taken : 2.310s
# Epoch 106 time: 5.281s, average error = 87.750mrad
# Starting Epoch 107, with 107 batches
# 	Epoch 107, Step 0000, MSE: 7.587e-03,  LearnRate: 1.000e-01, Time taken : 0.932s
# 	Epoch 107, Step 0050, MSE: 7.933e-03,  LearnRate: 1.000e-01, Time taken : 2.257s
# 	Epoch 107, Step 0100, MSE: 7.672e-03,  LearnRate: 1.000e-01, Time taken : 2.326s
# Epoch 107 time: 5.167s, average error = 87.591mrad
# Starting Epoch 108, with 107 batches
# 	Epoch 108, Step 0000, MSE: 7.234e-03,  LearnRate: 1.000e-01, Time taken : 1.793s
# 	Epoch 108, Step 0050, MSE: 7.518e-03,  LearnRate: 1.000e-01, Time taken : 2.168s
# 	Epoch 108, Step 0100, MSE: 7.965e-03,  LearnRate: 1.000e-01, Time taken : 2.197s
# Epoch 108 time: 4.936s, average error = 89.247mrad
# Starting Epoch 109, with 107 batches
# 	Epoch 109, Step 0000, MSE: 7.492e-03,  LearnRate: 1.000e-01, Time taken : 1.226s
# 	Epoch 109, Step 0050, MSE: 7.692e-03,  LearnRate: 1.000e-01, Time taken : 2.191s
# 	Epoch 109, Step 0100, MSE: 7.525e-03,  LearnRate: 1.000e-01, Time taken : 2.225s
# Epoch 109 time: 5.006s, average error = 86.746mrad
# Starting Epoch 110, with 107 batches
# 	Epoch 110, Step 0000, MSE: 7.292e-03,  LearnRate: 1.000e-01, Time taken : 2.197s
# 	Epoch 110, Step 0050, MSE: 7.393e-03,  LearnRate: 1.000e-01, Time taken : 2.378s
# 	Epoch 110, Step 0100, MSE: 7.292e-03,  LearnRate: 1.000e-01, Time taken : 2.191s
# Epoch 110 time: 5.133s, average error = 85.395mrad
# Starting Epoch 111, with 107 batches
# 	Epoch 111, Step 0000, MSE: 7.154e-03,  LearnRate: 1.000e-01, Time taken : 0.837s
# 	Epoch 111, Step 0050, MSE: 7.445e-03,  LearnRate: 1.000e-01, Time taken : 2.386s
# 	Epoch 111, Step 0100, MSE: 7.488e-03,  LearnRate: 1.000e-01, Time taken : 2.487s
# Epoch 111 time: 5.497s, average error = 86.534mrad
# Starting Epoch 112, with 107 batches
# 	Epoch 112, Step 0000, MSE: 7.703e-03,  LearnRate: 1.000e-01, Time taken : 1.549s
# 	Epoch 112, Step 0050, MSE: 7.494e-03,  LearnRate: 1.000e-01, Time taken : 2.460s
# 	Epoch 112, Step 0100, MSE: 7.548e-03,  LearnRate: 1.000e-01, Time taken : 2.455s
# Epoch 112 time: 5.516s, average error = 86.882mrad
# Starting Epoch 113, with 107 batches
# 	Epoch 113, Step 0000, MSE: 7.683e-03,  LearnRate: 1.000e-01, Time taken : 1.334s
# 	Epoch 113, Step 0050, MSE: 7.545e-03,  LearnRate: 1.000e-01, Time taken : 2.368s
# 	Epoch 113, Step 0100, MSE: 7.729e-03,  LearnRate: 1.000e-01, Time taken : 2.325s
# Epoch 113 time: 5.350s, average error = 87.912mrad
# Starting Epoch 114, with 107 batches
# 	Epoch 114, Step 0000, MSE: 7.479e-03,  LearnRate: 1.000e-01, Time taken : 1.517s
# 	Epoch 114, Step 0050, MSE: 7.459e-03,  LearnRate: 1.000e-01, Time taken : 2.414s
# 	Epoch 114, Step 0100, MSE: 7.889e-03,  LearnRate: 1.000e-01, Time taken : 2.214s
# Epoch 114 time: 5.183s, average error = 88.821mrad
# Starting Epoch 115, with 107 batches
# 	Epoch 115, Step 0000, MSE: 7.166e-03,  LearnRate: 1.000e-01, Time taken : 3.710s
# 	Epoch 115, Step 0050, MSE: 7.347e-03,  LearnRate: 1.000e-01, Time taken : 2.631s
# 	Epoch 115, Step 0100, MSE: 7.490e-03,  LearnRate: 1.000e-01, Time taken : 2.361s
# Epoch 115 time: 5.600s, average error = 86.544mrad
# Starting Epoch 116, with 107 batches
# 	Epoch 116, Step 0000, MSE: 6.919e-03,  LearnRate: 1.000e-01, Time taken : 5.252s
# 	Epoch 116, Step 0050, MSE: 7.360e-03,  LearnRate: 1.000e-01, Time taken : 2.330s
# 	Epoch 116, Step 0100, MSE: 7.269e-03,  LearnRate: 1.000e-01, Time taken : 2.343s
# Epoch 116 time: 5.255s, average error = 85.259mrad
# Starting Epoch 117, with 107 batches
# 	Epoch 117, Step 0000, MSE: 7.208e-03,  LearnRate: 1.000e-01, Time taken : 1.262s
# 	Epoch 117, Step 0050, MSE: 6.982e-03,  LearnRate: 1.000e-01, Time taken : 2.405s
# 	Epoch 117, Step 0100, MSE: 7.455e-03,  LearnRate: 1.000e-01, Time taken : 2.168s
# Epoch 117 time: 5.136s, average error = 86.343mrad
# Starting Epoch 118, with 107 batches
# 	Epoch 118, Step 0000, MSE: 7.036e-03,  LearnRate: 1.000e-01, Time taken : 1.077s
# 	Epoch 118, Step 0050, MSE: 7.495e-03,  LearnRate: 1.000e-01, Time taken : 2.137s
# 	Epoch 118, Step 0100, MSE: 7.303e-03,  LearnRate: 1.000e-01, Time taken : 2.291s
# Epoch 118 time: 5.002s, average error = 85.456mrad
# Starting Epoch 119, with 107 batches
# 	Epoch 119, Step 0000, MSE: 7.527e-03,  LearnRate: 1.000e-01, Time taken : 0.715s
# 	Epoch 119, Step 0050, MSE: 7.205e-03,  LearnRate: 1.000e-01, Time taken : 2.264s
# 	Epoch 119, Step 0100, MSE: 7.487e-03,  LearnRate: 1.000e-01, Time taken : 2.321s
# Epoch 119 time: 5.086s, average error = 86.525mrad
# Starting Epoch 120, with 107 batches
# 	Epoch 120, Step 0000, MSE: 6.699e-03,  LearnRate: 1.000e-01, Time taken : 0.972s
# 	Epoch 120, Step 0050, MSE: 7.251e-03,  LearnRate: 1.000e-01, Time taken : 2.635s
# 	Epoch 120, Step 0100, MSE: 7.131e-03,  LearnRate: 1.000e-01, Time taken : 2.232s
# Epoch 120 time: 5.476s, average error = 84.447mrad
# Starting Epoch 121, with 107 batches
# 	Epoch 121, Step 0000, MSE: 7.123e-03,  LearnRate: 1.000e-01, Time taken : 0.823s
# 	Epoch 121, Step 0050, MSE: 7.473e-03,  LearnRate: 1.000e-01, Time taken : 2.497s
# 	Epoch 121, Step 0100, MSE: 7.612e-03,  LearnRate: 1.000e-01, Time taken : 2.419s
# Epoch 121 time: 5.509s, average error = 87.249mrad
# Starting Epoch 122, with 107 batches
# 	Epoch 122, Step 0000, MSE: 6.695e-03,  LearnRate: 1.000e-01, Time taken : 0.945s
# 	Epoch 122, Step 0050, MSE: 7.586e-03,  LearnRate: 1.000e-01, Time taken : 2.172s
# 	Epoch 122, Step 0100, MSE: 7.058e-03,  LearnRate: 1.000e-01, Time taken : 2.271s
# Epoch 122 time: 5.024s, average error = 84.012mrad
# Starting Epoch 123, with 107 batches
# 	Epoch 123, Step 0000, MSE: 6.779e-03,  LearnRate: 1.000e-01, Time taken : 0.860s
# 	Epoch 123, Step 0050, MSE: 7.260e-03,  LearnRate: 1.000e-01, Time taken : 2.329s
# 	Epoch 123, Step 0100, MSE: 7.197e-03,  LearnRate: 1.000e-01, Time taken : 2.517s
# Epoch 123 time: 5.474s, average error = 84.833mrad
# Starting Epoch 124, with 107 batches
# 	Epoch 124, Step 0000, MSE: 6.649e-03,  LearnRate: 1.000e-01, Time taken : 4.518s
# 	Epoch 124, Step 0050, MSE: 7.017e-03,  LearnRate: 1.000e-01, Time taken : 2.420s
# 	Epoch 124, Step 0100, MSE: 7.189e-03,  LearnRate: 1.000e-01, Time taken : 2.306s
# Epoch 124 time: 5.348s, average error = 84.787mrad
# Starting Epoch 125, with 107 batches
# 	Epoch 125, Step 0000, MSE: 6.755e-03,  LearnRate: 1.000e-01, Time taken : 1.492s
# 	Epoch 125, Step 0050, MSE: 7.240e-03,  LearnRate: 1.000e-01, Time taken : 2.492s
# 	Epoch 125, Step 0100, MSE: 7.179e-03,  LearnRate: 1.000e-01, Time taken : 2.189s
# Epoch 125 time: 5.285s, average error = 84.730mrad
# Starting Epoch 126, with 107 batches
# 	Epoch 126, Step 0000, MSE: 6.952e-03,  LearnRate: 1.000e-01, Time taken : 0.899s
# 	Epoch 126, Step 0050, MSE: 7.280e-03,  LearnRate: 1.000e-01, Time taken : 2.248s
# 	Epoch 126, Step 0100, MSE: 7.102e-03,  LearnRate: 1.000e-01, Time taken : 2.188s
# Epoch 126 time: 5.159s, average error = 84.273mrad
# Starting Epoch 127, with 107 batches
# 	Epoch 127, Step 0000, MSE: 6.632e-03,  LearnRate: 1.000e-01, Time taken : 1.027s
# 	Epoch 127, Step 0050, MSE: 6.839e-03,  LearnRate: 1.000e-01, Time taken : 2.321s
# 	Epoch 127, Step 0100, MSE: 7.082e-03,  LearnRate: 1.000e-01, Time taken : 2.237s
# Epoch 127 time: 5.126s, average error = 84.157mrad
# Starting Epoch 128, with 107 batches
# 	Epoch 128, Step 0000, MSE: 7.027e-03,  LearnRate: 1.000e-01, Time taken : 1.617s
# 	Epoch 128, Step 0050, MSE: 7.128e-03,  LearnRate: 1.000e-01, Time taken : 1.981s
# 	Epoch 128, Step 0100, MSE: 7.198e-03,  LearnRate: 1.000e-01, Time taken : 2.246s
# Epoch 128 time: 4.773s, average error = 84.842mrad
# Starting Epoch 129, with 107 batches
# 	Epoch 129, Step 0000, MSE: 6.353e-03,  LearnRate: 1.000e-01, Time taken : 2.054s
# 	Epoch 129, Step 0050, MSE: 6.807e-03,  LearnRate: 1.000e-01, Time taken : 2.471s
# 	Epoch 129, Step 0100, MSE: 6.928e-03,  LearnRate: 1.000e-01, Time taken : 2.450s
# Epoch 129 time: 5.524s, average error = 83.237mrad
# Starting Epoch 130, with 107 batches
# 	Epoch 130, Step 0000, MSE: 6.807e-03,  LearnRate: 1.000e-01, Time taken : 1.438s
# 	Epoch 130, Step 0050, MSE: 6.872e-03,  LearnRate: 1.000e-01, Time taken : 2.309s
# 	Epoch 130, Step 0100, MSE: 6.861e-03,  LearnRate: 1.000e-01, Time taken : 2.271s
# Epoch 130 time: 5.332s, average error = 82.831mrad
# Starting Epoch 131, with 107 batches
# 	Epoch 131, Step 0000, MSE: 6.604e-03,  LearnRate: 1.000e-01, Time taken : 0.893s
# 	Epoch 131, Step 0050, MSE: 6.758e-03,  LearnRate: 1.000e-01, Time taken : 2.350s
# 	Epoch 131, Step 0100, MSE: 6.916e-03,  LearnRate: 1.000e-01, Time taken : 2.382s
# Epoch 131 time: 5.308s, average error = 83.162mrad
# Starting Epoch 132, with 107 batches
# 	Epoch 132, Step 0000, MSE: 6.758e-03,  LearnRate: 1.000e-01, Time taken : 1.319s
# 	Epoch 132, Step 0050, MSE: 6.803e-03,  LearnRate: 1.000e-01, Time taken : 2.243s
# 	Epoch 132, Step 0100, MSE: 7.079e-03,  LearnRate: 1.000e-01, Time taken : 2.329s
# Epoch 132 time: 5.183s, average error = 84.136mrad
# Starting Epoch 133, with 107 batches
# 	Epoch 133, Step 0000, MSE: 6.479e-03,  LearnRate: 1.000e-01, Time taken : 0.879s
# 	Epoch 133, Step 0050, MSE: 6.726e-03,  LearnRate: 1.000e-01, Time taken : 2.086s
# 	Epoch 133, Step 0100, MSE: 7.097e-03,  LearnRate: 1.000e-01, Time taken : 2.322s
# Epoch 133 time: 4.965s, average error = 84.246mrad
# Starting Epoch 134, with 107 batches
# 	Epoch 134, Step 0000, MSE: 6.666e-03,  LearnRate: 1.000e-01, Time taken : 1.201s
# 	Epoch 134, Step 0050, MSE: 7.208e-03,  LearnRate: 1.000e-01, Time taken : 2.321s
# 	Epoch 134, Step 0100, MSE: 7.229e-03,  LearnRate: 1.000e-01, Time taken : 2.182s
# Epoch 134 time: 5.086s, average error = 85.024mrad
# Starting Epoch 135, with 107 batches
# 	Epoch 135, Step 0000, MSE: 6.528e-03,  LearnRate: 1.000e-01, Time taken : 0.890s
# 	Epoch 135, Step 0050, MSE: 6.577e-03,  LearnRate: 1.000e-01, Time taken : 2.220s
# 	Epoch 135, Step 0100, MSE: 6.881e-03,  LearnRate: 1.000e-01, Time taken : 2.225s
# Epoch 135 time: 5.018s, average error = 82.949mrad
# Starting Epoch 136, with 107 batches
# 	Epoch 136, Step 0000, MSE: 6.207e-03,  LearnRate: 1.000e-01, Time taken : 1.181s
# 	Epoch 136, Step 0050, MSE: 6.801e-03,  LearnRate: 1.000e-01, Time taken : 2.247s
# 	Epoch 136, Step 0100, MSE: 8.181e-03,  LearnRate: 1.000e-01, Time taken : 2.433s
# Epoch 136 time: 5.246s, average error = 90.447mrad
# Starting Epoch 137, with 107 batches
# 	Epoch 137, Step 0000, MSE: 6.863e-03,  LearnRate: 1.000e-01, Time taken : 0.865s
# 	Epoch 137, Step 0050, MSE: 6.592e-03,  LearnRate: 1.000e-01, Time taken : 2.337s
# 	Epoch 137, Step 0100, MSE: 6.721e-03,  LearnRate: 1.000e-01, Time taken : 2.279s
# Epoch 137 time: 5.178s, average error = 81.980mrad
# Starting Epoch 138, with 107 batches
# 	Epoch 138, Step 0000, MSE: 6.040e-03,  LearnRate: 1.000e-01, Time taken : 1.207s
# 	Epoch 138, Step 0050, MSE: 6.494e-03,  LearnRate: 1.000e-01, Time taken : 2.257s
# 	Epoch 138, Step 0100, MSE: 6.662e-03,  LearnRate: 1.000e-01, Time taken : 2.263s
# Epoch 138 time: 5.086s, average error = 81.623mrad
# Starting Epoch 139, with 107 batches
# 	Epoch 139, Step 0000, MSE: 6.306e-03,  LearnRate: 1.000e-01, Time taken : 1.441s
# 	Epoch 139, Step 0050, MSE: 6.593e-03,  LearnRate: 1.000e-01, Time taken : 2.317s
# 	Epoch 139, Step 0100, MSE: 6.751e-03,  LearnRate: 1.000e-01, Time taken : 2.156s
# Epoch 139 time: 5.045s, average error = 82.167mrad
# Starting Epoch 140, with 107 batches
# 	Epoch 140, Step 0000, MSE: 6.296e-03,  LearnRate: 1.000e-01, Time taken : 0.906s
# 	Epoch 140, Step 0050, MSE: 6.554e-03,  LearnRate: 1.000e-01, Time taken : 2.209s
# 	Epoch 140, Step 0100, MSE: 6.884e-03,  LearnRate: 1.000e-01, Time taken : 2.155s
# Epoch 140 time: 4.922s, average error = 82.969mrad
# Starting Epoch 141, with 107 batches
# 	Epoch 141, Step 0000, MSE: 6.165e-03,  LearnRate: 1.000e-01, Time taken : 1.852s
# 	Epoch 141, Step 0050, MSE: 6.469e-03,  LearnRate: 1.000e-01, Time taken : 2.108s
# 	Epoch 141, Step 0100, MSE: 7.096e-03,  LearnRate: 1.000e-01, Time taken : 2.422s
# Epoch 141 time: 5.097s, average error = 84.238mrad
# Starting Epoch 142, with 107 batches
# 	Epoch 142, Step 0000, MSE: 6.864e-03,  LearnRate: 1.000e-01, Time taken : 0.914s
# 	Epoch 142, Step 0050, MSE: 6.985e-03,  LearnRate: 1.000e-01, Time taken : 2.497s
# 	Epoch 142, Step 0100, MSE: 6.972e-03,  LearnRate: 1.000e-01, Time taken : 2.391s
# Epoch 142 time: 5.503s, average error = 83.497mrad
# Starting Epoch 143, with 107 batches
# 	Epoch 143, Step 0000, MSE: 6.504e-03,  LearnRate: 1.000e-01, Time taken : 1.403s
# 	Epoch 143, Step 0050, MSE: 6.598e-03,  LearnRate: 1.000e-01, Time taken : 2.674s
# 	Epoch 143, Step 0100, MSE: 6.807e-03,  LearnRate: 1.000e-01, Time taken : 2.265s
# Epoch 143 time: 5.541s, average error = 82.504mrad
# Starting Epoch 144, with 107 batches
# 	Epoch 144, Step 0000, MSE: 6.104e-03,  LearnRate: 1.000e-01, Time taken : 0.923s
# 	Epoch 144, Step 0050, MSE: 6.492e-03,  LearnRate: 1.000e-01, Time taken : 2.397s
# 	Epoch 144, Step 0100, MSE: 6.709e-03,  LearnRate: 1.000e-01, Time taken : 2.401s
# Epoch 144 time: 5.381s, average error = 81.907mrad
# Starting Epoch 145, with 107 batches
# ...
# 	Epoch 4953, Step 0000, MSE: 1.808e-03,  LearnRate: 6.250e-03, Time taken : 0.769s
# 	Epoch 4953, Step 0050, MSE: 1.803e-03,  LearnRate: 6.250e-03, Time taken : 2.277s
# 	Epoch 4953, Step 0100, MSE: 1.807e-03,  LearnRate: 6.250e-03, Time taken : 2.129s
# Epoch 4953 time: 4.933s, average error = 42.511mrad
# Starting Epoch 4954, with 107 batches
# 	Epoch 4954, Step 0000, MSE: 1.821e-03,  LearnRate: 6.250e-03, Time taken : 0.968s
# 	Epoch 4954, Step 0050, MSE: 1.819e-03,  LearnRate: 6.250e-03, Time taken : 2.271s
# 	Epoch 4954, Step 0100, MSE: 1.820e-03,  LearnRate: 6.250e-03, Time taken : 2.465s
# Epoch 4954 time: 5.323s, average error = 42.667mrad
# Starting Epoch 4955, with 107 batches
# 	Epoch 4955, Step 0000, MSE: 1.860e-03,  LearnRate: 6.250e-03, Time taken : 0.923s
# 	Epoch 4955, Step 0050, MSE: 1.856e-03,  LearnRate: 6.250e-03, Time taken : 2.600s
# 	Epoch 4955, Step 0100, MSE: 1.862e-03,  LearnRate: 6.250e-03, Time taken : 2.456s
# Epoch 4955 time: 5.723s, average error = 43.146mrad
# Starting Epoch 4956, with 107 batches
# 	Epoch 4956, Step 0000, MSE: 1.825e-03,  LearnRate: 6.250e-03, Time taken : 1.081s
# 	Epoch 4956, Step 0050, MSE: 1.823e-03,  LearnRate: 6.250e-03, Time taken : 2.337s
# 	Epoch 4956, Step 0100, MSE: 1.822e-03,  LearnRate: 6.250e-03, Time taken : 2.300s
# Epoch 4956 time: 5.260s, average error = 42.685mrad
# Starting Epoch 4957, with 107 batches
# 	Epoch 4957, Step 0000, MSE: 1.846e-03,  LearnRate: 6.250e-03, Time taken : 0.931s
# 	Epoch 4957, Step 0050, MSE: 1.847e-03,  LearnRate: 6.250e-03, Time taken : 2.519s
# 	Epoch 4957, Step 0100, MSE: 1.847e-03,  LearnRate: 6.250e-03, Time taken : 2.483s
# Epoch 4957 time: 5.558s, average error = 42.971mrad
# Starting Epoch 4958, with 107 batches
# 	Epoch 4958, Step 0000, MSE: 1.888e-03,  LearnRate: 6.250e-03, Time taken : 0.920s
# 	Epoch 4958, Step 0050, MSE: 1.888e-03,  LearnRate: 6.250e-03, Time taken : 2.317s
# 	Epoch 4958, Step 0100, MSE: 1.896e-03,  LearnRate: 6.250e-03, Time taken : 2.158s
# Epoch 4958 time: 5.028s, average error = 43.542mrad
# Starting Epoch 4959, with 107 batches
# 	Epoch 4959, Step 0000, MSE: 1.840e-03,  LearnRate: 6.250e-03, Time taken : 0.841s
# 	Epoch 4959, Step 0050, MSE: 1.842e-03,  LearnRate: 6.250e-03, Time taken : 2.167s
# 	Epoch 4959, Step 0100, MSE: 1.845e-03,  LearnRate: 6.250e-03, Time taken : 2.429s
# Epoch 4959 time: 5.148s, average error = 42.954mrad
# Starting Epoch 4960, with 107 batches
# 	Epoch 4960, Step 0000, MSE: 1.872e-03,  LearnRate: 6.250e-03, Time taken : 0.854s
# 	Epoch 4960, Step 0050, MSE: 1.878e-03,  LearnRate: 6.250e-03, Time taken : 2.166s
# 	Epoch 4960, Step 0100, MSE: 1.873e-03,  LearnRate: 6.250e-03, Time taken : 2.244s
# Epoch 4960 time: 5.035s, average error = 43.274mrad
# Starting Epoch 4961, with 107 batches
# 	Epoch 4961, Step 0000, MSE: 1.890e-03,  LearnRate: 6.250e-03, Time taken : 1.006s
# 	Epoch 4961, Step 0050, MSE: 1.893e-03,  LearnRate: 6.250e-03, Time taken : 2.258s
# 	Epoch 4961, Step 0100, MSE: 1.892e-03,  LearnRate: 6.250e-03, Time taken : 2.451s
# Epoch 4961 time: 5.349s, average error = 43.493mrad
# Starting Epoch 4962, with 107 batches
# 	Epoch 4962, Step 0000, MSE: 1.833e-03,  LearnRate: 6.250e-03, Time taken : 1.033s
# 	Epoch 4962, Step 0050, MSE: 1.837e-03,  LearnRate: 6.250e-03, Time taken : 2.578s
# 	Epoch 4962, Step 0100, MSE: 1.833e-03,  LearnRate: 6.250e-03, Time taken : 2.204s
# Epoch 4962 time: 5.452s, average error = 42.810mrad
# Starting Epoch 4963, with 107 batches
# 	Epoch 4963, Step 0000, MSE: 1.885e-03,  LearnRate: 6.250e-03, Time taken : 0.944s
# 	Epoch 4963, Step 0050, MSE: 1.884e-03,  LearnRate: 6.250e-03, Time taken : 2.307s
# 	Epoch 4963, Step 0100, MSE: 1.886e-03,  LearnRate: 6.250e-03, Time taken : 2.232s
# Epoch 4963 time: 5.111s, average error = 43.430mrad
# Starting Epoch 4964, with 107 batches
# 	Epoch 4964, Step 0000, MSE: 1.829e-03,  LearnRate: 6.250e-03, Time taken : 0.884s
# 	Epoch 4964, Step 0050, MSE: 1.834e-03,  LearnRate: 6.250e-03, Time taken : 2.416s
# 	Epoch 4964, Step 0100, MSE: 1.828e-03,  LearnRate: 6.250e-03, Time taken : 2.326s
# Epoch 4964 time: 5.312s, average error = 42.760mrad
# Starting Epoch 4965, with 107 batches
# 	Epoch 4965, Step 0000, MSE: 1.806e-03,  LearnRate: 6.250e-03, Time taken : 0.993s
# 	Epoch 4965, Step 0050, MSE: 1.805e-03,  LearnRate: 6.250e-03, Time taken : 2.350s
# 	Epoch 4965, Step 0100, MSE: 1.808e-03,  LearnRate: 6.250e-03, Time taken : 2.127s
# Epoch 4965 time: 5.091s, average error = 42.524mrad
# Starting Epoch 4966, with 107 batches
# 	Epoch 4966, Step 0000, MSE: 1.846e-03,  LearnRate: 6.250e-03, Time taken : 1.112s
# 	Epoch 4966, Step 0050, MSE: 1.847e-03,  LearnRate: 6.250e-03, Time taken : 2.598s
# 	Epoch 4966, Step 0100, MSE: 1.846e-03,  LearnRate: 6.250e-03, Time taken : 2.217s
# Epoch 4966 time: 5.504s, average error = 42.970mrad
# Starting Epoch 4967, with 107 batches
# 	Epoch 4967, Step 0000, MSE: 1.875e-03,  LearnRate: 6.250e-03, Time taken : 0.987s
# 	Epoch 4967, Step 0050, MSE: 1.876e-03,  LearnRate: 6.250e-03, Time taken : 2.241s
# 	Epoch 4967, Step 0100, MSE: 1.876e-03,  LearnRate: 6.250e-03, Time taken : 2.237s
# Epoch 4967 time: 5.079s, average error = 43.313mrad
# Starting Epoch 4968, with 107 batches
# 	Epoch 4968, Step 0000, MSE: 1.817e-03,  LearnRate: 6.250e-03, Time taken : 0.962s
# 	Epoch 4968, Step 0050, MSE: 1.816e-03,  LearnRate: 6.250e-03, Time taken : 2.373s
# 	Epoch 4968, Step 0100, MSE: 1.817e-03,  LearnRate: 6.250e-03, Time taken : 2.275s
# Epoch 4968 time: 5.274s, average error = 42.623mrad
# Starting Epoch 4969, with 107 batches
# 	Epoch 4969, Step 0000, MSE: 1.857e-03,  LearnRate: 6.250e-03, Time taken : 1.016s
# 	Epoch 4969, Step 0050, MSE: 1.858e-03,  LearnRate: 6.250e-03, Time taken : 2.376s
# 	Epoch 4969, Step 0100, MSE: 1.857e-03,  LearnRate: 6.250e-03, Time taken : 2.280s
# Epoch 4969 time: 5.249s, average error = 43.097mrad
# Starting Epoch 4970, with 107 batches
# 	Epoch 4970, Step 0000, MSE: 1.764e-03,  LearnRate: 6.250e-03, Time taken : 0.928s
# 	Epoch 4970, Step 0050, MSE: 1.762e-03,  LearnRate: 6.250e-03, Time taken : 2.243s
# 	Epoch 4970, Step 0100, MSE: 1.765e-03,  LearnRate: 6.250e-03, Time taken : 2.513s
# Epoch 4970 time: 5.332s, average error = 42.013mrad
# Starting Epoch 4971, with 107 batches
# 	Epoch 4971, Step 0000, MSE: 1.845e-03,  LearnRate: 6.250e-03, Time taken : 0.991s
# 	Epoch 4971, Step 0050, MSE: 1.845e-03,  LearnRate: 6.250e-03, Time taken : 2.174s
# 	Epoch 4971, Step 0100, MSE: 1.845e-03,  LearnRate: 6.250e-03, Time taken : 2.186s
# Epoch 4971 time: 4.932s, average error = 42.954mrad
# Starting Epoch 4972, with 107 batches
# 	Epoch 4972, Step 0000, MSE: 1.841e-03,  LearnRate: 6.250e-03, Time taken : 0.915s
# 	Epoch 4972, Step 0050, MSE: 1.842e-03,  LearnRate: 6.250e-03, Time taken : 2.291s
# 	Epoch 4972, Step 0100, MSE: 1.841e-03,  LearnRate: 6.250e-03, Time taken : 2.186s
# Epoch 4972 time: 5.010s, average error = 42.902mrad
# Starting Epoch 4973, with 107 batches
# 	Epoch 4973, Step 0000, MSE: 1.880e-03,  LearnRate: 6.250e-03, Time taken : 0.970s
# 	Epoch 4973, Step 0050, MSE: 1.882e-03,  LearnRate: 6.250e-03, Time taken : 2.210s
# 	Epoch 4973, Step 0100, MSE: 1.880e-03,  LearnRate: 6.250e-03, Time taken : 2.262s
# Epoch 4973 time: 5.092s, average error = 43.363mrad
# Starting Epoch 4974, with 107 batches
# 	Epoch 4974, Step 0000, MSE: 1.848e-03,  LearnRate: 6.250e-03, Time taken : 0.973s
# 	Epoch 4974, Step 0050, MSE: 1.849e-03,  LearnRate: 6.250e-03, Time taken : 2.313s
# 	Epoch 4974, Step 0100, MSE: 1.850e-03,  LearnRate: 6.250e-03, Time taken : 2.276s
# Epoch 4974 time: 5.160s, average error = 43.010mrad
# Starting Epoch 4975, with 107 batches
# 	Epoch 4975, Step 0000, MSE: 1.862e-03,  LearnRate: 6.250e-03, Time taken : 1.000s
# 	Epoch 4975, Step 0050, MSE: 1.861e-03,  LearnRate: 6.250e-03, Time taken : 2.296s
# 	Epoch 4975, Step 0100, MSE: 1.860e-03,  LearnRate: 6.250e-03, Time taken : 2.318s
# Epoch 4975 time: 5.259s, average error = 43.133mrad
# Starting Epoch 4976, with 107 batches
# 	Epoch 4976, Step 0000, MSE: 1.878e-03,  LearnRate: 6.250e-03, Time taken : 0.964s
# 	Epoch 4976, Step 0050, MSE: 1.888e-03,  LearnRate: 6.250e-03, Time taken : 2.192s
# 	Epoch 4976, Step 0100, MSE: 1.878e-03,  LearnRate: 6.250e-03, Time taken : 2.172s
# Epoch 4976 time: 4.936s, average error = 43.337mrad
# Starting Epoch 4977, with 107 batches
# 	Epoch 4977, Step 0000, MSE: 1.890e-03,  LearnRate: 6.250e-03, Time taken : 0.929s
# 	Epoch 4977, Step 0050, MSE: 1.892e-03,  LearnRate: 6.250e-03, Time taken : 2.368s
# 	Epoch 4977, Step 0100, MSE: 1.892e-03,  LearnRate: 6.250e-03, Time taken : 2.305s
# Epoch 4977 time: 5.219s, average error = 43.493mrad
# Starting Epoch 4978, with 107 batches
# 	Epoch 4978, Step 0000, MSE: 1.900e-03,  LearnRate: 6.250e-03, Time taken : 0.998s
# 	Epoch 4978, Step 0050, MSE: 1.901e-03,  LearnRate: 6.250e-03, Time taken : 2.424s
# 	Epoch 4978, Step 0100, MSE: 1.901e-03,  LearnRate: 6.250e-03, Time taken : 2.158s
# Epoch 4978 time: 5.231s, average error = 43.602mrad
# Starting Epoch 4979, with 107 batches
# 	Epoch 4979, Step 0000, MSE: 1.856e-03,  LearnRate: 6.250e-03, Time taken : 0.981s
# 	Epoch 4979, Step 0050, MSE: 1.855e-03,  LearnRate: 6.250e-03, Time taken : 2.230s
# 	Epoch 4979, Step 0100, MSE: 1.854e-03,  LearnRate: 6.250e-03, Time taken : 2.177s
# Epoch 4979 time: 4.996s, average error = 43.063mrad
# Starting Epoch 4980, with 107 batches
# 	Epoch 4980, Step 0000, MSE: 1.833e-03,  LearnRate: 6.250e-03, Time taken : 0.849s
# 	Epoch 4980, Step 0050, MSE: 1.834e-03,  LearnRate: 6.250e-03, Time taken : 2.491s
# 	Epoch 4980, Step 0100, MSE: 1.834e-03,  LearnRate: 6.250e-03, Time taken : 2.264s
# Epoch 4980 time: 5.346s, average error = 42.822mrad
# Starting Epoch 4981, with 107 batches
# 	Epoch 4981, Step 0000, MSE: 1.879e-03,  LearnRate: 6.250e-03, Time taken : 1.015s
# 	Epoch 4981, Step 0050, MSE: 1.878e-03,  LearnRate: 6.250e-03, Time taken : 2.175s
# 	Epoch 4981, Step 0100, MSE: 1.878e-03,  LearnRate: 6.250e-03, Time taken : 2.188s
# Epoch 4981 time: 4.932s, average error = 43.331mrad
# Starting Epoch 4982, with 107 batches
# 	Epoch 4982, Step 0000, MSE: 1.804e-03,  LearnRate: 6.250e-03, Time taken : 0.910s
# 	Epoch 4982, Step 0050, MSE: 1.807e-03,  LearnRate: 6.250e-03, Time taken : 2.246s
# 	Epoch 4982, Step 0100, MSE: 1.803e-03,  LearnRate: 6.250e-03, Time taken : 2.255s
# Epoch 4982 time: 5.041s, average error = 42.460mrad
# Starting Epoch 4983, with 107 batches
# 	Epoch 4983, Step 0000, MSE: 1.802e-03,  LearnRate: 6.250e-03, Time taken : 0.896s
# 	Epoch 4983, Step 0050, MSE: 1.805e-03,  LearnRate: 6.250e-03, Time taken : 2.413s
# 	Epoch 4983, Step 0100, MSE: 1.807e-03,  LearnRate: 6.250e-03, Time taken : 2.263s
# Epoch 4983 time: 5.225s, average error = 42.510mrad
# Starting Epoch 4984, with 107 batches
# 	Epoch 4984, Step 0000, MSE: 1.892e-03,  LearnRate: 6.250e-03, Time taken : 0.953s
# 	Epoch 4984, Step 0050, MSE: 1.893e-03,  LearnRate: 6.250e-03, Time taken : 2.355s
# 	Epoch 4984, Step 0100, MSE: 1.893e-03,  LearnRate: 6.250e-03, Time taken : 2.316s
# Epoch 4984 time: 5.271s, average error = 43.507mrad
# Starting Epoch 4985, with 107 batches
# 	Epoch 4985, Step 0000, MSE: 1.838e-03,  LearnRate: 6.250e-03, Time taken : 0.960s
# 	Epoch 4985, Step 0050, MSE: 1.841e-03,  LearnRate: 6.250e-03, Time taken : 2.127s
# 	Epoch 4985, Step 0100, MSE: 1.838e-03,  LearnRate: 6.250e-03, Time taken : 2.401s
# Epoch 4985 time: 5.162s, average error = 42.876mrad
# Starting Epoch 4986, with 107 batches
# 	Epoch 4986, Step 0000, MSE: 1.814e-03,  LearnRate: 6.250e-03, Time taken : 0.985s
# 	Epoch 4986, Step 0050, MSE: 1.813e-03,  LearnRate: 6.250e-03, Time taken : 2.356s
# 	Epoch 4986, Step 0100, MSE: 1.813e-03,  LearnRate: 6.250e-03, Time taken : 2.377s
# Epoch 4986 time: 5.425s, average error = 42.580mrad
# Starting Epoch 4987, with 107 batches
# 	Epoch 4987, Step 0000, MSE: 1.837e-03,  LearnRate: 6.250e-03, Time taken : 0.972s
# 	Epoch 4987, Step 0050, MSE: 1.837e-03,  LearnRate: 6.250e-03, Time taken : 2.181s
# 	Epoch 4987, Step 0100, MSE: 1.839e-03,  LearnRate: 6.250e-03, Time taken : 2.284s
# Epoch 4987 time: 5.055s, average error = 42.879mrad
# Starting Epoch 4988, with 107 batches
# 	Epoch 4988, Step 0000, MSE: 1.927e-03,  LearnRate: 6.250e-03, Time taken : 0.900s
# 	Epoch 4988, Step 0050, MSE: 1.929e-03,  LearnRate: 6.250e-03, Time taken : 2.290s
# 	Epoch 4988, Step 0100, MSE: 1.927e-03,  LearnRate: 6.250e-03, Time taken : 2.245s
# Epoch 4988 time: 5.093s, average error = 43.902mrad
# Starting Epoch 4989, with 107 batches
# 	Epoch 4989, Step 0000, MSE: 1.862e-03,  LearnRate: 6.250e-03, Time taken : 0.982s
# 	Epoch 4989, Step 0050, MSE: 1.866e-03,  LearnRate: 6.250e-03, Time taken : 2.298s
# 	Epoch 4989, Step 0100, MSE: 1.865e-03,  LearnRate: 6.250e-03, Time taken : 2.224s
# Epoch 4989 time: 5.168s, average error = 43.183mrad
# Starting Epoch 4990, with 107 batches
# 	Epoch 4990, Step 0000, MSE: 1.851e-03,  LearnRate: 6.250e-03, Time taken : 1.031s
# 	Epoch 4990, Step 0050, MSE: 1.853e-03,  LearnRate: 6.250e-03, Time taken : 2.290s
# 	Epoch 4990, Step 0100, MSE: 1.852e-03,  LearnRate: 6.250e-03, Time taken : 2.160s
# Epoch 4990 time: 5.103s, average error = 43.029mrad
# Starting Epoch 4991, with 107 batches
# 	Epoch 4991, Step 0000, MSE: 1.860e-03,  LearnRate: 6.250e-03, Time taken : 0.977s
# 	Epoch 4991, Step 0050, MSE: 1.861e-03,  LearnRate: 6.250e-03, Time taken : 2.275s
# 	Epoch 4991, Step 0100, MSE: 1.860e-03,  LearnRate: 6.250e-03, Time taken : 2.250s
# Epoch 4991 time: 5.126s, average error = 43.130mrad
# Starting Epoch 4992, with 107 batches
# 	Epoch 4992, Step 0000, MSE: 1.891e-03,  LearnRate: 6.250e-03, Time taken : 1.004s
# 	Epoch 4992, Step 0050, MSE: 1.891e-03,  LearnRate: 6.250e-03, Time taken : 2.310s
# 	Epoch 4992, Step 0100, MSE: 1.891e-03,  LearnRate: 6.250e-03, Time taken : 2.211s
# Epoch 4992 time: 5.122s, average error = 43.490mrad
# Starting Epoch 4993, with 107 batches
# 	Epoch 4993, Step 0000, MSE: 1.906e-03,  LearnRate: 6.250e-03, Time taken : 0.929s
# 	Epoch 4993, Step 0050, MSE: 1.912e-03,  LearnRate: 6.250e-03, Time taken : 2.187s
# 	Epoch 4993, Step 0100, MSE: 1.907e-03,  LearnRate: 6.250e-03, Time taken : 2.306s
# Epoch 4993 time: 5.063s, average error = 43.670mrad
# Starting Epoch 4994, with 107 batches
# 	Epoch 4994, Step 0000, MSE: 1.890e-03,  LearnRate: 6.250e-03, Time taken : 0.966s
# 	Epoch 4994, Step 0050, MSE: 1.890e-03,  LearnRate: 6.250e-03, Time taken : 2.489s
# 	Epoch 4994, Step 0100, MSE: 1.889e-03,  LearnRate: 6.250e-03, Time taken : 2.171s
# Epoch 4994 time: 5.228s, average error = 43.468mrad
# Starting Epoch 4995, with 107 batches
# 	Epoch 4995, Step 0000, MSE: 1.873e-03,  LearnRate: 6.250e-03, Time taken : 0.954s
# 	Epoch 4995, Step 0050, MSE: 1.880e-03,  LearnRate: 6.250e-03, Time taken : 2.299s
# 	Epoch 4995, Step 0100, MSE: 1.875e-03,  LearnRate: 6.250e-03, Time taken : 2.414s
# Epoch 4995 time: 5.313s, average error = 43.298mrad
# Starting Epoch 4996, with 107 batches
# 	Epoch 4996, Step 0000, MSE: 1.814e-03,  LearnRate: 6.250e-03, Time taken : 1.003s
# 	Epoch 4996, Step 0050, MSE: 1.815e-03,  LearnRate: 6.250e-03, Time taken : 2.188s
# 	Epoch 4996, Step 0100, MSE: 1.814e-03,  LearnRate: 6.250e-03, Time taken : 2.621s
# Epoch 4996 time: 5.478s, average error = 42.588mrad
# Starting Epoch 4997, with 107 batches
# 	Epoch 4997, Step 0000, MSE: 1.863e-03,  LearnRate: 6.250e-03, Time taken : 1.134s
# 	Epoch 4997, Step 0050, MSE: 1.865e-03,  LearnRate: 6.250e-03, Time taken : 2.479s
# 	Epoch 4997, Step 0100, MSE: 1.863e-03,  LearnRate: 6.250e-03, Time taken : 2.402s
# Epoch 4997 time: 5.529s, average error = 43.165mrad
# Starting Epoch 4998, with 107 batches
# 	Epoch 4998, Step 0000, MSE: 1.803e-03,  LearnRate: 6.250e-03, Time taken : 0.971s
# 	Epoch 4998, Step 0050, MSE: 1.800e-03,  LearnRate: 6.250e-03, Time taken : 2.250s
# 	Epoch 4998, Step 0100, MSE: 1.805e-03,  LearnRate: 6.250e-03, Time taken : 2.227s
# Epoch 4998 time: 5.130s, average error = 42.485mrad
# Starting Epoch 4999, with 107 batches
# 	Epoch 4999, Step 0000, MSE: 1.886e-03,  LearnRate: 6.250e-03, Time taken : 0.980s
# 	Epoch 4999, Step 0050, MSE: 1.888e-03,  LearnRate: 6.250e-03, Time taken : 2.233s
# 	Epoch 4999, Step 0100, MSE: 1.885e-03,  LearnRate: 6.250e-03, Time taken : 2.324s
# Epoch 4999 time: 5.113s, average error = 43.419mrad
#
# Total time:	 29131.412s
# Model saved in path: ./model_SGD_Nesterov_2.ckpt
